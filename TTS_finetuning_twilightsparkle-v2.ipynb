# %% [markdown]
# <a href="https://colab.research.google.com/github/Conv-AI/TTS-Dev/blob/main/TTS_finetuning_Starlight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setting up the environment

# %%
# !pip install hydra-core==1.1
# !pip install scipy==1.7.3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hydra-core==1.1 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (4.8)
# Requirement already satisfied: omegaconf==2.1.* in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (2.1.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (5.7.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf==2.1.*->hydra-core==1.1) (6.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->hydra-core==1.1) (3.8.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scipy==1.7.3 in /usr/local/lib/python3.7/dist-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy==1.7.3) (1.21.6)

# %%
# !nvidia-smi
# Out:
# Sat Jul  9 18:26:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
BRANCH = 'main'
# If you're using Google Colab and not running locally, uncomment and run this cell.
# !apt-get install sox libsndfile1 ffmpeg
# !pip install wget unidecode pynini==2.1.4
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# Out:
# E: dpkg was interrupted, you must manually run 'dpkg --configure -a' to correct the problem.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.1 MB/s
# Collecting pynini==2.1.4
#   Downloading pynini-2.1.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165.5 MB)
#      |████████████████████████████████| 165.5 MB 60 kB/s
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from pynini==2.1.4) (0.29.30)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=3d7f28c7d1c44dd22b99a9fa0aa54ab8f767b526988183f8ed75731b84f57450
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget, unidecode, pynini
# Successfully installed pynini-2.1.4 unidecode-1.3.4 wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-p_6k4lhp/nemo-toolkit_5b8d8c805f384694bf62f30d30c48eb1
#   Running command git clone -q https://github.com/NVIDIA/NeMo.git /tmp/pip-install-p_6k4lhp/nemo-toolkit_5b8d8c805f384694bf62f30d30c48eb1
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 5.0 MB/s
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.21.6)
# Collecting onnx>=1.7.0
#   Downloading onnx-1.12.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 58.0 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.11.0+cu113)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 45.8 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.64.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.51.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2)
# Collecting frozendict
#   Downloading frozendict-2.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (99 kB)
#      |████████████████████████████████| 99 kB 7.4 MB/s
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.4)
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 9.9 MB/s
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.8 MB/s
# Collecting isort[requirements]<5
#   Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 990 kB/s
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Collecting pytest-runner
#   Using cached pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.8.6)
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.4.2-py3-none-any.whl (39 kB)
# Collecting wandb
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 48.8 MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2022.6.2)
# Requirement already satisfied: pynini==2.1.4 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.4)
# Collecting pytorch-lightning>=1.6.1
#   Downloading pytorch_lightning-1.6.4-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 39.0 MB/s
# Collecting torchmetrics>=0.4.1rc0
#   Downloading torchmetrics-0.9.2-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 62.4 MB/s
# Collecting transformers>=4.0.1
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 56.5 MB/s
# Collecting webdataset<=0.1.62,>=0.1.48
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Requirement already satisfied: omegaconf<2.2,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: hydra-core<1.2,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.1.0)
# Collecting pyyaml<6
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 69.5 MB/s
# Collecting sentencepiece<1.0.0
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 59.2 MB/s
# Collecting youtokentome>=1.0.5
#   Downloading youtokentome-1.0.6-cp37-cp37m-manylinux2010_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 61.2 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Collecting sacremoses>=0.0.43
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 57.3 MB/s
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Collecting marshmallow
#   Downloading marshmallow-3.17.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 5.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.10.3.post1)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 49.7 MB/s
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting pyannote.core
#   Downloading pyannote.core-4.4-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 4.0 MB/s
# Collecting pyannote.metrics
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 143 kB/s
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.7.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.12.0+cu113)
# Collecting boto3
#   Downloading boto3-1.24.26-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 61.0 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting matplotlib>=3.3.2
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 34.4 MB/s
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.1.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 52.8 MB/s
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.1.0-py3-none-any.whl (92 kB)
#      |████████████████████████████████| 92 kB 10.3 MB/s
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.7)
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 1.2 MB/s
# Collecting opencc
#   Downloading OpenCC-1.1.4-cp37-cp37m-manylinux1_x86_64.whl (769 kB)
#      |████████████████████████████████| 769 kB 52.7 MB/s
# Collecting pangu
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.5 MB/s
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.9-py2.py3-none-any.whl (25 kB)
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting ijson
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 61.8 MB/s
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 20.8 MB/s
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 4.8 MB/s
# Collecting pypinyin
#   Downloading pypinyin-0.46.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 52.5 MB/s
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pystoi
#   Downloading pystoi-0.3.3.tar.gz (7.0 kB)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
# Requirement already satisfied: click>=6.5 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (7.1.2)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 27.5 MB/s
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (21.4.0)
# Collecting toml>=0.9.4
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from pynini==2.1.4->nemo_toolkit[all]) (0.29.30)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.2,>=1.1.0->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.2,>=1.1.0->nemo_toolkit[all]) (4.8)
# Collecting pip-api
#   Downloading pip_api-0.0.29-py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 67.7 MB/s
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.12.2->onnx>=1.7.0->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.8.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 55.5 MB/s
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 58.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.46.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (3.7.1)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 56.7 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 71.1 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.7 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 69.5 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 8.3 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.28.0,>=1.27.26
#   Downloading botocore-1.27.26-py3-none-any.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 56.4 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 68.8 MB/s
# Collecting pybind11>=2.2
#   Using cached pybind11-2.9.2-py2.py3-none-any.whl (213 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (2022.1)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (1.1.4)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.5 MB/s
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      |████████████████████████████████| 180 kB 71.0 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->nemo_toolkit[all]) (1.5.2)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.4.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.3.5)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (1.0.18)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.6.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (4.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (0.18.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (23.1.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->nemo_toolkit[all]) (0.34.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (21.1.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.6.2)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Collecting simplejson>=3.8.1
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 54.0 MB/s
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Collecting pyannote.database>=4.0.1
#   Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 471 kB/s
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (0.8.9)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Collecting colorama<0.5.0,>=0.4.3
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.4.0-py2.py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (8.13.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.4.0)
# Collecting jarowinkler<2.0.0,>=1.1.0
#   Downloading jarowinkler-1.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (104 kB)
#      |████████████████████████████████| 104 kB 67.0 MB/s
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.7.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 54.6 MB/s
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Collecting ipadic<2.0,>=1.0
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      |████████████████████████████████| 13.4 MB 48.3 MB/s
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (574 kB)
#      |████████████████████████████████| 574 kB 60.0 MB/s
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.10.2)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.2.4)
# Requirement already satisfied: docutils<0.18,>=0.11 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.17.1)
# Collecting sphinx
#   Downloading Sphinx-5.0.2-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 56.6 MB/s
# Collecting pybtex>=0.24
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 53.6 MB/s
# Collecting pybtex-docutils>=1.0.0
#   Downloading pybtex_docutils-1.0.2-py3-none-any.whl (6.3 kB)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 10.6 MB/s
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 7.6 MB/s
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.6 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 53.0 MB/s
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.6.0-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 55.5 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (2.3)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 48.8 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: nemo-toolkit, sacremoses, fasttext, distance, kaldi-python-io, kaldiio, pesq, pystoi, ipadic, sentence-transformers, pathtools
#   Building wheel for nemo-toolkit (setup.py) ... done
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-1.11.0rc0-py3-none-any.whl size=3632536 sha256=817611794540adfb044058731e341cc3e730ce4f58d4966bff0ca2ae9e90e9b0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pkb_hcbp/wheels/82/66/ef/7248c1c27216d06425cab14b3391059534c889aaf2db89b855
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=ce805fbb2d1fc71215f2bf397da60dd3bbda46b6fe19373a92ddd44c7787c204
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3138319 sha256=7b1ec84e5874821c04a9485eb121281a6d87c7cc11f5128274ad876e98075eec
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16276 sha256=96f748ba311ff38f1349fcc86d69aae9949482a5b10d8718af8ec95de228472d
#   Stored in directory: /root/.cache/pip/wheels/b2/10/1b/96fca621a1be378e2fe104cfb0d160bb6cdf3d04a3d35266cc
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8969 sha256=9b4bdf86fb22cd0a0b8b7583b312248efacf380945f46d258a98a0702250c223
#   Stored in directory: /root/.cache/pip/wheels/a9/26/38/7678d1ff6cd1bbcbfc0d80b0a29d94d917dfa9ad790b4a85a9
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24471 sha256=9458a6cf768c7d4a36ed13b40bb33d4338568386c7d613d8e00f0ec4f926fc0e
#   Stored in directory: /root/.cache/pip/wheels/04/07/e8/45641287c59bf6ce41e22259f8680b521c31e6306cb88392ac
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp37-cp37m-linux_x86_64.whl size=214577 sha256=e4bdebaa55fc789ffd1fe38d83e32fffb6465ca8994909cbd776fa83cf7beb7b
#   Stored in directory: /root/.cache/pip/wheels/c5/3d/9c/542731f8357f7c82eb6ac2047cc5375f92c9a05b09a715aff6
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7793 sha256=74796b2fa3824778a044ca8293d5d6cab1ca2ec134de54aacaa12c4e066c512e
#   Stored in directory: /root/.cache/pip/wheels/46/4a/ad/3ab460193ed0535430b4b1575f255aa6bae69df17453628e86
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556723 sha256=dbba05e1fcd28f334abf7dc3bde2b3c1971ada8225addbac0c228db75ccba174
#   Stored in directory: /root/.cache/pip/wheels/33/8b/99/cf0d27191876637cd3639a560f93aa982d7855ce826c94348b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=1775b7bd4a0158dfe8370c0cca7b6d6c84f939cf69253aa2dc8756d23404f37c
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=970b26048938b8962e49189fb39dd7675fa1d7a4ed7dd8e5511c521f9ba382c0
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built nemo-toolkit sacremoses fasttext distance kaldi-python-io kaldiio pesq pystoi ipadic sentence-transformers pathtools
# Installing collected packages: urllib3, setuptools, multidict, frozenlist, yarl, smmap, simplejson, shellingham, pyyaml, latexcodec, jmespath, colorama, asynctest, async-timeout, aiosignal, yarg, tokenizers, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, ruamel.yaml.clib, pybtex, pyannote.core, portalocker, huggingface-hub, gitdb, fsspec, botocore, aiohttp, typed-ast, transformers, torchmetrics, toml, sphinx, shortuuid, setproctitle, sentry-sdk, sentencepiece, sacrebleu, s3transfer, ruamel.yaml, pyDeprecate, pybtex-docutils, pybind11, pyannote.database, pipreqs, pip-api, pathtools, pathspec, onnx, mecab-python3, jarowinkler, isort, ipadic, GitPython, frozendict, docker-pycreds, distance, braceexpand, aniso8601, youtokentome, webdataset, wandb, sphinxcontrib-bibtex, sox, sentence-transformers, sacremoses, rapidfuzz, pytorch-lightning, pytest-runner, pystoi, pypinyin, pydub, pyannote.metrics, pesq, parameterized, pangu, opencc, nemo-toolkit, marshmallow, kaldiio, kaldi-python-io, ijson, g2p-en, ftfy, flask-restful, fasttext, faiss-cpu, einops, boto3, black, attrdict
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed GitPython-3.1.27 aiohttp-3.8.1 aiosignal-1.2.0 aniso8601-9.0.1 async-timeout-4.0.2 asynctest-0.13.0 attrdict-2.0.1 black-19.10b0 boto3-1.24.26 botocore-1.27.26 braceexpand-0.1.7 colorama-0.4.5 distance-0.1.3 docker-pycreds-0.4.0 einops-0.4.1 faiss-cpu-1.7.2 fasttext-0.9.2 flask-restful-0.3.9 frozendict-2.3.2 frozenlist-1.3.0 fsspec-2022.5.0 ftfy-6.1.1 g2p-en-2.1.0 gitdb-4.0.9 huggingface-hub-0.8.1 ijson-3.1.4 ipadic-1.0.0 isort-4.3.21 jarowinkler-1.1.1 jmespath-1.0.1 kaldi-python-io-1.2.2 kaldiio-2.17.2 latexcodec-2.0.1 marshmallow-3.17.0 mecab-python3-1.0.5 multidict-6.0.2 nemo-toolkit-1.11.0rc0 onnx-1.12.0 opencc-1.1.4 pangu-4.0.6.1 parameterized-0.8.1 pathspec-0.9.0 pathtools-0.1.2 pesq-0.0.4 pip-api-0.0.29 pipreqs-0.4.11 portalocker-2.5.1 pyDeprecate-0.3.2 pyannote.core-4.4 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pybind11-2.9.2 pybtex-0.24.0 pybtex-docutils-1.0.2 pydub-0.25.1 pypinyin-0.46.0 pystoi-0.3.3 pytest-runner-6.0.0 pytorch-lightning-1.6.4 pyyaml-5.4.1 rapidfuzz-2.1.3 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 s3transfer-0.6.0 sacrebleu-2.1.0 sacremoses-0.0.53 sentence-transformers-2.2.2 sentencepiece-0.1.96 sentry-sdk-1.6.0 setproctitle-1.2.3 setuptools-59.5.0 shellingham-1.4.0 shortuuid-1.0.9 simplejson-3.17.6 smmap-5.0.0 sox-1.4.1 sphinx-5.0.2 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-bibtex-2.4.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 tokenizers-0.12.1 toml-0.10.2 torchmetrics-0.9.2 transformers-4.20.1 typed-ast-1.5.4 urllib3-1.25.11 wandb-0.12.21 webdataset-0.1.62 yarg-0.1.9 yarl-1.7.2 youtokentome-1.0.6

# %%
home_path = !(echo $HOME)
home_path = home_path[0]
print(home_path)
# Out:
# /root

# %%
# !sudo dpkg --configure -a
# Out:
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
#=== load the repo and data (Thanks Synthbot) ===
# !sudo apt -qq install -y sox
# !git clone "https://github.com/synthbot-anon/synthbot.git" /content/synthbot
!(cd /content/synthbot; git checkout experimental)
# !python3 -m pip install pysoundfile 
# !python3 -m pip install librosa
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   libsox-fmt-alsa libsox-fmt-base libsox3
# Suggested packages:
#   libsox-fmt-all
# The following NEW packages will be installed:
#   libsox-fmt-alsa libsox-fmt-base libsox3 sox
# 0 upgraded, 4 newly installed, 0 to remove and 62 not upgraded.
# Need to get 0 B/370 kB of archives.
# After this operation, 1,174 kB of additional disk space will be used.
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libsox3:amd64.
# (Reading database ... 155671 files and directories currently installed.)
# Preparing to unpack .../libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# fatal: destination path '/content/synthbot' already exists and is not an empty directory.
# Already on 'experimental'
# Your branch is up to date with 'origin/experimental'.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pysoundfile in /usr/local/lib/python3.7/dist-packages (0.9.0.post1)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.7/dist-packages (from pysoundfile) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=0.6->pysoundfile) (2.21)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.2.2)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.7.3)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (59.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy>=0.2.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)

# %% [markdown]
# ## Preparing the Dataset for Fastpitch finetuning

# %%
#downloading the dataset
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=16RgwgcvZTS0926hAszj7bu-NmjuHiAqq' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=16RgwgcvZTS0926hAszj7bu-NmjuHiAqq" -O twilight_sparkle.tar && rm -rf /tmp/cookies.txt
# Out:
# --2022-07-09 18:29:48--  https://docs.google.com/uc?export=download&confirm=t&id=16RgwgcvZTS0926hAszj7bu-NmjuHiAqq
# Resolving docs.google.com (docs.google.com)... 173.194.216.113, 173.194.216.102, 173.194.216.138, ...
# Connecting to docs.google.com (docs.google.com)|173.194.216.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-84-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k7l3hu4mnubsvot60cm6n2g0bpnlc703/1657391325000/05434657448262868821/*/16RgwgcvZTS0926hAszj7bu-NmjuHiAqq?e=download&uuid=2df8ac76-254f-46ee-bbe9-edfc5a5b3e90 [following]
# Warning: wildcards not supported in HTTP.
# --2022-07-09 18:29:49--  https://doc-0k-84-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/k7l3hu4mnubsvot60cm6n2g0bpnlc703/1657391325000/05434657448262868821/*/16RgwgcvZTS0926hAszj7bu-NmjuHiAqq?e=download&uuid=2df8ac76-254f-46ee-bbe9-edfc5a5b3e90
# Resolving doc-0k-84-docs.googleusercontent.com (doc-0k-84-docs.googleusercontent.com)... 173.194.215.132, 2607:f8b0:400c:c0c::84
# Connecting to doc-0k-84-docs.googleusercontent.com (doc-0k-84-docs.googleusercontent.com)|173.194.215.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2405294080 (2.2G) [application/x-tar]
# Saving to: ‘twilight_sparkle.tar’
#
# twilight_sparkle.ta 100%[===================>]   2.24G   159MB/s    in 14s
#
# 2022-07-09 18:30:03 (159 MB/s) - ‘twilight_sparkle.tar’ saved [2405294080/2405294080]

# %%
skip_noisy = True # Disable to train with Noisy Data included
allowed_emotions = """
Anxious
Angry
Annoyed
Amused
Confused
Crazy
Disgust
Exhausted
Fear
Happy
Neutral
Sad
Serious
Singing
Shouting
Surprised
Smug
Love
Sarcastic
Tired
Whispering
Whining
""".split("\n")[1:-1]

# %%
percentage_training_data = 0.95 # 90% of Data will be used for training, 5% for Validation

# %%
import sys
sys.path.append('/content/synthbot/src')
from ponysynth.corpus import ClipperArchive, phoneme_transcription
import librosa
import subprocess

# %%
archive_fn = "/content/twilight_sparkle.tar"
archive = ClipperArchive(archive_fn)

# %%
data_path = 'TwilightSparkle'
allowed_emotions = [x.lower() for x in allowed_emotions]
# !mkdir {data_path}
# !mkdir {data_path+"/out"}
all_clips = []; all_clips_arpa = []; skipped_count=0; too_short_count=0; emotion_skip=0
for key in archive.keys(): # write the audio files for processing in bash terminal
  audio = archive.read_audio(key)
  audio_fn = '{}/{}.wav'.format(data_path, key)
  audio_fn_ = '{}/{}.wav'.format(data_path+"/out", key)
  with open(audio_fn, 'wb') as audio_out:
    audio_out.write(audio.read())

# %%
# %%script bash
# # trim all 48Khz files
# cd TwilightSparkle
# for input in *.wav; do
#   output="out/$input"
#   sox "$input" "$output" silence 1 0.05 0.1% reverse silence 1 0.05 0.1% reverse;
# done

# %%
import os

should_continue = 0 # should run "continue" command inside outer loop.
for key in archive.keys():
  label = archive.read_label(key)
  audio_fn = '{}/{}.wav'.format(data_path, key)
  audio_fn_ = '{}/{}.wav'.format(data_path+"/out", key)
  if (label['noise'] in ['Very Noisy','Noisy']) and skip_noisy: os.remove(audio_fn_); skipped_count+=1; continue

  for tag in label['tags']:
     if tag.lower() not in allowed_emotions:
       try: os.remove(audio_fn_)
       except: pass
       print(tag+" emotion not in list"); emotion_skip+=1; should_continue = 1; break # this is supposed to break the outer loop
  if should_continue: should_continue = 0; continue

  audio = archive.read_audio(key)
  transcript = label['utterance']['content']
  
  if os.stat(audio_fn_).st_size < 71602:
    #print("Skipping Audio, Duration: "+str(len(librosa.core.load(audio_fn_, sr=48000)[0])/48000))
    try: os.remove(audio_fn_)
    except: pass
    too_short_count+=1; continue # Skips files based on size.

  filelist_line = "{}|{}".format(audio_fn_, transcript)
  all_clips.append(filelist_line)
  filelist_line = "{}|{}".format(audio_fn_, phoneme_transcription(label))
  all_clips_arpa.append(filelist_line)
    
print(str(skipped_count)+" Files are too Noisy.")
print(str(emotion_skip)+" Files contain an emotion not in permitted emotions")
print(str(too_short_count)+" Files are too short")
print(str(len(list(archive.keys()))-(skipped_count+too_short_count+emotion_skip))+" Files kept in dataset.")
# Out:
# 6037 Files are too Noisy.
# 0 Files contain an emotion not in permitted emotions
# 363 Files are too short
# 3491 Files kept in dataset.

# %%
# shuffle the training data
import random
random.seed(0)
random.shuffle(all_clips)

# get train, test, validation splits
num_clips = len(all_clips)
train_end = int(num_clips * percentage_training_data)

train = all_clips[:train_end]
validation = all_clips[train_end:]

train_arpa = all_clips_arpa[:train_end]
validation_arpa = all_clips_arpa[train_end:]

# dump the info to filelist files
with open('train_filelist_twilightsparkle.txt', 'w') as train_out:
  train_out.write('\n'.join(train)+'\n'+'\n'.join(train_arpa)+"")
with open('val_filelist_twilightsparkle.txt', 'w') as val_out:
  val_out.write('\n'.join(validation)+'\n'+'\n'.join(validation_arpa)+"")

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json

# %%
#imports
import os
import json
import random
import librosa

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

from nemo.collections.tts.models import FastPitchModel
# Out:
# [NeMo W 2022-07-09 18:33:55 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-07-09 18:33:55 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.

# %%
#creating the json files for training and validation
with open('/content/train_filelist_twilightsparkle.txt') as f :
  records = f.readlines()

print("Number of records : ",len(records))

train_manifest = 'fastpitch_train.json'

train_rec = []
random.shuffle(records)
count = 0

for i in records :
  #if count > 1200 :
  #  break
  
  i = i.split('|')
  audio_filepath = i[0]
  text = i[-1].strip('\n')
  if '{' in text :
    #print(text)
    continue
  count = count + 1

  duration = librosa.get_duration(filename=audio_filepath)
  r = {
       "audio_filepath" : audio_filepath,
       "text" : text,
       "duration" : round(duration,1),
       "text_no_preprocessing" : text
    }

  train_rec.append(r)

with open(train_manifest, "w") as f:
    for s in train_rec:
        f.write(json.dumps(s) + '\n')
        
print("Training Data : ", len(train_rec))
# Out:
# Number of records :  6632
# Training Data :  3316

# %%
with open('/content/val_filelist_twilightsparkle.txt') as f :
  records_val = f.readlines()

print("Number of records : ", len(records_val))

val_manifest = 'fastpitch_val.json'
count = 0
val_rec = []
random.shuffle(records_val)

for i in records_val:
  #if count > 50 :
  #  break
    
  i = i.split('|')
  audio_filepath = i[0]
  text = i[-1].strip('\n')

  if '{' in text :
    #print(text)
    continue
  count = count + 1
  duration = librosa.get_duration(filename=audio_filepath)
  r = {
       "audio_filepath" : audio_filepath,
       "text" : text,
       "duration" : round(duration,1),
       "text_no_preprocessing" : text
    }

  val_rec.append(r)

print(len(val_rec))
with open(val_manifest, "w") as f:
    for s in val_rec:
        f.write(json.dumps(s) + '\n')
# Out:
# Number of records :  350
# 175

# %%
FastPitchModel.from_pretrained("tts_en_fastpitch")
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_en_fastpitch_align.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_en_fastpitch_align.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# [NeMo I 2022-07-09 18:33:56 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/tts_en_fastpitch/versions/1.8.1/files/tts_en_fastpitch_align.nemo to /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo
# [NeMo I 2022-07-09 18:34:09 common:789] Instantiating model from pre-trained checkpoint
# [NeMo I 2022-07-09 18:34:12 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-09 18:34:36 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-07-09 18:34:37 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-09 18:34:37 modelPT:150] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-07-09 18:34:37 modelPT:157] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
# [NeMo I 2022-07-09 18:34:37 features:200] PADDING: 1
# [NeMo I 2022-07-09 18:34:50 save_restore_connector:243] Model FastPitchModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo.
# Copying /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo to ./
# 187023360

# %%
# !wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/fastpitch_finetune.py

# !mkdir -p conf \
&& cd conf \
&& wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/fastpitch_align_v1.05.yaml \
&& cd ..
# Out:
# --2022-07-09 18:34:50--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/fastpitch_finetune.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1751 (1.7K) [text/plain]
# Saving to: ‘fastpitch_finetune.py’
#
# fastpitch_finetune. 100%[===================>]   1.71K  --.-KB/s    in 0s
#
# 2022-07-09 18:34:50 (32.3 MB/s) - ‘fastpitch_finetune.py’ saved [1751/1751]
#
# --2022-07-09 18:34:50--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/fastpitch_align_v1.05.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6692 (6.5K) [text/plain]
# Saving to: ‘fastpitch_align_v1.05.yaml’
#
# fastpitch_align_v1. 100%[===================>]   6.54K  --.-KB/s    in 0s
#
# 2022-07-09 18:34:50 (76.5 MB/s) - ‘fastpitch_align_v1.05.yaml’ saved [6692/6692]

# %%
# additional files
# !mkdir -p tts_dataset_files && cd tts_dataset_files \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/cmudict-0.7b_nv22.07 \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/heteronyms-030921 \
&& wget wget https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/nemo_text_processing/text_normalization/en/data/whitelist/lj_speech.tsv \
&& cd ..
# Out:
# --2022-07-09 18:34:51--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/cmudict-0.7b_nv22.07
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3722012 (3.5M) [text/plain]
# Saving to: ‘cmudict-0.7b_nv22.07’
#
# cmudict-0.7b_nv22.0 100%[===================>]   3.55M  --.-KB/s    in 0.07s
#
# 2022-07-09 18:34:51 (52.5 MB/s) - ‘cmudict-0.7b_nv22.07’ saved [3722012/3722012]
#
# --2022-07-09 18:34:51--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/heteronyms-030921
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3132 (3.1K) [text/plain]
# Saving to: ‘heteronyms-030921’
#
# heteronyms-030921   100%[===================>]   3.06K  --.-KB/s    in 0s
#
# 2022-07-09 18:34:51 (20.1 MB/s) - ‘heteronyms-030921’ saved [3132/3132]
#
# --2022-07-09 18:34:51--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2022-07-09 18:34:51--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/nemo_text_processing/text_normalization/en/data/whitelist/lj_speech.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 263 [text/plain]
# Saving to: ‘lj_speech.tsv’
#
# lj_speech.tsv       100%[===================>]     263  --.-KB/s    in 0s
#
# 2022-07-09 18:34:51 (18.8 MB/s) - ‘lj_speech.tsv’ saved [263/263]
#
# FINISHED --2022-07-09 18:34:51--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 263 in 0s (18.8 MB/s)

# %%
def pre_calculate_supplementary_data(sup_data_path, sup_data_types, text_tokenizer, text_normalizer, text_normalizer_call_kwargs):
    # init train and val dataloaders
    stages = ["train", "val"]
    stage2dl = {}
    for stage in stages:
        ds = TTSDataset(
            manifest_filepath=f"fastpitch_{stage}.json",
            sample_rate=16000,
            sup_data_path=sup_data_path,
            sup_data_types=sup_data_types,
            n_fft=1024,
            win_length=1024,
            hop_length=256,
            window="hann",
            n_mels=80,
            lowfreq=0,
            highfreq=8000,
            text_tokenizer=text_tokenizer,
            text_normalizer=text_normalizer,
            text_normalizer_call_kwargs=text_normalizer_call_kwargs

        ) 
        stage2dl[stage] = torch.utils.data.DataLoader(ds, batch_size=1, collate_fn=ds._collate_fn, num_workers=1)

    # iteration over dataloaders
    pitch_mean, pitch_std, pitch_min, pitch_max = None, None, None, None
    for stage, dl in stage2dl.items():
        pitch_list = []
        print(stage)
        print(dl)
        for batch in tqdm(dl, total=len(dl)):
            tokens, tokens_lengths, audios, audio_lengths, attn_prior, pitches, pitches_lengths = batch
            pitch = pitches.squeeze(0)
            pitch_list.append(pitch[pitch != 0])

        if stage == "train":
            pitch_tensor = torch.cat(pitch_list)
            pitch_mean, pitch_std = pitch_tensor.mean().item(), pitch_tensor.std().item()
            pitch_min, pitch_max = pitch_tensor.min().item(), pitch_tensor.max().item()
    
    print("Pitch_mean : ",pitch_mean)
    print("Pitch_std : ",pitch_std)
    print("Pitch_min : ",pitch_min)
    print("Pitch_max : ",pitch_max)
            
    return pitch_mean, pitch_std, pitch_min, pitch_max

# %%
from nemo.collections.tts.torch.g2ps import EnglishG2p
from nemo.collections.tts.torch.data import TTSDataset
from nemo_text_processing.text_normalization.normalize import Normalizer
from nemo.collections.tts.torch.tts_tokenizers import EnglishPhonemesTokenizer, EnglishCharsTokenizer

import torch
from tqdm.notebook import tqdm

# %%
# Text normalizer
text_normalizer = Normalizer(
    lang="en", 
    input_case="cased", 
    whitelist="./tts_dataset_files/lj_speech.tsv"
)

text_normalizer_call_kwargs = {
    "punct_pre_process": True,
    "punct_post_process": True
}

# Text tokenizer
text_tokenizer = EnglishCharsTokenizer()
# Out:
# [NeMo I 2022-07-09 18:34:54 tokenize_and_classify:87] Creating ClassifyFst grammars.

# %%
fastpitch_sup_data_path = "fastpitch_sup_data_folder"
sup_data_types = ["align_prior_matrix", "pitch"]

pitch_mean, pitch_std, pitch_min, pitch_max = pre_calculate_supplementary_data(
    fastpitch_sup_data_path, sup_data_types, text_tokenizer, text_normalizer, text_normalizer_call_kwargs
)
# Out:
# [NeMo I 2022-07-09 18:35:17 data:186] Loading dataset from fastpitch_train.json.
# 3316it [00:38, 87.22it/s]
# [NeMo I 2022-07-09 18:35:55 data:221] Loaded dataset with 3316 files.
# [NeMo I 2022-07-09 18:35:55 data:223] Dataset contains 2.17 hours.
# [NeMo I 2022-07-09 18:35:55 data:321] Pruned 0 files. Final dataset contains 3316 files
# [NeMo I 2022-07-09 18:35:55 data:324] Pruned 0.00 hours. Final dataset contains 2.17 hours.
# [NeMo I 2022-07-09 18:35:55 data:186] Loading dataset from fastpitch_val.json.
# 175it [00:02, 85.59it/s]
# [NeMo I 2022-07-09 18:35:57 data:221] Loaded dataset with 175 files.
# [NeMo I 2022-07-09 18:35:57 data:223] Dataset contains 0.11 hours.
# [NeMo I 2022-07-09 18:35:57 data:321] Pruned 0 files. Final dataset contains 175 files
# [NeMo I 2022-07-09 18:35:57 data:324] Pruned 0.00 hours. Final dataset contains 0.11 hours.
# train
# <torch.utils.data.dataloader.DataLoader object at 0x7fab96c11ad0>
#   0%|          | 0/3316 [00:00<?, ?it/s]
# val
# <torch.utils.data.dataloader.DataLoader object at 0x7fab99032dd0>
#   0%|          | 0/175 [00:00<?, ?it/s]
# Pitch_mean :  319.8547668457031
# Pitch_std :  122.54292297363281
# Pitch_min :  65.4063949584961
# Pitch_max :  2068.96435546875

# %% [markdown]
# ## finetuning the Fastpitch model

# %%
#setting up wandb credentials
#weights and biases 
wandb_api_key = "d06dcb679ec9cf0d71c81cb750d142b6b90f3d25"
wandb_project_name = "twilight_sparkle"
wandb_run_name = "Twilight_sparkle"

# !wandb login ${wandb_api_key}
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# TODO(oktai15): remove +model.text_tokenizer.add_blank_at=true when we update FastPitch checkpoint
! (python fastpitch_finetune.py --config-name=fastpitch_align_v1.05.yaml \
  train_dataset=fastpitch_train.json \
  validation_datasets=fastpitch_val.json \
  sup_data_path=fastpitch_sup_data \
  phoneme_dict_path=tts_dataset_files/cmudict-0.7b_nv22.07 \
  heteronyms_path=tts_dataset_files/heteronyms-030921 \
  whitelist_path=tts_dataset_files/lj_speech.tsv \
  exp_manager.exp_dir=training_logs2 \
  +init_from_nemo_model=tts_en_fastpitch_align.nemo \
  trainer.max_epochs=300 ~trainer.max_epochs \
  trainer.check_val_every_n_epoch=7 \
  model.train_ds.dataloader_params.batch_size=8 model.validation_ds.dataloader_params.batch_size=8 \
  model.n_speakers=1 model.pitch_mean=319.86 model.pitch_std=122.54 \
  model.pitch_fmin=65.41 model.pitch_fmax=2068.96 model.optim.lr=2e-4 \
  ~model.optim.sched model.optim.name=adam trainer.devices=1 trainer.strategy=null \
  +model.text_tokenizer.add_blank_at=true \
)
# Out:
# [NeMo W 2022-07-09 19:40:51 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-07-09 19:40:52 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# Using 16bit native Automatic Mixed Precision (AMP)
# [NeMo W 2022-07-09 19:40:53 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#       category=PossibleUserWarning,
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-07-09 19:40:53 exp_manager:287] Experiments will be logged at training_logs2/FastPitch/2022-07-09_19-40-53
# [NeMo I 2022-07-09 19:40:53 exp_manager:661] TensorboardLogger has been set up
# [NeMo W 2022-07-09 19:40:53 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo I 2022-07-09 19:40:56 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-09 19:41:18 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-07-09 19:41:19 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# Created a temporary directory at /tmp/tmppk9ov_cy
# Writing /tmp/tmppk9ov_cy/_remote_module_non_sriptable.py
# [NeMo I 2022-07-09 19:41:19 data:186] Loading dataset from fastpitch_train.json.
# 3316it [00:34, 95.66it/s]
# [NeMo I 2022-07-09 19:41:54 data:221] Loaded dataset with 3316 files.
# [NeMo I 2022-07-09 19:41:54 data:223] Dataset contains 2.17 hours.
# [NeMo I 2022-07-09 19:41:54 data:321] Pruned 0 files. Final dataset contains 3316 files
# [NeMo I 2022-07-09 19:41:54 data:324] Pruned 0.00 hours. Final dataset contains 2.17 hours.
# [NeMo W 2022-07-09 19:41:54 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# [NeMo I 2022-07-09 19:41:54 data:186] Loading dataset from fastpitch_val.json.
# 175it [00:01, 94.50it/s]
# [NeMo I 2022-07-09 19:41:56 data:221] Loaded dataset with 175 files.
# [NeMo I 2022-07-09 19:41:56 data:223] Dataset contains 0.11 hours.
# [NeMo I 2022-07-09 19:41:56 data:321] Pruned 0 files. Final dataset contains 175 files
# [NeMo I 2022-07-09 19:41:56 data:324] Pruned 0.00 hours. Final dataset contains 0.11 hours.
# [NeMo I 2022-07-09 19:41:56 features:200] PADDING: 1
# [NeMo I 2022-07-09 19:41:59 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-09 19:42:23 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-09 19:42:23 modelPT:150] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-07-09 19:42:23 modelPT:157] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
#
# [NeMo I 2022-07-09 19:42:23 features:200] PADDING: 1
# [NeMo I 2022-07-09 19:42:24 save_restore_connector:243] Model FastPitchModel was successfully restored from /content/tts_en_fastpitch_align.nemo.
# [NeMo I 2022-07-09 19:42:24 modelPT:1041] Model checkpoint restored from nemo file with path : `tts_en_fastpitch_align.nemo`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2022-07-09 19:42:27 modelPT:585] Optimizer config = Adam (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.999]
#         eps: 1e-08
#         lr: 0.0002
#         maximize: False
#         weight_decay: 1e-06
#     )
# [NeMo I 2022-07-09 19:42:27 lr_scheduler:699] Scheduler not initialized as no `sched` config supplied to setup_optimizer()
#
#   | Name             | Type                              | Params
# -----------------------------------------------------------------------
# 0 | mel_loss         | MelLoss                           | 0
# 1 | pitch_loss       | PitchLoss                         | 0
# 2 | duration_loss    | DurationLoss                      | 0
# 3 | aligner          | AlignmentEncoder                  | 1.0 M
# 4 | forward_sum_loss | ForwardSumLoss                    | 0
# 5 | bin_loss         | BinLoss                           | 0
# 6 | preprocessor     | AudioToMelSpectrogramPreprocessor | 0
# 7 | fastpitch        | FastPitchModule                   | 45.8 M
# -----------------------------------------------------------------------
# 45.8 M    Trainable params
# 0         Non-trainable params
# 45.8 M    Total params
# 91.518    Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s][NeMo W 2022-07-09 19:43:14 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#       warnings.warn(problem)
#
# Epoch 0:   0% 0/415 [00:00<?, ?it/s] [NeMo W 2022-07-09 19:43:17 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# Epoch 6:  92% 400/437 [02:17<00:12,  2.91it/s, loss=3.55, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 6:  96% 420/437 [02:41<00:06,  2.61it/s, loss=3.55, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:21<00:02,  1.07s/it]
# Validation DataLoader 0:  91% 20/22 [00:21<00:02,  1.07s/it]
# Epoch 6: 100% 437/437 [02:45<00:00,  2.63it/s, loss=3.48, v_num=0-53]
#                                                             Epoch 6, global step 2905: 'v_loss' reached 1.29510 (best 1.29510), saving model to '/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.2951-epoch=6.ckpt' as top 3
# Epoch 13:  92% 400/437 [02:17<00:12,  2.90it/s, loss=3.34, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 13:  96% 420/437 [02:24<00:05,  2.90it/s, loss=3.34, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.89it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.89it/s]
# Epoch 13: 100% 437/437 [02:30<00:00,  2.91it/s, loss=3.2, v_num=0-53]
#                                                             Epoch 13, global step 5810: 'v_loss' reached 1.16866 (best 1.16866), saving model to '/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.1687-epoch=13.ckpt' as top 3
# Epoch 20:  92% 400/437 [02:18<00:12,  2.88it/s, loss=3.03, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 20:  96% 420/437 [02:26<00:05,  2.86it/s, loss=3.03, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Epoch 20: 100% 437/437 [02:32<00:00,  2.87it/s, loss=2.97, v_num=0-53]
#                                                             Epoch 20, global step 8715: 'v_loss' reached 1.15237 (best 1.15237), saving model to '/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.1524-epoch=20.ckpt' as top 3
# Epoch 27:  92% 400/437 [02:16<00:12,  2.92it/s, loss=2.97, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 27:  96% 420/437 [02:24<00:05,  2.92it/s, loss=2.97, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.82it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.82it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.25it/s]
# Epoch 27: 100% 437/437 [02:29<00:00,  2.93it/s, loss=2.93, v_num=0-53]
#                                                             Epoch 27, global step 11620: 'v_loss' reached 1.16232 (best 1.15237), saving model to '/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.1623-epoch=27.ckpt' as top 3
# Epoch 34:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.93, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 34:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.93, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.83it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.83it/s]
# Epoch 34: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.83, v_num=0-53]
#                                                             Epoch 34, global step 14525: 'v_loss' was not in top 3
# Epoch 41:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.8, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 41:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.8, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Epoch 41: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.87, v_num=0-53]
#                                                             Epoch 41, global step 17430: 'v_loss' was not in top 3
# Epoch 48:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.86, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 48:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.86, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.71it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.71it/s]
# Epoch 48: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.84, v_num=0-53]
#                                                             Epoch 48, global step 20335: 'v_loss' reached 1.14553 (best 1.14553), saving model to '/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.1455-epoch=48.ckpt' as top 3
# Epoch 55:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.81, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 55:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.81, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.78it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.78it/s]
# Epoch 55: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.8, v_num=0-53]
#                                                             Epoch 55, global step 23240: 'v_loss' reached 1.15730 (best 1.14553), saving model to '/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.1573-epoch=55.ckpt' as top 3
# Epoch 62:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.75, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 62:  96% 420/437 [02:25<00:05,  2.90it/s, loss=2.75, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.79it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.79it/s]
# Epoch 62: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.69, v_num=0-53]
#                                                             Epoch 62, global step 26145: 'v_loss' was not in top 3
# Epoch 69:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.91, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 69:  96% 420/437 [02:25<00:05,  2.88it/s, loss=2.91, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.69it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.69it/s]
# Epoch 69: 100% 437/437 [02:31<00:00,  2.89it/s, loss=2.89, v_num=0-53]
#                                                             Epoch 69, global step 29050: 'v_loss' was not in top 3
# Epoch 76:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.83, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 76:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.83, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.71it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.71it/s]
# Epoch 76: 100% 437/437 [02:30<00:00,  2.89it/s, loss=2.8, v_num=0-53]
#                                                             Epoch 76, global step 31955: 'v_loss' was not in top 3
# Epoch 83:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.88, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 83:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.88, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.63it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.63it/s]
# Epoch 83: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.8, v_num=0-53]
#                                                             Epoch 83, global step 34860: 'v_loss' was not in top 3
# Epoch 90:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.79, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 90:  96% 420/437 [02:25<00:05,  2.90it/s, loss=2.79, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.88it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.88it/s]
# Epoch 90: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.87, v_num=0-53]
#                                                             Epoch 90, global step 37765: 'v_loss' was not in top 3
# Epoch 97:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.76, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 97:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.76, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.15it/s]
# Epoch 97: 100% 437/437 [02:30<00:00,  2.89it/s, loss=2.69, v_num=0-53]
#                                                             Epoch 97, global step 40670: 'v_loss' was not in top 3
# Epoch 104:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.7, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 104:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.7, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.84it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.84it/s]
# Epoch 104: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.69, v_num=0-53]
#                                                             Epoch 104, global step 43575: 'v_loss' was not in top 3
# Epoch 111:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.64, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 111:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.64, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.15it/s]
# Epoch 111: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.72, v_num=0-53]
#                                                             Epoch 111, global step 46480: 'v_loss' was not in top 3
# Epoch 118:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.67, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 118:  96% 420/437 [02:26<00:05,  2.86it/s, loss=2.67, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.74it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.74it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.16it/s]
# Epoch 118: 100% 437/437 [02:32<00:00,  2.87it/s, loss=2.69, v_num=0-53]
#                                                             Epoch 118, global step 49385: 'v_loss' was not in top 3
# Epoch 125:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.61, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 125:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.61, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Epoch 125: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.73, v_num=0-53]
#                                                             Epoch 125, global step 52290: 'v_loss' was not in top 3
# Epoch 132:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.69, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 132:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.69, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.86it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.86it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.28it/s]
# Epoch 132: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.61, v_num=0-53]
#                                                             Epoch 132, global step 55195: 'v_loss' was not in top 3
# Epoch 139:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.72, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 139:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.72, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Epoch 139: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.69, v_num=0-53]
#                                                             Epoch 139, global step 58100: 'v_loss' was not in top 3
# Epoch 146:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.67, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 146:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.67, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.64it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.64it/s]
# Epoch 146: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.7, v_num=0-53]
#                                                             Epoch 146, global step 61005: 'v_loss' was not in top 3
# Epoch 153:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.63, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 153:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.63, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.70it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.70it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.12it/s]
# Epoch 153: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.7, v_num=0-53]
#                                                             Epoch 153, global step 63910: 'v_loss' was not in top 3
# Epoch 160:  92% 400/437 [02:17<00:12,  2.92it/s, loss=2.66, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 160:  96% 420/437 [02:24<00:05,  2.91it/s, loss=2.66, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.95it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.95it/s]
# Epoch 160: 100% 437/437 [02:29<00:00,  2.92it/s, loss=2.69, v_num=0-53]
#                                                             Epoch 160, global step 66815: 'v_loss' was not in top 3
# Epoch 167:  92% 400/437 [02:18<00:12,  2.88it/s, loss=2.67, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 167:  96% 420/437 [02:26<00:05,  2.86it/s, loss=2.67, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Epoch 167: 100% 437/437 [02:32<00:00,  2.87it/s, loss=2.61, v_num=0-53]
#                                                             Epoch 167, global step 69720: 'v_loss' was not in top 3
# Epoch 174:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.57, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 174:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.57, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.75it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.75it/s]
# Epoch 174: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.46, v_num=0-53]
#                                                             Epoch 174, global step 72625: 'v_loss' was not in top 3
# Epoch 181:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.49, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 181:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.49, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.72it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.72it/s]
# Epoch 181: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.5, v_num=0-53]
#                                                             Epoch 181, global step 75530: 'v_loss' was not in top 3
# Epoch 188:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.56, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 188:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.56, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.83it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.83it/s]
# Epoch 188: 100% 437/437 [02:29<00:00,  2.92it/s, loss=2.46, v_num=0-53]
#                                                             Epoch 188, global step 78435: 'v_loss' was not in top 3
# Epoch 195:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.59, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 195:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.59, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.96it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.96it/s]
# Epoch 195: 100% 437/437 [02:29<00:00,  2.92it/s, loss=2.61, v_num=0-53]
#                                                             Epoch 195, global step 81340: 'v_loss' was not in top 3
# Epoch 202:  92% 400/437 [02:18<00:12,  2.90it/s, loss=2.49, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 202:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.49, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Epoch 202: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.45, v_num=0-53]
#                                                             Epoch 202, global step 84245: 'v_loss' was not in top 3
# Epoch 209:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.53, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 209:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.53, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.87it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.87it/s]
# Epoch 209: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.45, v_num=0-53]
#                                                             Epoch 209, global step 87150: 'v_loss' was not in top 3
# Epoch 216:  92% 400/437 [02:19<00:12,  2.87it/s, loss=2.57, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 216:  96% 420/437 [02:27<00:05,  2.84it/s, loss=2.57, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.78it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.78it/s]
# Epoch 216: 100% 437/437 [02:33<00:00,  2.85it/s, loss=2.46, v_num=0-53]
#                                                             Epoch 216, global step 90055: 'v_loss' was not in top 3
# Epoch 223:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.5, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 223:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.5, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.82it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.82it/s]
# Epoch 223: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.55, v_num=0-53]
#                                                             Epoch 223, global step 92960: 'v_loss' was not in top 3
# Epoch 230:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.51, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 230:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.51, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Epoch 230: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.52, v_num=0-53]
#                                                             Epoch 230, global step 95865: 'v_loss' was not in top 3
# Epoch 237:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.54, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 237:  96% 420/437 [02:25<00:05,  2.90it/s, loss=2.54, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Epoch 237: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.52, v_num=0-53]
#                                                             Epoch 237, global step 98770: 'v_loss' was not in top 3
# Epoch 244:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.58, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 244:  96% 420/437 [02:25<00:05,  2.90it/s, loss=2.58, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Epoch 244: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.5, v_num=0-53]
#                                                             Epoch 244, global step 101675: 'v_loss' was not in top 3
# Epoch 251:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.56, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 251:  96% 420/437 [02:25<00:05,  2.88it/s, loss=2.56, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.72it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.72it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.14it/s]
# Epoch 251: 100% 437/437 [02:31<00:00,  2.89it/s, loss=2.55, v_num=0-53]
#                                                             Epoch 251, global step 104580: 'v_loss' was not in top 3
# Epoch 258:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.46, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 258:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.46, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.62it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.62it/s]
# Epoch 258: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.49, v_num=0-53]
#                                                             Epoch 258, global step 107485: 'v_loss' was not in top 3
# Epoch 265:  92% 400/437 [02:19<00:12,  2.88it/s, loss=2.56, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 265:  96% 420/437 [02:27<00:05,  2.85it/s, loss=2.56, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  4.00it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  4.00it/s]
# Epoch 265: 100% 437/437 [02:32<00:00,  2.86it/s, loss=2.5, v_num=0-53]
#                                                             Epoch 265, global step 110390: 'v_loss' was not in top 3
# Epoch 272:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.53, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 272:  96% 420/437 [02:25<00:05,  2.90it/s, loss=2.53, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.18it/s]
# Epoch 272: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.52, v_num=0-53]
#                                                             Epoch 272, global step 113295: 'v_loss' was not in top 3
# Epoch 279:  92% 400/437 [02:18<00:12,  2.88it/s, loss=2.52, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 279:  96% 420/437 [02:26<00:05,  2.87it/s, loss=2.52, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.75it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.75it/s]
# Epoch 279: 100% 437/437 [02:31<00:00,  2.88it/s, loss=2.47, v_num=0-53]
#                                                             Epoch 279, global step 116200: 'v_loss' was not in top 3
# Epoch 286:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.52, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 286:  96% 420/437 [02:24<00:05,  2.90it/s, loss=2.52, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.72it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.72it/s]
# Epoch 286: 100% 437/437 [02:30<00:00,  2.91it/s, loss=2.35, v_num=0-53]
#                                                             Epoch 286, global step 119105: 'v_loss' was not in top 3
# Epoch 293:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.47, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 293:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.47, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.81it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.81it/s]
# Epoch 293: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.42, v_num=0-53]
#                                                             Epoch 293, global step 122010: 'v_loss' was not in top 3
# Epoch 300:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.46, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 300:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.46, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.65it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.65it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.07it/s]
# Epoch 300: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.62, v_num=0-53]
#                                                             Epoch 300, global step 124915: 'v_loss' was not in top 3
# Epoch 307:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.44, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 307:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.44, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.74it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.74it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.16it/s]
# Epoch 307: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.43, v_num=0-53]
#                                                             Epoch 307, global step 127820: 'v_loss' was not in top 3
# Epoch 314:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.45, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 314:  96% 420/437 [02:26<00:05,  2.86it/s, loss=2.45, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.75it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.75it/s]
# Epoch 314: 100% 437/437 [02:32<00:00,  2.86it/s, loss=2.52, v_num=0-53]
#                                                             Epoch 314, global step 130725: 'v_loss' was not in top 3
# Epoch 321:  92% 400/437 [02:17<00:12,  2.91it/s, loss=2.58, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 321:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.58, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.61it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.61it/s]
# Epoch 321: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.51, v_num=0-53]
#                                                             Epoch 321, global step 133630: 'v_loss' was not in top 3
# Epoch 328:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.52, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 328:  96% 420/437 [02:25<00:05,  2.90it/s, loss=2.52, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Epoch 328: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.44, v_num=0-53]
#                                                             Epoch 328, global step 136535: 'v_loss' was not in top 3
# Epoch 335:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.43, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 335:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.43, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Epoch 335: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.34, v_num=0-53]
#                                                             Epoch 335, global step 139440: 'v_loss' was not in top 3
# Epoch 342:  92% 400/437 [02:17<00:12,  2.90it/s, loss=2.5, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 342:  96% 420/437 [02:25<00:05,  2.89it/s, loss=2.5, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Epoch 342: 100% 437/437 [02:30<00:00,  2.90it/s, loss=2.5, v_num=0-53]
#                                                             Epoch 342, global step 142345: 'v_loss' was not in top 3
# Epoch 349:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.43, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 349:  96% 420/437 [02:25<00:05,  2.88it/s, loss=2.43, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.73it/s]
# Epoch 349: 100% 437/437 [02:31<00:00,  2.89it/s, loss=2.54, v_num=0-53]
#                                                             Epoch 349, global step 145250: 'v_loss' was not in top 3
# Epoch 356:  92% 400/437 [02:18<00:12,  2.89it/s, loss=2.5, v_num=0-53]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 356:  96% 420/437 [02:25<00:05,  2.88it/s, loss=2.5, v_num=0-53]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.76it/s]
# Epoch 356: 100% 437/437 [02:30<00:00,  2.89it/s, loss=2.52, v_num=0-53]
#                                                             Epoch 356, global step 148155: 'v_loss' was not in top 3
# Epoch 361:   0% 0/415 [00:00<?, ?it/s, loss=2.36, v_num=0-53][NeMo W 2022-07-10 10:30:49 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:726: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#       rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
# %ls /home/deepankaracharyya/Disk2/Twilight_sparkle/training_logs/FastPitch/2022-06-20_17-00-59/checkpoints/
# Out:
# FastPitch.nemo
# FastPitch--v_loss=1.8499-epoch=15.ckpt
# FastPitch--v_loss=1.8572-epoch=12.ckpt
# FastPitch--v_loss=1.8701-epoch=17.ckpt
# FastPitch--v_loss=1.8701-epoch=18-last.ckpt

# %%
#imports
import os
import json
import librosa

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

from nemo.collections.tts.models import FastPitchModel
from nemo.collections.tts.models import HifiGanModel
from nemo.collections.tts.torch.helpers import BetaBinomialInterpolator
import soundfile as sf
import numpy as np

# %%
#helper functions
def infer(spec_gen_model, vocoder_model, str_input, speaker=None):
    """
    Synthesizes spectrogram and audio from a text string given a spectrogram synthesis and vocoder model.
    
    Args:
        spec_gen_model: Spectrogram generator model (FastPitch in our case)
        vocoder_model: Vocoder model (HiFiGAN in our case)
        str_input: Text input for the synthesis
        speaker: Speaker ID
    
    Returns:
        spectrogram and waveform of the synthesized audio.
    """
    with torch.no_grad():
        parsed = spec_gen_model.parse(str_input)
        if speaker is not None:
            speaker = torch.tensor([speaker]).long().to(device=spec_gen_model.device)
        spectrogram = spec_gen_model.generate_spectrogram(tokens=parsed, speaker=speaker)
        audio = vocoder_model.convert_spectrogram_to_audio(spec=spectrogram)
        
    if spectrogram is not None:
        if isinstance(spectrogram, torch.Tensor):
            spectrogram = spectrogram.to('cpu').numpy()
        if len(spectrogram.shape) == 3:
            spectrogram = spectrogram[0]
    if isinstance(audio, torch.Tensor):
        audio = audio.to('cpu').numpy()
    return spectrogram, audio

def custom_infer(transcript, spec_model, vocoder, download=None):
  spec, audio = infer(spec_model, vocoder, transcript)
  print("\n\n\n\n")
  ipd.display(ipd.Audio(audio, rate=22050))
  # %matplotlib inline
  plt.show()

def try_infering_with_finetuned_fastpitch(checkpointpath, sentence):
  spec_model = FastPitchModel.load_from_checkpoint(checkpointpath)
  spec_model.eval().cuda()

  vocoder = HifiGanModel.from_pretrained("tts_hifigan")
  vocoder = vocoder.eval().cuda()

  custom_infer(sentence, spec_model, vocoder)

# %%
checkpointpath = "/content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.2314-epoch=356-last.ckpt"

# %%
try_infering_with_finetuned_fastpitch(checkpointpath, "Trying out the model for the first time and I just cannot contain my excitement.")
# Out:
# [NeMo I 2022-07-10 10:31:45 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-10 10:32:10 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-10 10:32:10 modelPT:150] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.41
#       pitch_fmax: 2068.96
#       pitch_norm: true
#       pitch_mean: 319.86
#       pitch_std: 122.54
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 8
#       num_workers: 12
#       pin_memory: true
#
# [NeMo W 2022-07-10 10:32:10 modelPT:157] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.41
#       pitch_fmax: 2068.96
#       pitch_norm: true
#       pitch_mean: 319.86
#       pitch_std: 122.54
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 8
#       num_workers: 8
#       pin_memory: true
# [NeMo I 2022-07-10 10:32:10 features:200] PADDING: 1
# [NeMo I 2022-07-10 10:32:11 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/tts_hifigan/versions/1.0.0rc1/files/tts_hifigan.nemo to /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# [NeMo I 2022-07-10 10:32:23 common:789] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-07-10 10:32:27 modelPT:150] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-07-10 10:32:27 modelPT:157] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-07-10 10:32:27 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-07-10 10:32:27 features:200] PADDING: 0
# [NeMo W 2022-07-10 10:32:27 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-07-10 10:32:27 features:200] PADDING: 0
# [NeMo I 2022-07-10 10:32:28 save_restore_connector:243] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
spec_model = FastPitchModel.load_from_checkpoint(checkpointpath)
spec_model.eval().cuda()

vocoder = HifiGanModel.from_pretrained("tts_hifigan")
vocoder = vocoder.eval().cuda()

custom_infer("Hi Deepankar, how are you doing today ?", spec_model, vocoder)
# Out:
# [NeMo I 2022-07-10 10:34:48 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-10 10:35:14 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-10 10:35:14 modelPT:150] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.41
#       pitch_fmax: 2068.96
#       pitch_norm: true
#       pitch_mean: 319.86
#       pitch_std: 122.54
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 8
#       num_workers: 12
#       pin_memory: true
#
# [NeMo W 2022-07-10 10:35:14 modelPT:157] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.41
#       pitch_fmax: 2068.96
#       pitch_norm: true
#       pitch_mean: 319.86
#       pitch_std: 122.54
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 8
#       num_workers: 8
#       pin_memory: true
# [NeMo I 2022-07-10 10:35:14 features:200] PADDING: 1
# [NeMo I 2022-07-10 10:35:15 cloud:56] Found existing object /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# [NeMo I 2022-07-10 10:35:15 cloud:62] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# [NeMo I 2022-07-10 10:35:15 common:789] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-07-10 10:35:18 modelPT:150] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-07-10 10:35:18 modelPT:157] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-07-10 10:35:18 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-07-10 10:35:18 features:200] PADDING: 0
# [NeMo W 2022-07-10 10:35:18 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-07-10 10:35:18 features:200] PADDING: 0
# [NeMo I 2022-07-10 10:35:19 save_restore_connector:243] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
custom_infer("Is my voice approaching the threshold it is expected to reach ?", spec_model, vocoder)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp /content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.2314-epoch=356-last.ckpt -t /content/drive/MyDrive/TTS_finetuning/Twilight_sparkle

# %%
#! cp /content/training_logs2/FastPitch/2022-07-09_19-40-53/checkpoints/FastPitch--v_loss=1.2314-epoch=356-last.ckpt -t /content/
! mv ./FastPitch--v_loss=1.2314-epoch=356-last.ckpt  ./Fastpitch_epoch_356.ckpt

# %%
#resuming the training 
! (python fastpitch_finetune.py --config-name=fastpitch_align_v1.05.yaml \
  train_dataset=fastpitch_train.json \
  validation_datasets=fastpitch_val.json \
  sup_data_path=fastpitch_sup_data \
  phoneme_dict_path=tts_dataset_files/cmudict-0.7b_nv22.07 \
  heteronyms_path=tts_dataset_files/heteronyms-030921 \
  whitelist_path=tts_dataset_files/lj_speech.tsv \
  exp_manager.exp_dir=training_logs2 \
  +init_from_ptl_ckpt=Fastpitch_epoch_356.ckpt \
  trainer.max_epochs=300 ~trainer.max_epochs \
  trainer.check_val_every_n_epoch=7 \
  model.train_ds.dataloader_params.batch_size=8 model.validation_ds.dataloader_params.batch_size=8 \
  model.n_speakers=1 model.pitch_mean=319.86 model.pitch_std=122.54 \
  model.pitch_fmin=65.41 model.pitch_fmax=2068.96 model.optim.lr=2e-4 \
  +exp_manager.create_wandb_logger=true \
  +exp_manager.wandb_logger_kwargs.name=${wandb_run_name} \
  +exp_manager.wandb_logger_kwargs.project=${wandb_project_name} \
  ~model.optim.sched model.optim.name=adam trainer.devices=1 trainer.strategy=null \
  +model.text_tokenizer.add_blank_at=true \
)
# Out:
# [NeMo W 2022-07-10 11:03:20 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-07-10 11:03:21 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# Using 16bit native Automatic Mixed Precision (AMP)
# [NeMo W 2022-07-10 11:03:22 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#       category=PossibleUserWarning,
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-07-10 11:03:22 exp_manager:287] Experiments will be logged at training_logs2/FastPitch/2022-07-10_11-03-22
# [NeMo I 2022-07-10 11:03:22 exp_manager:661] TensorboardLogger has been set up
# wandb: Currently logged in as: convaitech. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in training_logs2/wandb/run-20220710_110323-2022-07-10_11-03-22
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run 2022-07-10_11-03-22
# wandb: ⭐️ View project at https://wandb.ai/convaitech/uncategorized
# wandb: 🚀 View run at https://wandb.ai/convaitech/uncategorized/runs/2022-07-10_11-03-22
# [NeMo I 2022-07-10 11:03:23 exp_manager:676] WandBLogger has been set up
# [NeMo W 2022-07-10 11:03:23 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loggers/base.py:236: LightningDeprecationWarning: `LoggerCollection` is deprecated in v1.6 and will be removed in v1.8. Directly pass a list of loggers to the Trainer and access the list via the `trainer.loggers` attribute.
#       "`LoggerCollection` is deprecated in v1.6 and will be removed in v1.8. Directly pass a list of loggers"
#
# [NeMo W 2022-07-10 11:03:23 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo I 2022-07-10 11:03:26 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-10 11:03:49 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-07-10 11:03:50 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# Created a temporary directory at /tmp/tmpv0o84o5e
# Writing /tmp/tmpv0o84o5e/_remote_module_non_sriptable.py
# [NeMo I 2022-07-10 11:03:50 data:186] Loading dataset from fastpitch_train.json.
# 3316it [00:36, 90.36it/s]
# [NeMo I 2022-07-10 11:04:27 data:221] Loaded dataset with 3316 files.
# [NeMo I 2022-07-10 11:04:27 data:223] Dataset contains 2.17 hours.
# [NeMo I 2022-07-10 11:04:27 data:321] Pruned 0 files. Final dataset contains 3316 files
# [NeMo I 2022-07-10 11:04:27 data:324] Pruned 0.00 hours. Final dataset contains 2.17 hours.
# [NeMo W 2022-07-10 11:04:27 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# [NeMo I 2022-07-10 11:04:27 data:186] Loading dataset from fastpitch_val.json.
# 175it [00:01, 88.90it/s]
# [NeMo I 2022-07-10 11:04:29 data:221] Loaded dataset with 175 files.
# [NeMo I 2022-07-10 11:04:29 data:223] Dataset contains 0.11 hours.
# [NeMo I 2022-07-10 11:04:29 data:321] Pruned 0 files. Final dataset contains 175 files
# [NeMo I 2022-07-10 11:04:29 data:324] Pruned 0.00 hours. Final dataset contains 0.11 hours.
# [NeMo I 2022-07-10 11:04:29 features:200] PADDING: 1
# [NeMo I 2022-07-10 11:04:30 modelPT:1125] Model checkpoint restored from pytorch lightning chackpoint with path : `Fastpitch_epoch_356.ckpt`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2022-07-10 11:04:33 modelPT:585] Optimizer config = Adam (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.999]
#         eps: 1e-08
#         lr: 0.0002
#         maximize: False
#         weight_decay: 1e-06
#     )
# [NeMo I 2022-07-10 11:04:33 lr_scheduler:699] Scheduler not initialized as no `sched` config supplied to setup_optimizer()
#
#   | Name             | Type                              | Params
# -----------------------------------------------------------------------
# 0 | mel_loss         | MelLoss                           | 0
# 1 | pitch_loss       | PitchLoss                         | 0
# 2 | duration_loss    | DurationLoss                      | 0
# 3 | aligner          | AlignmentEncoder                  | 1.0 M
# 4 | forward_sum_loss | ForwardSumLoss                    | 0
# 5 | bin_loss         | BinLoss                           | 0
# 6 | preprocessor     | AudioToMelSpectrogramPreprocessor | 0
# 7 | fastpitch        | FastPitchModule                   | 45.8 M
# -----------------------------------------------------------------------
# 45.8 M    Trainable params
# 0         Non-trainable params
# 45.8 M    Total params
# 91.518    Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0% 0/2 [00:00<?, ?it/s][NeMo W 2022-07-10 11:04:43 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#       warnings.warn(problem)
#
# Epoch 0:   0% 0/415 [00:00<?, ?it/s] [NeMo W 2022-07-10 11:04:44 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# Epoch 6:  92% 400/437 [02:18<00:12,  2.88it/s, loss=2.2, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 6:  96% 420/437 [02:26<00:05,  2.86it/s, loss=2.2, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.63it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.63it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.04it/s]
# Epoch 6: 100% 437/437 [02:31<00:00,  2.88it/s, loss=2.22, v_num=3-22]
#                                                             Epoch 6, global step 2905: 'v_loss' reached 1.25220 (best 1.25220), saving model to '/content/training_logs2/FastPitch/2022-07-10_11-03-22/checkpoints/FastPitch--v_loss=1.2522-epoch=6.ckpt' as top 3
# Epoch 13:  92% 400/437 [02:22<00:13,  2.80it/s, loss=2.24, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 13:  96% 420/437 [02:30<00:06,  2.78it/s, loss=2.24, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.65it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.65it/s]
# Epoch 13: 100% 437/437 [02:36<00:00,  2.80it/s, loss=2.29, v_num=3-22]
#                                                             Epoch 13, global step 5810: 'v_loss' reached 1.23349 (best 1.23349), saving model to '/content/training_logs2/FastPitch/2022-07-10_11-03-22/checkpoints/FastPitch--v_loss=1.2335-epoch=13.ckpt' as top 3
# Epoch 20:  92% 400/437 [02:24<00:13,  2.77it/s, loss=2.24, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 20:  96% 420/437 [02:31<00:06,  2.76it/s, loss=2.24, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.59it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.59it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.00it/s]
# Epoch 20: 100% 437/437 [02:37<00:00,  2.78it/s, loss=2.17, v_num=3-22]
#                                                             Epoch 20, global step 8715: 'v_loss' reached 1.23363 (best 1.23349), saving model to '/content/training_logs2/FastPitch/2022-07-10_11-03-22/checkpoints/FastPitch--v_loss=1.2336-epoch=20.ckpt' as top 3
# Epoch 27:  92% 400/437 [02:22<00:13,  2.81it/s, loss=2.26, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 27:  96% 420/437 [02:30<00:06,  2.80it/s, loss=2.26, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.67it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.67it/s]
# Epoch 27: 100% 437/437 [02:35<00:00,  2.81it/s, loss=2.24, v_num=3-22]
#                                                             Epoch 27, global step 11620: 'v_loss' reached 1.22757 (best 1.22757), saving model to '/content/training_logs2/FastPitch/2022-07-10_11-03-22/checkpoints/FastPitch--v_loss=1.2276-epoch=27.ckpt' as top 3
# Epoch 34:  92% 400/437 [02:20<00:13,  2.84it/s, loss=2.25, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 34:  96% 420/437 [02:28<00:05,  2.84it/s, loss=2.25, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.66it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.07it/s]
# Epoch 34: 100% 437/437 [02:33<00:00,  2.85it/s, loss=2.34, v_num=3-22]
#                                                             Epoch 34, global step 14525: 'v_loss' was not in top 3
# Epoch 41:  92% 400/437 [02:21<00:13,  2.83it/s, loss=2.26, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 41:  96% 420/437 [02:28<00:06,  2.82it/s, loss=2.26, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.64it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.64it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.05it/s]
# Epoch 41: 100% 437/437 [02:34<00:00,  2.84it/s, loss=2.25, v_num=3-22]
#                                                             Epoch 41, global step 17430: 'v_loss' was not in top 3
# Epoch 48:  92% 400/437 [02:22<00:13,  2.80it/s, loss=2.38, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 48:  96% 420/437 [02:30<00:06,  2.79it/s, loss=2.38, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.68it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.10it/s]
# Epoch 48: 100% 437/437 [02:35<00:00,  2.81it/s, loss=2.34, v_num=3-22]
#                                                             Epoch 48, global step 20335: 'v_loss' was not in top 3
# Epoch 55:  92% 400/437 [02:22<00:13,  2.80it/s, loss=2.48, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 55:  96% 420/437 [02:30<00:06,  2.80it/s, loss=2.48, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.48it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.48it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  3.87it/s]
# Epoch 55: 100% 437/437 [02:35<00:00,  2.81it/s, loss=2.37, v_num=3-22]
#                                                             Epoch 55, global step 23240: 'v_loss' was not in top 3
# Epoch 62:  92% 400/437 [02:22<00:13,  2.81it/s, loss=2.33, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 62:  96% 420/437 [02:29<00:06,  2.80it/s, loss=2.33, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.62it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.62it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.04it/s]
# Epoch 62: 100% 437/437 [02:34<00:00,  2.82it/s, loss=2.38, v_num=3-22]
#                                                             Epoch 62, global step 26145: 'v_loss' was not in top 3
# Epoch 69:  92% 400/437 [02:22<00:13,  2.81it/s, loss=2.37, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 69:  96% 420/437 [02:30<00:06,  2.80it/s, loss=2.37, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.60it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.60it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  4.01it/s]
# Epoch 69: 100% 437/437 [02:35<00:00,  2.81it/s, loss=2.32, v_num=3-22]
#                                                             Epoch 69, global step 29050: 'v_loss' was not in top 3
# Epoch 76:  92% 400/437 [02:21<00:13,  2.83it/s, loss=2.35, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 76:  96% 420/437 [02:28<00:06,  2.82it/s, loss=2.35, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.60it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3
/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  3.89it/s]
# Epoch 139: 100% 437/437 [02:37<00:00,  2.77it/s, loss=2.44, v_num=3-22]
#                                                             Epoch 139, global step 58100: 'v_loss' was not in top 3
# Epoch 146:  92% 400/437 [02:24<00:13,  2.78it/s, loss=2.38, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 146:  96% 420/437 [02:31<00:06,  2.77it/s, loss=2.38, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.53it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.53it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  3.93it/s]
# Epoch 146: 100% 437/437 [02:36<00:00,  2.79it/s, loss=2.4, v_num=3-22]
#                                                             Epoch 146, global step 61005: 'v_loss' was not in top 3
# Epoch 153:  92% 400/437 [02:24<00:13,  2.76it/s, loss=2.49, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 153:  96% 420/437 [02:32<00:06,  2.75it/s, loss=2.49, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.54it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.54it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  3.94it/s]
# Epoch 153: 100% 437/437 [02:38<00:00,  2.76it/s, loss=2.39, v_num=3-22]
#                                                             Epoch 153, global step 63910: 'v_loss' was not in top 3
# Epoch 160:  92% 400/437 [02:24<00:13,  2.77it/s, loss=2.36, v_num=3-22]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/22 [00:00<?, ?it/s]
# Epoch 160:  96% 420/437 [02:31<00:06,  2.77it/s, loss=2.36, v_num=3-22]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.50it/s]
# Validation DataLoader 0:  91% 20/22 [00:05<00:00,  3.50it/s]
# Validation DataLoader 0: 100% 22/22 [00:05<00:00,  3.90it/s]
# Epoch 160: 100% 437/437 [02:37<00:00,  2.78it/s, loss=2.31, v_num=3-22]
#                                                             Epoch 160, global step 66815: 'v_loss' was not in top 3
# Epoch 164:  82% 340/415 [02:04<00:27,  2.72it/s, loss=2.42, v_num=3-22]

# %% [markdown]
# ## Preparing the data for HiFiGAN finetuning

# %%
#helper functions
def load_wav(audio_file, target_sr=None):
    with sf.SoundFile(audio_file, 'r') as f:
        samples = f.read(dtype='float32')
        sample_rate = f.samplerate
        if target_sr is not None and target_sr != sample_rate:
            samples = librosa.core.resample(samples, orig_sr=sample_rate, target_sr=target_sr)
    return samples.transpose()

# %%
#dataset preparation
# Get records from the training manifest
manifest_path = "./fastpitch_train.json"
records = []
with open(manifest_path, "r") as f:
    for i, line in enumerate(f):
        records.append(json.loads(line))

beta_binomial_interpolator = BetaBinomialInterpolator()
spec_model.eval()

device = spec_model.device

save_dir = Path("./train_mels")
save_dir.mkdir(exist_ok=True, parents=True)

# Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
for i, r in enumerate(records):
    audio = load_wav(r["audio_filepath"])
    audio = torch.from_numpy(audio).unsqueeze(0).to(device)
    audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)
    
        
    with torch.no_grad():
        if "normalized_text" in r:
            text = spec_model.parse(r["normalized_text"], normalize=False)
        else:
            text = spec_model.parse(r['text'])
        
        text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)
    
        spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

        # Generate attention prior and spectrogram inputs for HiFi-GAN
        attn_prior = torch.from_numpy(
          beta_binomial_interpolator(spect_len.item(), text_len.item())
        ).unsqueeze(0).to(text.device)
            
        spectrogram = spec_model.forward(
          text=text, 
          input_lens=text_len, 
          spec=spect, 
          mel_lens=spect_len, 
          attn_prior=attn_prior,
        )[0]
        
        save_path = save_dir / f"mel_{i}.npy"
        np.save(save_path, spectrogram[0].to('cpu').numpy())
        r["mel_filepath"] = str(save_path)

hifigan_manifest_path = "hifigan_train_ft.json"
with open(hifigan_manifest_path, "w") as f:
    for r in records:
        f.write(json.dumps(r) + '\n')
# Out:
# [NeMo W 2022-06-20 18:28:56 tts_tokenizers:357] Text: [HHEY1, !] contains unknown char/phoneme: []. Original text: [Hey, cerberus!]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:07 tts_tokenizers:357] Text: [GREY1T AY0DIY1AH0 PIH1NGKIY0, we'll be HHAE1PIY0 to HHEH1LP the .] contains unknown char/phoneme: []. Original text: [Great idea pinkie, We'll be happy to help the yaks.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:07 tts_tokenizers:357] Text: [without DHOW1Z  and the MAE1JHIH0K YUW1 BRAO1T HHIY1R from IH0KWEH0STRIY0AH0, DHEH1R just THRIY1 HHAA1RMLAH0S TIY1NEY2JH GER1LZ.] contains unknown char/phoneme: []. Original text: [Without those pendants and the magic you brought here from Equestria, they're just three harmless teenage girls.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:09 tts_tokenizers:357] Text: [AY1 haven't STAH1DIY0D IY1STER0N  as MAH1CH as AY1 SHUH1DAH0V.] contains unknown char/phoneme: []. Original text: [I haven't studied eastern unicorns as much as i should've.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:10 tts_tokenizers:357] Text: [BAY1 , AY1 THIH1NGK AY1V GAA1T it.] contains unknown char/phoneme: []. Original text: [By Jove, I think I've got it.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:29 tts_tokenizers:357] Text: [YUW1 NOW1, WIY1 STIH1L don't NOW1 a lot AH0BAW1T the .] contains unknown char/phoneme: []. Original text: [You know, we still don't know a lot about the yaks.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:41 tts_tokenizers:357] Text: [AY1 KUH1D SEH1ND her to the KRIH1STAH0L EH1MPAY0ER0 to KAH0NTIH1NYUW0 her MAE1JHIH0KAH0L STAH1DIY0Z with !] contains unknown char/phoneme: []. Original text: [I could send her to the crystal empire To continue her magical studies with sunburst!]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:44 tts_tokenizers:357] Text: [THAE1NGKS again for LEH1TIH0NG us KAH1M and get  KIY1 PRIH1NSAH0PAH0L SAH0LEH0STIY0AH0.] contains unknown char/phoneme: []. Original text: [Thanks again for letting us come and get Sunset's key Principal Celestia.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:45 tts_tokenizers:357] Text: [DHEY1 KUH1D CHAE1LAH0NJH IY1CH AH1DHER0 into BIH0KAH1MIH0NG the most talented  IH0KWEH0STRIY0AH0Z EH1VER0 SIY1N!] contains unknown char/phoneme: []. Original text: [They could challenge each other into becoming The most talented unicorns equestria's ever seen!]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:46 tts_tokenizers:357] Text: [, next SLAY1D please.] contains unknown char/phoneme: []. Original text: [Ahem, next slide please.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:48 tts_tokenizers:357] Text: [AY1 was SOW1 intrigued BAY1  BRAE1GIH0NG that AY1 was KAH0MPEH1LD to do a LIH1TAH0L reading AH1P on them.] contains unknown char/phoneme: []. Original text: [I was so intrigued by Trixie's bragging that I was compelled to do a little reading up on them.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:29:55 tts_tokenizers:357] Text: [SIH1NS YUW1 AA1BVIY0AH0SLIY0 NOW1 that  WAO1RMIH0NG is AH0BAW1T KAH1MIH0NG TAH0GEH1DHER0.] contains unknown char/phoneme: []. Original text: [Since you obviously know that hearth's warming Is about coming together.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:30
. Symbol will be skipped.
# [NeMo W 2022-06-20 18:36:22 tts_tokenizers:357] Text: [LUH1K , AY1 RIY1AH0LAY2Z AY1 MEY1 HHAE1V been a LIH1TAH0L AO1F ER1LIY0ER0, BAH1T i'm really good AE1T this GEY1M.] contains unknown char/phoneme: []. Original text: [look sunburst, i realize i may have been a little off earlier, but i'm really good at this game.]. Symbol will be skipped.

# %%
# Get records from the training manifest
manifest_path_validation = "./fastpitch_val.json"
records_val = []
with open(manifest_path_validation, "r") as f:
    for i, line in enumerate(f):
        records_val.append(json.loads(line))

save_dir_val = Path("./dev_mels")
save_dir_val.mkdir(exist_ok=True, parents=True)

# Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
for i, r in enumerate(records_val):
    audio = load_wav(r["audio_filepath"])
    audio = torch.from_numpy(audio).unsqueeze(0).to(device)
    audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)
    
       
    with torch.no_grad():
        if "normalized_text" in r:
            text = spec_model.parse(r["normalized_text"], normalize=False)
        else:
            text = spec_model.parse(r['text'])
        
        text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)
    
        spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

        # Generate attention prior and spectrogram inputs for HiFi-GAN
        attn_prior = torch.from_numpy(
          beta_binomial_interpolator(spect_len.item(), text_len.item())
        ).unsqueeze(0).to(text.device)
            
        spectrogram = spec_model.forward(
          text=text, 
          input_lens=text_len, 
          spec=spect, 
          mel_lens=spect_len, 
          attn_prior=attn_prior,
        )[0]
        
        save_path_val = save_dir_val / f"mel_{i}.npy"
        np.save(save_path_val, spectrogram[0].to('cpu').numpy())
        r["mel_filepath"] = str(save_path_val)

hifigan_val_manifest_path = "hifigan_val_ft.json"
with open(hifigan_val_manifest_path, "w") as f:
    for r in records_val:
        f.write(json.dumps(r) + '\n')
# Out:
# [NeMo W 2022-06-20 18:36:39 tts_tokenizers:357] Text: [. MEY1BIY0 YUW1 TUW1 HHAE1V learned SAH1MTHIH0NG AE1FTER0 AO1L.] contains unknown char/phoneme: []. Original text: [Hmmm. maybe you two have learned something after all.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:36:40 tts_tokenizers:357] Text: [PAH0ZEH1SIH0NG the AY1DAH0L of BAO1RIY0AH0Z FIH1LD the ' HHAA1RTS with PRAY1D.] contains unknown char/phoneme: []. Original text: [Possessing the idol of boreas filled the griffons' hearts with pride.]. Symbol will be skipped.
# [NeMo W 2022-06-20 18:36:45 tts_tokenizers:357] Text: [AY1 KAE1NT BIH0LIY1V TAY1M  really PAA1SAH0BAH0L!] contains unknown char/phoneme: []. Original text: [I can't believe time travel's really possible!]. Symbol will be skipped.

# %%
! cd conf && unzip hifigan.zip
! cd conf && cd hifigan && wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/hifigan/hifigan.yaml && cd ..
# Out:
# Archive:  hifigan.zip
#    creating: hifigan/
#    creating: hifigan/model/
#    creating: hifigan/model/validation_ds/
#  extracting: hifigan/model/validation_ds/val_ds.yaml
#  extracting: hifigan/model/validation_ds/val_ds_finetune.yaml
#    creating: hifigan/model/train_ds/
#  extracting: hifigan/model/train_ds/train_ds.yaml
#  extracting: hifigan/model/train_ds/train_ds_finetune.yaml
#    creating: hifigan/model/generator/
#  extracting: hifigan/model/generator/v1.yaml
#  extracting: hifigan/model/generator/v1_44100.yaml
#  extracting: hifigan/model/generator/v2.yaml
#  extracting: hifigan/model/generator/v3.yaml
#  extracting: hifigan/hifigan.yaml
#  extracting: hifigan/hifigan_44100.yaml
# --2022-06-20 18:40:40--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/hifigan/hifigan.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2245 (2.2K) [text/plain]
# Saving to: ‘hifigan.yaml.1’
#
# hifigan.yaml.1      100%[===================>]   2.19K  --.-KB/s    in 0s
#
# 2022-06-20 18:40:40 (50.8 MB/s) - ‘hifigan.yaml.1’ saved [2245/2245]

# %%
# %pwd
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_hifigan.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_hifigan.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# Copying /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo to ./
# 315386678

# %% [markdown]
# ## finetuning the HiFiGAN model

# %%
!(python hifigan_finetune.py \
--config-name=hifigan.yaml \
model.train_ds.dataloader_params.batch_size=16 \
model.max_steps=10000 \
model.optim.lr=0.0002 \
~model.optim.sched \
train_dataset=./hifigan_train_ft.json \
validation_datasets=./hifigan_val_ft.json \
exp_manager.exp_dir=training_logs \
+init_from_nemo_model=tts_hifigan.nemo \
trainer.check_val_every_n_epoch=2 \
)
# Out:
# [NeMo W 2022-06-20 18:40:49 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-06-20 18:40:49 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-06-20 18:40:49 exp_manager:287] Experiments will be logged at training_logs/HifiGan/2022-06-20_18-40-49
# [NeMo I 2022-06-20 18:40:49 exp_manager:661] TensorboardLogger has been set up
# [NeMo W 2022-06-20 18:40:49 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo W 2022-06-20 18:40:49 exp_manager:896] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 10000. Please ensure that max_steps will run for at least 2 epochs to ensure that checkpointing will not error out.
# Created a temporary directory at /tmp/tmpahb8elqk
# Writing /tmp/tmpahb8elqk/_remote_module_non_sriptable.py
# [NeMo I 2022-06-20 18:40:50 data:846] Loading dataset from ./hifigan_train_ft.json.
# 8753it [00:00, 186948.42it/s]
# [NeMo I 2022-06-20 18:40:50 data:870] Loaded dataset with 8753 files.
# [NeMo I 2022-06-20 18:40:50 data:872] Dataset contains 5.92 hours.
# [NeMo I 2022-06-20 18:40:50 data:315] Pruned 10 files. Final dataset contains 8743 files
# [NeMo I 2022-06-20 18:40:50 data:318] Pruned 0.00 hours. Final dataset contains 5.92 hours.
# [NeMo I 2022-06-20 18:40:50 data:846] Loading dataset from ./hifigan_val_ft.json.
# 461it [00:00, 190687.79it/s]
# [NeMo I 2022-06-20 18:40:50 data:870] Loaded dataset with 461 files.
# [NeMo I 2022-06-20 18:40:50 data:872] Dataset contains 0.31 hours.
# [NeMo I 2022-06-20 18:40:50 data:315] Pruned 342 files. Final dataset contains 119 files
# [NeMo I 2022-06-20 18:40:50 data:318] Pruned 0.17 hours. Final dataset contains 0.13 hours.
# [NeMo I 2022-06-20 18:40:50 features:200] PADDING: 0
# [NeMo I 2022-06-20 18:40:50 features:208] STFT using exact pad
# [NeMo I 2022-06-20 18:40:50 features:200] PADDING: 0
# [NeMo I 2022-06-20 18:40:50 features:208] STFT using exact pad
# [NeMo W 2022-06-20 18:40:54 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-06-20 18:40:54 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-06-20 18:40:54 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-20 18:40:54 features:200] PADDING: 0
# [NeMo W 2022-06-20 18:40:54 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-20 18:40:54 features:200] PADDING: 0
# [NeMo I 2022-06-20 18:40:55 save_restore_connector:243] Model HifiGanModel was successfully restored from /home/deepankaracharyya/Disk2/Twilight_sparkle/tts_hifigan.nemo.
# [NeMo I 2022-06-20 18:40:55 modelPT:991] Model checkpoint restored from nemo file with path : `tts_hifigan.nemo`
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                       | Type                     | Params
# ------------------------------------------------------------------------
# 0 | audio_to_melspec_precessor | FilterbankFeatures       | 0
# 1 | trg_melspec_fn             | FilterbankFeatures       | 0
# 2 | generator                  | Generator                | 13.9 M
# 3 | mpd                        | MultiPeriodDiscriminator | 41.1 M
# 4 | msd                        | MultiScaleDiscriminator  | 29.6 M
# 5 | feature_loss               | FeatureMatchingLoss      | 0
# 6 | discriminator_loss         | DiscriminatorLoss        | 0
# 7 | generator_loss             | GeneratorLoss            | 0
# ------------------------------------------------------------------------
# 84.7 M    Trainable params
# 0         Non-trainable params
# 84.7 M    Total params
# 338.643   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s][NeMo W 2022-06-20 18:40:59 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:245: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       category=PossibleUserWarning,
#
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s][NeMo W 2022-06-20 18:40:59 nemo_logging:349] /usr/local/lib/python3.7/site-packages/torch/functional.py:696: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:798.)
#       normalized, onesided, return_complex)
#
# [NeMo W 2022-06-20 18:41:01 nemo_logging:349] /usr/local/lib/python3.7/site-packages/torch/functional.py:771: UserWarning: istft will require a complex-valued input tensor in a future PyTorch release. Matching the output from stft with return_complex=True.  (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:950.)
#       normalized, onesided, length, return_complex)
#
# Epoch 0:   0%|                                          | 0/547 [00:00<?, ?it/s][W reducer.cpp:1289] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [NeMo W 2022-06-20 18:41:04 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:231: UserWarning: You called `self.log('global_step', ...)` in your `training_step` but the value needs to be floating point. Converting it to torch.float32.
#       f"You called `self.log({self.meta.name!r}, ...)` in your `{self.meta.fx}` but the value needs to"
#
# Epoch 1:  68%|██ | 376/555 [13:50<06:35,  2.21s/it, v_num=0-49, g_l1_loss=0.378]^C

# %% [markdown]
# ## Copy the final weights to the gdrive for future reference

# %%
checkpoint_fp_path = "/home/deepankaracharyya/Disk2/Twilight_sparkle/training_logs/FastPitch/2022-06-20_17-00-59/checkpoints/FastPitch--v_loss=1.8701-epoch=18-last.ckpt"
checkpoint_hf_path = '/home/deepankaracharyya/Disk2/Twilight_sparkle/training_logs/HifiGan/2022-06-20_19-15-22/checkpoints/HifiGan--val_loss=0.4247-epoch=7-last.ckpt'

# %%
# !ls /home/deepankaracharyya/Disk2/Twilight_sparkle/training_logs/HifiGan/2022-06-20_19-15-22/checkpoints/
# Out:
# HifiGan.nemo
# HifiGan--val_loss=0.4247-epoch=7.ckpt
# HifiGan--val_loss=0.4247-epoch=7-last.ckpt
# HifiGan--val_loss=0.4262-epoch=5.ckpt
# HifiGan--val_loss=0.4382-epoch=3.ckpt

# %% [markdown]
# ## Load the checkpoints and do the inference

# %%
#imports
import os
import json
import librosa

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

from nemo.collections.tts.models import FastPitchModel
from nemo.collections.tts.models import HifiGanModel
from nemo.collections.tts.torch.helpers import BetaBinomialInterpolator
import soundfile as sf
import numpy as np
# Out:
# [NeMo W 2022-06-21 04:22:38 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-06-21 04:22:38 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.

# %%
spec_model = FastPitchModel.load_from_checkpoint(checkpoint_fp_path)
spec_model.eval().cuda()

vocoder = HifiGanModel.load_from_checkpoint(checkpoint_hf_path)
vocoder = vocoder.eval().cuda()
# Out:
# [NeMo I 2022-06-21 04:22:44 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-21 04:23:17 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-06-21 04:23:19 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-06-21 04:23:19 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 12
#       pin_memory: true
#
# [NeMo W 2022-06-21 04:23:19 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 8
#       pin_memory: true
# [NeMo I 2022-06-21 04:23:19 features:200] PADDING: 1
# [NeMo W 2022-06-21 04:23:24 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.VocoderDataset
#       manifest_filepath: ./hifigan_train_ft.json
#       sample_rate: 22050
#       n_segments: 8192
#       max_duration: null
#       min_duration: 0.75
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 4
#
# [NeMo W 2022-06-21 04:23:24 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.VocoderDataset
#       manifest_filepath: ./hifigan_val_ft.json
#       sample_rate: 22050
#       n_segments: 66048
#       max_duration: null
#       min_duration: 3
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 1
# [NeMo I 2022-06-21 04:23:24 features:200] PADDING: 0
# [NeMo I 2022-06-21 04:23:24 features:208] STFT using exact pad
# [NeMo I 2022-06-21 04:23:24 features:200] PADDING: 0
# [NeMo I 2022-06-21 04:23:24 features:208] STFT using exact pad

# %%
custom_infer("Oo its possible even if I have to organise the whole library by subject ", spec_model, vocoder)
# Out:
# [NeMo W 2022-06-21 04:29:13 tts_tokenizers:357] Text: [UW1 its PAA1SAH0BAH0L IY1VIH0N if AY1 HHAE1V to  the HHOW1L library BAY1 subject] contains unknown char/phoneme: []. Original text: [Oo its possible even if I have to organise the whole library by subject]. Symbol will be skipped.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
checkpoint_fp_path = "/home/deepankaracharyya/Disk2/Twilight_sparkle/training_logs/FastPitch/2022-06-20_17-00-59/checkpoints/FastPitch--v_loss=1.8701-epoch=18-last.ckpt"
spec_model = FastPitchModel.load_from_checkpoint(checkpoint_fp_path)
spec_model.eval().cuda()

vocoder2 = HifiGanModel.from_pretrained("tts_hifigan")
vocoder2 = vocoder.eval().cuda()

custom_infer("Oo its possible even if I have to organise the whole library by subject ", spec_model, vocoder2)
# Out:
# [NeMo I 2022-06-21 04:32:35 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-21 04:33:10 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-06-21 04:33:10 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 12
#       pin_memory: true
#
# [NeMo W 2022-06-21 04:33:10 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 8
#       pin_memory: true
# [NeMo I 2022-06-21 04:33:10 features:200] PADDING: 1
# [NeMo I 2022-06-21 04:33:10 cloud:56] Found existing object /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# [NeMo I 2022-06-21 04:33:10 cloud:62] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# [NeMo I 2022-06-21 04:33:10 common:789] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-06-21 04:33:13 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-06-21 04:33:13 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-06-21 04:33:13 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-21 04:33:13 features:200] PADDING: 0
# [NeMo W 2022-06-21 04:33:13 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-21 04:33:13 features:200] PADDING: 0
# [NeMo I 2022-06-21 04:33:14 save_restore_connector:243] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# [NeMo W 2022-06-21 04:33:14 tts_tokenizers:357] Text: [UW1 its PAA1SAH0BAH0L IY1VIH0N if AY1 HHAE1V to  the HHOW1L library BAY1 subject] contains unknown char/phoneme: []. Original text: [Oo its possible even if I have to organise the whole library by subject]. Symbol will be skipped.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
