# %% [markdown]
# <a href="https://colab.research.google.com/github/Conv-AI/TTS-Dev/blob/main/TTS_Finetuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pre-requisites : Setting up the environment

# %%
#installs
BRANCH = 'r1.8.2'
# !apt-get install sox libsndfile1 ffmpeg
# !pip install wget unidecode pynini==2.1.4
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# !pip install hydra-core==1.1
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.2).
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# sox is already the newest version (14.4.2-3ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (3.2)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (1.3.4)
# Requirement already satisfied: pynini==2.1.4 in /usr/local/lib/python3.7/dist-packages (2.1.4)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from pynini==2.1.4) (0.29.30)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision r1.8.2) to /tmp/pip-install-3uwzbo5t/nemo-toolkit_a9a7fafe8fc24d57b97e391b1b158b3e
#   Running command git clone -q https://github.com/NVIDIA/NeMo.git /tmp/pip-install-3uwzbo5t/nemo-toolkit_a9a7fafe8fc24d57b97e391b1b158b3e
#   Running command git checkout -b r1.8.2 --track origin/r1.8.2
#   Switched to a new branch 'r1.8.2'
#   Branch 'r1.8.2' set up to track remote branch 'r1.8.2' from 'origin'.
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (59.5.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.21.6)
# Requirement already satisfied: onnx>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.11.0+cu113)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.17.21)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.64.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.51.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.3.2)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.4)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: black==19.10b0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (19.10b0)
# Requirement already satisfied: isort[requirements]<5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.3.21)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (6.0.0)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: sphinxcontrib-bibtex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.4.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.12.17)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2019.12.20)
# Requirement already satisfied: pynini==2.1.4 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.4)
# Requirement already satisfied: pytorch-lightning>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.6.4)
# Requirement already satisfied: torchmetrics>=0.4.1rc0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: transformers>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.19.2)
# Requirement already satisfied: webdataset<=0.1.62,>=0.1.48 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.62)
# Requirement already satisfied: omegaconf>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: hydra-core>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: pyyaml<6 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (5.4.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.96)
# Requirement already satisfied: youtokentome>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.7)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Requirement already satisfied: kaldi-io in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.9.4)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.10.3.post1)
# Requirement already satisfied: sox in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: kaldi-python-io in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.2.2)
# Requirement already satisfied: kaldiio in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.17.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.25.1)
# Requirement already satisfied: pyannote.core in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.4)
# Requirement already satisfied: pyannote.metrics in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: torch-stft in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.1.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.7.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.12.0+cu113)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.24.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting matplotlib>=3.3.2
#   Using cached matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.0.11)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Requirement already satisfied: sacrebleu[ja] in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: sacremoses>=0.0.43 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.0.53)
# Collecting nltk>=3.6.5
#   Using cached nltk-3.7-py3-none-any.whl (1.5 MB)
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.9.2)
# Requirement already satisfied: opencc in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: pangu in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.0.6.1)
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (6.1.1)
# Requirement already satisfied: flask_restful in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.3.9)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.5)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.46.0)
# Requirement already satisfied: attrdict in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.3.3)
# Requirement already satisfied: pesq in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.0.4)
# Requirement already satisfied: click>=6.5 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: pathspec<1,>=0.6 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (21.4.0)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: typed-ast>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.5.4)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from pynini==2.1.4->nemo_toolkit[all]) (0.29.30)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.1.0->nemo_toolkit[all]) (4.8)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core>=1.1.0->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: pipreqs in /usr/local/lib/python3.7/dist-packages (from isort[requirements]<5->nemo_toolkit[all]) (0.4.11)
# Requirement already satisfied: pip-api in /usr/local/lib/python3.7/dist-packages (from isort[requirements]<5->nemo_toolkit[all]) (0.0.29)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.2.0)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.17.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.12.2->onnx>=1.7.0->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.3.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6.0->nemo_toolkit[all]) (2.8.0)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6.0->nemo_toolkit[all]) (2022.5.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.46.3)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (3.2.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (3.7.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (2.0.12)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from boto3->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from boto3->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.4 in /usr/local/lib/python3.7/dist-packages (from boto3->nemo_toolkit[all]) (1.27.4)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext->nemo_toolkit[all]) (2.9.2)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (9.0.1)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (2022.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from g2p_en->nemo_toolkit[all]) (0.1.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->nemo_toolkit[all]) (1.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (4.10.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.3.5)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (1.0.18)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (4.10.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (0.18.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (23.0.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (2.1.9)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->nemo_toolkit[all]) (0.34.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (21.1.3)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.6.2)
# Requirement already satisfied: yarg in /usr/local/lib/python3.7/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.1.9)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: simplejson>=3.8.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (3.17.6)
# Requirement already satisfied: pyannote.database>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (4.1.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (0.8.9)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.4)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.4.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (8.13.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.4.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: jarowinkler<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from rapidfuzz->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.0->nemo_toolkit[all]) (1.7.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml->nemo_toolkit[all]) (0.2.6)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: mecab-python3==1.0.5 in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.5)
# Requirement already satisfied: ipadic<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.10.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: docutils<0.19,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.17.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: pybtex>=0.24 in /usr/local/lib/python3.7/dist-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (0.24.0)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from pybtex>=0.24->sphinxcontrib-bibtex->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (1.0.9)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (1.5.12)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (3.1.27)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (2.3)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (1.2.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb->nemo_toolkit[all]) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->nemo_toolkit[all]) (5.0.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hydra-core==1.1 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (4.8)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (5.7.1)
# Requirement already satisfied: omegaconf==2.1.* in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (2.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf==2.1.*->hydra-core==1.1) (5.4.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->hydra-core==1.1) (3.8.0)

# %%
# !nvidia-smi
# Out:
# Wed Jun  8 10:33:13 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     8W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#helper functions
def infer(spec_gen_model, vocoder_model, str_input, speaker=None):
    """
    Synthesizes spectrogram and audio from a text string given a spectrogram synthesis and vocoder model.
    
    Args:
        spec_gen_model: Spectrogram generator model (FastPitch in our case)
        vocoder_model: Vocoder model (HiFiGAN in our case)
        str_input: Text input for the synthesis
        speaker: Speaker ID
    
    Returns:
        spectrogram and waveform of the synthesized audio.
    """
    with torch.no_grad():
        parsed = spec_gen_model.parse(str_input)
        if speaker is not None:
            speaker = torch.tensor([speaker]).long().to(device=spec_gen_model.device)
        spectrogram = spec_gen_model.generate_spectrogram(tokens=parsed, speaker=speaker)
        audio = vocoder_model.convert_spectrogram_to_audio(spec=spectrogram)
        
    if spectrogram is not None:
        if isinstance(spectrogram, torch.Tensor):
            spectrogram = spectrogram.to('cpu').numpy()
        if len(spectrogram.shape) == 3:
            spectrogram = spectrogram[0]
    if isinstance(audio, torch.Tensor):
        audio = audio.to('cpu').numpy()
    return spectrogram, audio

def get_best_ckpt_from_last_run(
        base_dir, 
        new_speaker_id, 
        duration_mins, 
        mixing_enabled, 
        original_speaker_id, 
        model_name="FastPitch"
    ):    
    mixing = "no_mixing" if not mixing_enabled else "mixing"
    
    d = f"{original_speaker_id}_to_{new_speaker_id}_{mixing}_{duration_mins}_mins"
    
    exp_dirs = list([i for i in (Path(base_dir) / d / model_name).iterdir() if i.is_dir()])
    last_exp_dir = sorted(exp_dirs)[-1]
    
    last_checkpoint_dir = last_exp_dir / "checkpoints"
    
    last_ckpt = list(last_checkpoint_dir.glob('*-last.ckpt'))

    if len(last_ckpt) == 0:
        raise ValueError(f"There is no last checkpoint in {last_checkpoint_dir}.")
    
    return str(last_ckpt[0])

# %% [markdown]
# Finetuning FastPitch

# %%
#datasets : downloading and preparing
# !wget https://nemo-public.s3.us-east-2.amazonaws.com/6097_5_mins.tar.gz  # Contains 10MB of data
# !tar -xzf 6097_5_mins.tar.gz

# !head -n 1 ./6097_5_mins/manifest.json

# !cat ./6097_5_mins/manifest.json | tail -n 10 > ./6097_manifest_dev_ns_all_local.json
# !cat ./6097_5_mins/manifest.json | head -n -4 > ./6097_manifest_train_dur_5_mins_local.json
# !ln -s ./6097_5_mins/audio audio

home_path = !(echo $HOME)
home_path = home_path[0]
print(home_path)
# Out:
# --2022-06-08 10:37:37--  https://nemo-public.s3.us-east-2.amazonaws.com/6097_5_mins.tar.gz
# Resolving nemo-public.s3.us-east-2.amazonaws.com (nemo-public.s3.us-east-2.amazonaws.com)... 52.219.100.80
# Connecting to nemo-public.s3.us-east-2.amazonaws.com (nemo-public.s3.us-east-2.amazonaws.com)|52.219.100.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11002569 (10M) [application/x-gzip]
# Saving to: ‘6097_5_mins.tar.gz.1’
#
# 6097_5_mins.tar.gz. 100%[===================>]  10.49M  37.8MB/s    in 0.3s
#
# 2022-06-08 10:37:38 (37.8 MB/s) - ‘6097_5_mins.tar.gz.1’ saved [11002569/11002569]
#
# {"audio_filepath": "audio/presentpictureofnsw_02_mann_0532.wav", "text": "not to stop more than ten minutes by the way", "duration": 2.6, "text_no_preprocessing": "not to stop more than ten minutes by the way,", "text_normalized": "not to stop more than ten minutes by the way,"}
# /root

# %%
#imports
import os
import json

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

# %%
from nemo.collections.tts.models import HifiGanModel
from nemo.collections.tts.models import FastPitchModel

# %%
#getting the pre-trained model for fastpitch
FastPitchModel.from_pretrained("tts_en_fastpitch")
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_en_fastpitch_align.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_en_fastpitch_align.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# [NeMo I 2022-06-08 10:33:53 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/tts_en_fastpitch/versions/1.8.1/files/tts_en_fastpitch_align.nemo to /root/.cache/torch/NeMo/NeMo_1.8.2/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo
# [NeMo I 2022-06-08 10:33:59 common:747] Instantiating model from pre-trained checkpoint
# [NeMo I 2022-06-08 10:34:00 tokenize_and_classify:88] Creating ClassifyFst grammars.
# [NeMo W 2022-06-08 10:34:05 g2ps:85] apply_to_oov_word=None, it means that some of words will remain unchanged if they are not handled by one of rule in self.parse_one_word(). It is useful when you use tokenizer with set of phonemes and chars together, otherwise it can be not.
# [NeMo W 2022-06-08 10:34:05 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-06-08 10:34:05 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
# [NeMo I 2022-06-08 10:34:05 features:259] PADDING: 1
# [NeMo I 2022-06-08 10:34:05 features:276] STFT using torch
# [NeMo I 2022-06-08 10:34:20 save_restore_connector:209] Model FastPitchModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.8.2/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo.
# Copying /root/.cache/torch/NeMo/NeMo_1.8.2/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo to ./
# 187023360

# %%
#get the finetuning file
# !wget https://raw.githubusercontent.com/nvidia/NeMo/$BRANCH/examples/tts/fastpitch_finetune.py

# !mkdir -p conf \
&& cd conf \
&& wget https://raw.githubusercontent.com/nvidia/NeMo/$BRANCH/examples/tts/conf/fastpitch_align_v1.05.yaml \
&& cd ..

##additional files
# !mkdir -p tts_dataset_files && cd tts_dataset_files \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/scripts/tts_dataset_files/cmudict-0.7b_nv22.01 \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/scripts/tts_dataset_files/heteronyms-030921 \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/nemo_text_processing/text_normalization/en/data/whitelist_lj_speech.tsv \
&& cd ..
# Out:
# --2022-06-08 10:35:40--  https://raw.githubusercontent.com/nvidia/NeMo/r1.8.2/examples/tts/fastpitch_finetune.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1751 (1.7K) [text/plain]
# Saving to: ‘fastpitch_finetune.py’
#
# fastpitch_finetune. 100%[===================>]   1.71K  --.-KB/s    in 0s
#
# 2022-06-08 10:35:41 (35.1 MB/s) - ‘fastpitch_finetune.py’ saved [1751/1751]
#
# --2022-06-08 10:35:41--  https://raw.githubusercontent.com/nvidia/NeMo/r1.8.2/examples/tts/conf/fastpitch_align_v1.05.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6625 (6.5K) [text/plain]
# Saving to: ‘fastpitch_align_v1.05.yaml’
#
# fastpitch_align_v1. 100%[===================>]   6.47K  --.-KB/s    in 0s
#
# 2022-06-08 10:35:41 (90.3 MB/s) - ‘fastpitch_align_v1.05.yaml’ saved [6625/6625]
#
# --2022-06-08 10:35:41--  https://raw.githubusercontent.com/NVIDIA/NeMo/r1.8.2/scripts/tts_dataset_files/cmudict-0.7b_nv22.01
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3721964 (3.5M) [text/plain]
# Saving to: ‘cmudict-0.7b_nv22.01’
#
# cmudict-0.7b_nv22.0 100%[===================>]   3.55M  --.-KB/s    in 0.07s
#
# 2022-06-08 10:35:41 (49.3 MB/s) - ‘cmudict-0.7b_nv22.01’ saved [3721964/3721964]
#
# --2022-06-08 10:35:41--  https://raw.githubusercontent.com/NVIDIA/NeMo/r1.8.2/scripts/tts_dataset_files/heteronyms-030921
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3132 (3.1K) [text/plain]
# Saving to: ‘heteronyms-030921’
#
# heteronyms-030921   100%[===================>]   3.06K  --.-KB/s    in 0s
#
# 2022-06-08 10:35:42 (51.6 MB/s) - ‘heteronyms-030921’ saved [3132/3132]
#
# --2022-06-08 10:35:42--  https://raw.githubusercontent.com/NVIDIA/NeMo/r1.8.2/nemo_text_processing/text_normalization/en/data/whitelist_lj_speech.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 263 [text/plain]
# Saving to: ‘whitelist_lj_speech.tsv’
#
# whitelist_lj_speech 100%[===================>]     263  --.-KB/s    in 0s
#
# 2022-06-08 10:35:42 (14.0 MB/s) - ‘whitelist_lj_speech.tsv’ saved [263/263]

# %%
#finetuning the fastpitch model
!(python fastpitch_finetune.py --config-name=fastpitch_align_v1.05.yaml \
  train_dataset=./6097_manifest_train_dur_5_mins_local.json \
  validation_datasets=./6097_manifest_dev_ns_all_local.json \
  sup_data_path=./fastpitch_sup_data \
  phoneme_dict_path=tts_dataset_files/cmudict-0.7b_nv22.01 \
  heteronyms_path=tts_dataset_files/heteronyms-030921 \
  whitelist_path=tts_dataset_files/whitelist_lj_speech.tsv \
  exp_manager.exp_dir=./ljspeech_to_6097_no_mixing_5_mins \
  +init_from_nemo_model=./tts_en_fastpitch_align.nemo \
  +trainer.max_steps=1000 ~trainer.max_epochs \
  trainer.check_val_every_n_epoch=25 \
  model.train_ds.dataloader_params.batch_size=24 model.validation_ds.dataloader_params.batch_size=24 \
  model.n_speakers=1 model.pitch_mean=121.9 model.pitch_std=23.1 \
  model.pitch_fmin=30 model.pitch_fmax=512 model.optim.lr=2e-4 \
  ~model.optim.sched model.optim.name=adam trainer.devices=1 trainer.strategy=null \
  +model.text_tokenizer.add_blank_at=true \
)
# Out:
# [NeMo W 2022-06-08 10:38:44 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################
#
# [NeMo W 2022-06-08 10:38:45 experimental:28] Module <class 'nemo.collections.nlp.data.language_modeling.megatron.megatron_batch_samplers.MegatronPretrainingRandomBatchSampler'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-06-08 10:38:46 exp_manager:281] Experiments will be logged at ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46
# [NeMo I 2022-06-08 10:38:46 exp_manager:647] TensorboardLogger has been set up
# [NeMo W 2022-06-08 10:38:46 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo I 2022-06-08 10:38:46 tokenize_and_classify:88] Creating ClassifyFst grammars.
# [NeMo W 2022-06-08 10:38:51 g2ps:85] apply_to_oov_word=None, it means that some of words will remain unchanged if they are not handled by one of rule in self.parse_one_word(). It is useful when you use tokenizer with set of phonemes and chars together, otherwise it can be not.
# Created a temporary directory at /tmp/tmpl7cy0e02
# Writing /tmp/tmpl7cy0e02/_remote_module_non_sriptable.py
# [NeMo I 2022-06-08 10:38:51 data:173] Loading dataset from ./6097_manifest_train_dur_5_mins_local.json.
# 112it [00:34,  3.22it/s]
# [NeMo I 2022-06-08 10:39:26 data:207] Loaded dataset with 112 files.
# [NeMo I 2022-06-08 10:39:26 data:209] Dataset contains 0.08 hours.
# [NeMo I 2022-06-08 10:39:26 data:297] Pruned 0 files. Final dataset contains 112 files
# [NeMo I 2022-06-08 10:39:26 data:300] Pruned 0.00 hours. Final dataset contains 0.08 hours.
# [NeMo W 2022-06-08 10:39:26 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# [NeMo I 2022-06-08 10:39:26 data:173] Loading dataset from ./6097_manifest_dev_ns_all_local.json.
# 10it [00:03,  3.24it/s]
# [NeMo I 2022-06-08 10:39:29 data:207] Loaded dataset with 10 files.
# [NeMo I 2022-06-08 10:39:29 data:209] Dataset contains 0.01 hours.
# [NeMo I 2022-06-08 10:39:29 data:297] Pruned 0 files. Final dataset contains 10 files
# [NeMo I 2022-06-08 10:39:29 data:300] Pruned 0.00 hours. Final dataset contains 0.01 hours.
# [NeMo W 2022-06-08 10:39:29 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# [NeMo I 2022-06-08 10:39:29 features:259] PADDING: 1
# [NeMo I 2022-06-08 10:39:29 features:276] STFT using torch
# [NeMo I 2022-06-08 10:39:30 tokenize_and_classify:88] Creating ClassifyFst grammars.
# [NeMo W 2022-06-08 10:39:34 g2ps:85] apply_to_oov_word=None, it means that some of words will remain unchanged if they are not handled by one of rule in self.parse_one_word(). It is useful when you use tokenizer with set of phonemes and chars together, otherwise it can be not.
# [NeMo W 2022-06-08 10:39:34 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-06-08 10:39:34 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
#
# [NeMo I 2022-06-08 10:39:34 features:259] PADDING: 1
# [NeMo I 2022-06-08 10:39:34 features:276] STFT using torch
# [NeMo I 2022-06-08 10:39:35 save_restore_connector:209] Model FastPitchModel was successfully restored from /content/tts_en_fastpitch_align.nemo.
# [NeMo I 2022-06-08 10:39:35 modelPT:999] Model checkpoint restored from nemo file with path : `./tts_en_fastpitch_align.nemo`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2022-06-08 10:39:40 modelPT:587] Optimizer config = Adam (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.98]
#         eps: 1e-08
#         lr: 0.0002
#         maximize: False
#         weight_decay: 1e-06
#     )
# [NeMo I 2022-06-08 10:39:40 lr_scheduler:698] Scheduler not initialized as no `sched` config supplied to setup_optimizer()
#
#   | Name             | Type                              | Params
# -----------------------------------------------------------------------
# 0 | mel_loss         | MelLoss                           | 0
# 1 | pitch_loss       | PitchLoss                         | 0
# 2 | duration_loss    | DurationLoss                      | 0
# 3 | aligner          | AlignmentEncoder                  | 1.0 M
# 4 | forward_sum_loss | ForwardSumLoss                    | 0
# 5 | bin_loss         | BinLoss                           | 0
# 6 | preprocessor     | AudioToMelSpectrogramPreprocessor | 0
# 7 | fastpitch        | FastPitchModule                   | 45.8 M
# -----------------------------------------------------------------------
# 45.8 M    Trainable params
# 0         Non-trainable params
# 45.8 M    Total params
# 91.518    Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0% 0/1 [00:00<?, ?it/s][NeMo W 2022-06-08 10:39:55 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#       warnings.warn(problem)
#
# [NeMo W 2022-06-08 10:39:55 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36: UserWarning: Torchmetrics v0.9 introduced a new argument class property called `full_state_update` that has
#                     not been set for this class (_ResultMetric). The property determines if `update` by
#                     default needs access to the full metric state. If this is not the case, significant speedups can be
#                     achieved and we recommend setting this to `False`.
#                     We provide an checking function
#                     `from torchmetrics.utilities import check_forward_no_full_state`
#                     that can be used to check if the `full_state_update=True` (old and potential slower behaviour,
#                     default for now) or if `full_state_update=False` can be used safely.
#
#       warnings.warn(*args, **kwargs)
#
# [NeMo W 2022-06-08 10:39:56 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1937: PossibleUserWarning: The number of training batches (5) is smaller than the logging interval Trainer(log_every_n_steps=100). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#       category=PossibleUserWarning,
#
# Epoch 0:   0% 0/5 [00:00<?, ?it/s] [NeMo W 2022-06-08 10:39:56 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# Epoch 24:   0% 0/6 [00:00<?, ?it/s, loss=2.59, v_num=8-46]
# Validation: 0it [00:00, ?it/s][NeMo W 2022-06-08 10:44:13 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
#
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 24: 100% 6/6 [00:06<00:00,  1.12s/it, loss=2.55, v_num=8-46]
#                                                           Epoch 24, global step 125: 'v_loss' reached 0.91510 (best 0.91510), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.9151-epoch=24.ckpt' as top 3
# Epoch 49:   0% 0/6 [00:00<?, ?it/s, loss=2.26, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 49: 100% 6/6 [00:07<00:00,  1.20s/it, loss=2.25, v_num=8-46]
#                                                           Epoch 49, global step 250: 'v_loss' reached 0.82464 (best 0.82464), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.8246-epoch=49.ckpt' as top 3
# Epoch 74:   0% 0/6 [00:00<?, ?it/s, loss=2.12, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 74: 100% 6/6 [00:07<00:00,  1.19s/it, loss=2.11, v_num=8-46]
#                                                           Epoch 74, global step 375: 'v_loss' reached 0.75772 (best 0.75772), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7577-epoch=74.ckpt' as top 3
# Epoch 99:   0% 0/6 [00:00<?, ?it/s, loss=2.05, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 99: 100% 6/6 [00:07<00:00,  1.23s/it, loss=2.04, v_num=8-46]
#                                                           Epoch 99, global step 500: 'v_loss' reached 0.74708 (best 0.74708), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7471-epoch=99.ckpt' as top 3
# Epoch 124:   0% 0/6 [00:00<?, ?it/s, loss=1.99, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 124: 100% 6/6 [00:07<00:00,  1.19s/it, loss=1.99, v_num=8-46]
#                                                           Epoch 124, global step 625: 'v_loss' reached 0.75573 (best 0.74708), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7557-epoch=124.ckpt' as top 3
# Epoch 149:   0% 0/6 [00:00<?, ?it/s, loss=1.94, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 149: 100% 6/6 [00:07<00:00,  1.22s/it, loss=1.93, v_num=8-46]
#                                                           Epoch 149, global step 750: 'v_loss' was not in top 3
# Epoch 174:   0% 0/6 [00:00<?, ?it/s, loss=1.92, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 174: 100% 6/6 [00:07<00:00,  1.28s/it, loss=1.91, v_num=8-46]
#                                                           Epoch 174, global step 875: 'v_loss' reached 0.71652 (best 0.71652), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7165-epoch=174.ckpt' as top 3
# Epoch 199:   0% 0/6 [00:00<?, ?it/s, loss=1.88, v_num=8-46]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Epoch 199: 100% 6/6 [00:07<00:00,  1.18s/it, loss=1.88, v_num=8-46]
#                                                           Epoch 199, global step 1000: 'v_loss' reached 0.73729 (best 0.71652), saving model to '/content/ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7373-epoch=199.ckpt' as top 3
# Epoch 199: 100% 6/6 [00:16<00:00,  2.81s/it, loss=1.88, v_num=8-46]

# %%
new_speaker_id = 6097
duration_mins = 5
mixing = False
original_speaker_id = "ljspeech"

# %%
last_ckpt = get_best_ckpt_from_last_run("./", new_speaker_id, duration_mins, mixing, original_speaker_id)
print(last_ckpt)

spec_model = FastPitchModel.load_from_checkpoint(last_ckpt)
spec_model.eval().cuda()
# Out:
# ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7373-epoch=199-last.ckpt
# [NeMo I 2022-06-08 11:07:03 tokenize_and_classify:88] Creating ClassifyFst grammars.
# [NeMo W 2022-06-08 11:07:08 g2ps:85] apply_to_oov_word=None, it means that some of words will remain unchanged if they are not handled by one of rule in self.parse_one_word(). It is useful when you use tokenizer with set of phonemes and chars together, otherwise it can be not.
# [NeMo W 2022-06-08 11:07:08 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./6097_manifest_train_dur_5_mins_local.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 12
#
# [NeMo W 2022-06-08 11:07:08 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./6097_manifest_dev_ns_all_local.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 8
# [NeMo I 2022-06-08 11:07:08 features:259] PADDING: 1
# [NeMo I 2022-06-08 11:07:08 features:276] STFT using torch
# FastPitchModel(
#   (mel_loss): MelLoss()
#   (pitch_loss): PitchLoss()
#   (duration_loss): DurationLoss()
#   (aligner): AlignmentEncoder(
#     (softmax): Softmax(dim=3)
#     (log_softmax): LogSoftmax(dim=3)
#     (key_proj): Sequential(
#       (0): ConvNorm(
#         (conv): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (1): ReLU()
#       (2): ConvNorm(
#         (conv): Conv1d(768, 80, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (query_proj): Sequential(
#       (0): ConvNorm(
#         (conv): Conv1d(80, 160, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (1): ReLU()
#       (2): ConvNorm(
#         (conv): Conv1d(160, 80, kernel_size=(1,), stride=(1,))
#       )
#       (3): ReLU()
#       (4): ConvNorm(
#         (conv): Conv1d(80, 80, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (forward_sum_loss): ForwardSumLoss(
#     (log_softmax): LogSoftmax(dim=3)
#     (ctc_loss): CTCLoss()
#   )
#   (bin_loss): BinLoss()
#   (preprocessor): AudioToMelSpectrogramPreprocessor(
#     (featurizer): FilterbankFeatures()
#   )
#   (fastpitch): FastPitchModule(
#     (encoder): FFTransformerEncoder(
#       (pos_emb): PositionalEmbedding()
#       (drop): Dropout(p=0.0, inplace=False)
#       (layers): ModuleList(
#         (0): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (word_emb): Embedding(115, 384, padding_idx=112)
#     )
#     (decoder): FFTransformerDecoder(
#       (pos_emb): PositionalEmbedding()
#       (drop): Dropout(p=0.0, inplace=False)
#       (layers): ModuleList(
#         (0): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (duration_predictor): TemporalPredictor(
#       (layers): Sequential(
#         (0): ConvReLUNorm(
#           (conv): Conv1d(384, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (1): ConvReLUNorm(
#           (conv): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (fc): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (pitch_predictor): TemporalPredictor(
#       (layers): Sequential(
#         (0): ConvReLUNorm(
#           (conv): Conv1d(384, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (1): ConvReLUNorm(
#           (conv): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (fc): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (aligner): AlignmentEncoder(
#       (softmax): Softmax(dim=3)
#       (log_softmax): LogSoftmax(dim=3)
#       (key_proj): Sequential(
#         (0): ConvNorm(
#           (conv): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ReLU()
#         (2): ConvNorm(
#           (conv): Conv1d(768, 80, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (query_proj): Sequential(
#         (0): ConvNorm(
#           (conv): Conv1d(80, 160, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ReLU()
#         (2): ConvNorm(
#           (conv): Conv1d(160, 80, kernel_size=(1,), stride=(1,))
#         )
#         (3): ReLU()
#         (4): ConvNorm(
#           (conv): Conv1d(80, 80, kernel_size=(1,), stride=(1,))
#         )
#       )
#     )
#     (pitch_emb): Conv1d(1, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#     (proj): Linear(in_features=384, out_features=80, bias=True)
#   )
# )

# %%
#save the model--> gdrive
# !cp ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7373-epoch=199-last.ckpt -t /content/drive/MyDrive/TTS-ConvAI/Iteration-01/Fastpitch_checkpoint/

# %%
#trying it out 
vocoder = HifiGanModel.from_pretrained("tts_hifigan")
vocoder = vocoder.eval().cuda()

# %%
# Only need to set speaker_id if there is more than one speaker
speaker_id = None
if mixing:
    speaker_id = 1

num_val = 4  # Number of validation samples
val_records = []
with open(f"{new_speaker_id}_manifest_dev_ns_all_local.json", "r") as f:
    for i, line in enumerate(f):
        val_records.append(json.loads(line))
        if len(val_records) >= num_val:
            break
            
for val_record in val_records:
    print("Real validation audio")
    ipd.display(ipd.Audio(val_record['audio_filepath'], rate=22050))
    print(f"SYNTHESIZED FOR -- Speaker: {new_speaker_id} | Dataset size: {duration_mins} mins | Mixing:{mixing} | Text: {val_record['text']}")
    spec, audio = infer(spec_model, vocoder, val_record['text'], speaker=speaker_id)
    ipd.display(ipd.Audio(audio, rate=22050))
    # %matplotlib inline
    imshow(spec, origin="lower", aspect="auto")
    plt.show()
# Out:
# [NeMo I 2022-06-08 11:18:09 cloud:56] Found existing object /root/.cache/torch/NeMo/NeMo_1.8.2/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# [NeMo I 2022-06-08 11:18:09 cloud:62] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.8.2/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# [NeMo I 2022-06-08 11:18:09 common:747] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-06-08 11:18:12 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-06-08 11:18:12 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-06-08 11:18:12 features:234] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-08 11:18:12 features:259] PADDING: 0
# [NeMo I 2022-06-08 11:18:12 features:276] STFT using torch
# [NeMo W 2022-06-08 11:18:12 features:234] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-08 11:18:12 features:259] PADDING: 0
# [NeMo I 2022-06-08 11:18:12 features:276] STFT using torch
# [NeMo I 2022-06-08 11:18:14 save_restore_connector:209] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.8.2/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: to mention that in this branch of the subject two reservations have been made
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: or vice versa
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: and felony towards our sovereign lord
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: and there abode in peace the time of their summoning
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Finetuning HiFiGAN

# %%
#imports
from nemo.collections.tts.torch.helpers import BetaBinomialInterpolator
import librosa
import soundfile as sf
import numpy as np

# %%
#helper functions
def load_wav(audio_file, target_sr=None):
    with sf.SoundFile(audio_file, 'r') as f:
        samples = f.read(dtype='float32')
        sample_rate = f.samplerate
        if target_sr is not None and target_sr != sample_rate:
            samples = librosa.core.resample(samples, orig_sr=sample_rate, target_sr=target_sr)
    return samples.transpose()

# %%
#dataset preparation
# Get records from the training manifest
manifest_path = "./6097_manifest_train_dur_5_mins_local.json"
records = []
with open(manifest_path, "r") as f:
    for i, line in enumerate(f):
        records.append(json.loads(line))

beta_binomial_interpolator = BetaBinomialInterpolator()
spec_model.eval()

device = spec_model.device

save_dir = Path("./6097_manifest_train_dur_5_mins_local_mels")
save_dir.mkdir(exist_ok=True, parents=True)

# Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
for i, r in enumerate(records):
    audio = load_wav(r["audio_filepath"])
    audio = torch.from_numpy(audio).unsqueeze(0).to(device)
    audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)
    
    # Again, our finetuned FastPitch model doesn't use multiple speakers,
    # but we keep the code to support it here for reference
    if spec_model.fastpitch.speaker_emb is not None and "speaker" in r:
        speaker = torch.tensor([r['speaker']]).to(device)
    else:
        speaker = None
    
    with torch.no_grad():
        if "normalized_text" in r:
            text = spec_model.parse(r["normalized_text"], normalize=False)
        else:
            text = spec_model.parse(r['text'])
        
        text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)
    
        spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

        # Generate attention prior and spectrogram inputs for HiFi-GAN
        attn_prior = torch.from_numpy(
          beta_binomial_interpolator(spect_len.item(), text_len.item())
        ).unsqueeze(0).to(text.device)
            
        spectrogram = spec_model.forward(
          text=text, 
          input_lens=text_len, 
          spec=spect, 
          mel_lens=spect_len, 
          attn_prior=attn_prior,
          speaker=speaker,
        )[0]
        
        save_path = save_dir / f"mel_{i}.npy"
        np.save(save_path, spectrogram[0].to('cpu').numpy())
        r["mel_filepath"] = str(save_path)

hifigan_manifest_path = "hifigan_train_ft.json"
with open(hifigan_manifest_path, "w") as f:
    for r in records:
        f.write(json.dumps(r) + '\n')

# %%
# Get records from the training manifest
manifest_path_validation = "./6097_manifest_dev_ns_all_local.json"
records_val = []
with open(manifest_path_validation, "r") as f:
    for i, line in enumerate(f):
        records_val.append(json.loads(line))

save_dir_val = Path("./6097_manifest_dev_ns_all_local_mels")
save_dir_val.mkdir(exist_ok=True, parents=True)

# Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
for i, r in enumerate(records_val):
    audio = load_wav(r["audio_filepath"])
    audio = torch.from_numpy(audio).unsqueeze(0).to(device)
    audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)
    
    # Again, our finetuned FastPitch model doesn't use multiple speakers,
    # but we keep the code to support it here for reference
    if spec_model.fastpitch.speaker_emb is not None and "speaker" in r:
        speaker = torch.tensor([r['speaker']]).to(device)
    else:
        speaker = None
    
    with torch.no_grad():
        if "normalized_text" in r:
            text = spec_model.parse(r["normalized_text"], normalize=False)
        else:
            text = spec_model.parse(r['text'])
        
        text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)
    
        spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

        # Generate attention prior and spectrogram inputs for HiFi-GAN
        attn_prior = torch.from_numpy(
          beta_binomial_interpolator(spect_len.item(), text_len.item())
        ).unsqueeze(0).to(text.device)
            
        spectrogram = spec_model.forward(
          text=text, 
          input_lens=text_len, 
          spec=spect, 
          mel_lens=spect_len, 
          attn_prior=attn_prior,
          speaker=speaker,
        )[0]
        
        save_path_val = save_dir_val / f"mel_{i}.npy"
        np.save(save_path_val, spectrogram[0].to('cpu').numpy())
        r["mel_filepath"] = str(save_path_val)

hifigan_val_manifest_path = "hifigan_val_ft.json"
with open(hifigan_val_manifest_path, "w") as f:
    for r in records_val:
        f.write(json.dumps(r) + '\n')

# %%
#downloading and unzipping the necessary files
! mv hifigan.zip -t ./conf/
! cd conf && unzip hifigan.zip && cd ..
! wget https://raw.githubusercontent.com/nvidia/NeMo/$BRANCH/examples/tts/hifigan_finetune.py
! cd conf && cd hifigan && wget https://raw.githubusercontent.com/nvidia/NeMo/$BRANCH/examples/tts/conf/hifigan/hifigan.yaml && cd .. && cd ..
# Out:
# Archive:  hifigan.zip
#    creating: hifigan/
#    creating: hifigan/model/
#    creating: hifigan/model/validation_ds/
#  extracting: hifigan/model/validation_ds/val_ds.yaml
#  extracting: hifigan/model/validation_ds/val_ds_finetune.yaml
#    creating: hifigan/model/train_ds/
#  extracting: hifigan/model/train_ds/train_ds.yaml
#  extracting: hifigan/model/train_ds/train_ds_finetune.yaml
#    creating: hifigan/model/generator/
#  extracting: hifigan/model/generator/v1.yaml
#  extracting: hifigan/model/generator/v1_44100.yaml
#  extracting: hifigan/model/generator/v2.yaml
#  extracting: hifigan/model/generator/v3.yaml
#  extracting: hifigan/hifigan.yaml
#  extracting: hifigan/hifigan_44100.yaml
# --2022-06-08 11:21:56--  https://raw.githubusercontent.com/nvidia/NeMo/r1.8.2/examples/tts/conf/hifigan/hifigan.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2226 (2.2K) [text/plain]
# Saving to: ‘hifigan.yaml.1’
#
# hifigan.yaml.1      100%[===================>]   2.17K  --.-KB/s    in 0s
#
# 2022-06-08 11:21:56 (37.1 MB/s) - ‘hifigan.yaml.1’ saved [2226/2226]

# %%
#getting the pre-trained model for hifigan
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_hifigan.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_hifigan.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# Copying /root/.cache/torch/NeMo/NeMo_1.8.2/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo to ./
# 315386678

# %%
#remove the FastPitch & HiFiGAN model from the GPU memory
del spec_model
del vocoder

# %%
#finetuning the hifigan model
!(python hifigan_finetune.py \
--config-name=hifigan.yaml \
model.train_ds.dataloader_params.batch_size=16 \
model.max_steps=1000 \
model.optim.lr=0.0001 \
~model.optim.sched \
train_dataset=./hifigan_train_ft.json \
validation_datasets=./hifigan_val_ft.json \
exp_manager.exp_dir=hifigan_ft \
+init_from_nemo_model=tts_hifigan.nemo \
trainer.check_val_every_n_epoch=10 \
)
# Out:
# [NeMo W 2022-06-08 11:40:27 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# ################################################################################
# ### WARNING, path does not exist: KALDI_ROOT=/mnt/matylda5/iveselyk/Tools/kaldi-trunk
# ###          (please add 'export KALDI_ROOT=<your_path>' in your $HOME/.profile)
# ###          (or run as: KALDI_ROOT=<your_path> python <your_script>.py)
# ################################################################################
#
# [NeMo W 2022-06-08 11:40:28 experimental:28] Module <class 'nemo.collections.nlp.data.language_modeling.megatron.megatron_batch_samplers.MegatronPretrainingRandomBatchSampler'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-06-08 11:40:28 exp_manager:281] Experiments will be logged at hifigan_ft/HifiGan/2022-06-08_11-40-28
# [NeMo I 2022-06-08 11:40:28 exp_manager:647] TensorboardLogger has been set up
# [NeMo W 2022-06-08 11:40:28 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo W 2022-06-08 11:40:28 exp_manager:882] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 1000. Please ensure that max_steps will run for at least 10 epochs to ensure that checkpointing will not error out.
# Created a temporary directory at /tmp/tmp1nzji20d
# Writing /tmp/tmp1nzji20d/_remote_module_non_sriptable.py
# [NeMo I 2022-06-08 11:40:29 data:775] Loading dataset from ./hifigan_train_ft.json.
# 112it [00:00, 47221.76it/s]
# [NeMo I 2022-06-08 11:40:29 data:799] Loaded dataset with 112 files.
# [NeMo I 2022-06-08 11:40:29 data:801] Dataset contains 0.08 hours.
# [NeMo I 2022-06-08 11:40:29 data:297] Pruned 2 files. Final dataset contains 110 files
# [NeMo I 2022-06-08 11:40:29 data:300] Pruned 0.00 hours. Final dataset contains 0.08 hours.
# [NeMo W 2022-06-08 11:40:29 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#       cpuset_checked))
#
# [NeMo I 2022-06-08 11:40:29 data:775] Loading dataset from ./hifigan_val_ft.json.
# 10it [00:00, 47716.77it/s]
# [NeMo I 2022-06-08 11:40:29 data:799] Loaded dataset with 10 files.
# [NeMo I 2022-06-08 11:40:29 data:801] Dataset contains 0.01 hours.
# [NeMo I 2022-06-08 11:40:29 data:297] Pruned 5 files. Final dataset contains 5 files
# [NeMo I 2022-06-08 11:40:29 data:300] Pruned 0.00 hours. Final dataset contains 0.01 hours.
# [NeMo I 2022-06-08 11:40:29 features:259] PADDING: 0
# [NeMo I 2022-06-08 11:40:29 features:276] STFT using torch
# [NeMo I 2022-06-08 11:40:29 features:278] STFT using exact pad
# [NeMo I 2022-06-08 11:40:29 features:259] PADDING: 0
# [NeMo I 2022-06-08 11:40:29 features:276] STFT using torch
# [NeMo I 2022-06-08 11:40:29 features:278] STFT using exact pad
# [NeMo W 2022-06-08 11:40:33 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-06-08 11:40:33 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-06-08 11:40:33 features:234] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-08 11:40:33 features:259] PADDING: 0
# [NeMo I 2022-06-08 11:40:33 features:276] STFT using torch
# [NeMo W 2022-06-08 11:40:33 features:234] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-08 11:40:33 features:259] PADDING: 0
# [NeMo I 2022-06-08 11:40:33 features:276] STFT using torch
# [NeMo I 2022-06-08 11:40:34 save_restore_connector:209] Model HifiGanModel was successfully restored from /content/tts_hifigan.nemo.
# [NeMo I 2022-06-08 11:40:35 modelPT:999] Model checkpoint restored from nemo file with path : `tts_hifigan.nemo`
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                       | Type                     | Params
# ------------------------------------------------------------------------
# 0 | audio_to_melspec_precessor | FilterbankFeatures       | 0
# 1 | trg_melspec_fn             | FilterbankFeatures       | 0
# 2 | generator                  | Generator                | 13.9 M
# 3 | mpd                        | MultiPeriodDiscriminator | 41.1 M
# 4 | msd                        | MultiScaleDiscriminator  | 29.6 M
# 5 | feature_loss               | FeatureMatchingLoss      | 0
# 6 | discriminator_loss         | DiscriminatorLoss        | 0
# 7 | generator_loss             | GeneratorLoss            | 0
# ------------------------------------------------------------------------
# 84.7 M    Trainable params
# 0         Non-trainable params
# 84.7 M    Total params
# 338.643   Total estimated model params size (MB)
# Sanity Checking DataLoader 0:   0% 0/1 [00:00<?, ?it/s][NeMo W 2022-06-08 11:40:41 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/functional.py:696: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:798.)
#       normalized, onesided, return_complex)
#
# [NeMo W 2022-06-08 11:40:41 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/functional.py:771: UserWarning: istft will require a complex-valued input tensor in a future PyTorch release. Matching the output from stft with return_complex=True.  (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:950.)
#       normalized, onesided, length, return_complex)
#
# [NeMo W 2022-06-08 11:40:41 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torchmetrics/utilities/prints.py:36: UserWarning: Torchmetrics v0.9 introduced a new argument class property called `full_state_update` that has
#                     not been set for this class (_ResultMetric). The property determines if `update` by
#                     default needs access to the full metric state. If this is not the case, significant speedups can be
#                     achieved and we recommend setting this to `False`.
#                     We provide an checking function
#                     `from torchmetrics.utilities import check_forward_no_full_state`
#                     that can be used to check if the `full_state_update=True` (old and potential slower behaviour,
#                     default for now) or if `full_state_update=False` can be used safely.
#
#       warnings.warn(*args, **kwargs)
#
# [NeMo W 2022-06-08 11:40:41 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1937: PossibleUserWarning: The number of training batches (7) is smaller than the logging interval Trainer(log_every_n_steps=100). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#       category=PossibleUserWarning,
#
# Epoch 0:   0% 0/7 [00:00<?, ?it/s] [W reducer.cpp:1289] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [NeMo W 2022-06-08 11:40:44 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:231: UserWarning: You called `self.log('global_step', ...)` in your `training_step` but the value needs to be floating point. Converting it to torch.float32.
#       f"You called `self.log({self.meta.name!r}, ...)` in your `{self.meta.fx}` but the value needs to"
#
# Epoch 9:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.435]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.85it/s]
# Epoch 9: 100% 8/8 [00:16<00:00,  2.02s/it, v_num=0-28, g_l1_loss=0.415]
#                                                           Epoch 9, global step 140: 'val_loss' reached 0.48153 (best 0.48153), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4815-epoch=9.ckpt' as top 3
# tcmalloc: large alloc 1296457728 bytes == 0x1a2396000 @  0x7ff4c3f12615 0x592b76 0x4df71e 0x59394f 0x593bc6 0x7ff4bf906e24 0x7ff4bf9a5484 0x7ff4bf9784a0 0x7ff4459afea5 0x7ff4459ab604 0x7ff4459b3185 0x7ff4bf9789f2 0x7ff4bf6543f1 0x593784 0x594731 0x548cc1 0x51566f 0x549e0e 0x593fce 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576
# tcmalloc: large alloc 1296457728 bytes == 0x170c4c000 @  0x7ff4c3f12615 0x592b76 0x4df71e 0x59394f 0x593bc6 0x7ff4bf906e24 0x7ff4bf9a5484 0x7ff4bf9784a0 0x7ff4459afea5 0x7ff4459ab604 0x7ff4459b3185 0x7ff4bf9789f2 0x7ff4bf6543f1 0x593784 0x594731 0x548cc1 0x51566f 0x549e0e 0x593fce 0x5118f8 0x549576 0x593fce 0x548ae9 0x51566f 0x593dd7 0x5118f8 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576
# Epoch 19:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.391]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.84it/s]
# Epoch 19: 100% 8/8 [00:16<00:00,  2.02s/it, v_num=0-28, g_l1_loss=0.404]
#                                                           Epoch 19, global step 280: 'val_loss' reached 0.44379 (best 0.44379), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4438-epoch=19.ckpt' as top 3
# Epoch 29:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.384]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.84it/s]
# Epoch 29: 100% 8/8 [00:16<00:00,  2.02s/it, v_num=0-28, g_l1_loss=0.403]
#                                                           Epoch 29, global step 420: 'val_loss' reached 0.44120 (best 0.44120), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4412-epoch=29.ckpt' as top 3
# Epoch 39:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.371]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.82it/s]
# Epoch 39: 100% 8/8 [00:16<00:00,  2.02s/it, v_num=0-28, g_l1_loss=0.385]
#                                                           Epoch 39, global step 560: 'val_loss' reached 0.43190 (best 0.43190), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4319-epoch=39.ckpt' as top 3
# Epoch 49:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.392]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.84it/s]
# Epoch 49: 100% 8/8 [00:16<00:00,  2.03s/it, v_num=0-28, g_l1_loss=0.389]
#                                                           Epoch 49, global step 700: 'val_loss' reached 0.44117 (best 0.43190), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4412-epoch=49.ckpt' as top 3
# Epoch 59:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.376]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.82it/s]
# Epoch 59: 100% 8/8 [00:16<00:00,  2.02s/it, v_num=0-28, g_l1_loss=0.376]
#                                                           Epoch 59, global step 840: 'val_loss' reached 0.42592 (best 0.42592), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4259-epoch=59.ckpt' as top 3
# Epoch 69:   0% 0/8 [00:00<?, ?it/s, v_num=0-28, g_l1_loss=0.362]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0:   0% 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100% 1/1 [00:00<00:00,  3.81it/s]
# Epoch 69: 100% 8/8 [00:16<00:00,  2.03s/it, v_num=0-28, g_l1_loss=0.369]
#                                                           Epoch 69, global step 980: 'val_loss' reached 0.42122 (best 0.42122), saving model to '/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4212-epoch=69.ckpt' as top 3
# Epoch 71:   0% 0/7 [00:07<?, ?it/s, v_num=0-28, g_l1_loss=0.384]

# %%
#save the model--> gdrive
# !cp /content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4212-epoch=69-last.ckpt -t /content/drive/MyDrive/TTS-ConvAI/Iteration-01/hifigan_checkpoint/

# %% [markdown]
# Inferencing with the finetuned model :

# %%
#inferencing
last_ckpt1 = get_best_ckpt_from_last_run("./", new_speaker_id, duration_mins, mixing, original_speaker_id)
print(last_ckpt1)
spec_model = FastPitchModel.load_from_checkpoint(last_ckpt1)
spec_model.eval().cuda()

last_ckpt2 = "/content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4212-epoch=69-last.ckpt"
print(last_ckpt2)
vocoder = HifiGanModel.load_from_checkpoint(last_ckpt2)
vocoder = vocoder.eval().cuda()
# Out:
# ljspeech_to_6097_no_mixing_5_mins/FastPitch/2022-06-08_10-38-46/checkpoints/FastPitch--v_loss=0.7373-epoch=199-last.ckpt
# [NeMo I 2022-06-08 12:11:17 tokenize_and_classify:88] Creating ClassifyFst grammars.
# [NeMo W 2022-06-08 12:11:23 g2ps:85] apply_to_oov_word=None, it means that some of words will remain unchanged if they are not handled by one of rule in self.parse_one_word(). It is useful when you use tokenizer with set of phonemes and chars together, otherwise it can be not.
# [NeMo W 2022-06-08 12:11:23 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./6097_manifest_train_dur_5_mins_local.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 12
#
# [NeMo W 2022-06-08 12:11:23 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./6097_manifest_dev_ns_all_local.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 8
# [NeMo I 2022-06-08 12:11:23 features:259] PADDING: 1
# [NeMo I 2022-06-08 12:11:23 features:276] STFT using torch
# /content/hifigan_ft/HifiGan/2022-06-08_11-40-28/checkpoints/HifiGan--val_loss=0.4212-epoch=69-last.ckpt
# [NeMo W 2022-06-08 12:11:28 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.VocoderDataset
#       manifest_filepath: ./hifigan_train_ft.json
#       sample_rate: 22050
#       n_segments: 8192
#       max_duration: null
#       min_duration: 0.75
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 4
#
# [NeMo W 2022-06-08 12:11:28 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.VocoderDataset
#       manifest_filepath: ./hifigan_val_ft.json
#       sample_rate: 22050
#       n_segments: 66048
#       max_duration: null
#       min_duration: 3
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 1
# [NeMo I 2022-06-08 12:11:28 features:259] PADDING: 0
# [NeMo I 2022-06-08 12:11:28 features:276] STFT using torch
# [NeMo I 2022-06-08 12:11:28 features:278] STFT using exact pad
# [NeMo I 2022-06-08 12:11:28 features:259] PADDING: 0
# [NeMo I 2022-06-08 12:11:28 features:276] STFT using torch
# [NeMo I 2022-06-08 12:11:28 features:278] STFT using exact pad

# %%
# Only need to set speaker_id if there is more than one speaker
speaker_id = None
if mixing:
    speaker_id = 1

num_val = 4  # Number of validation samples
val_records = []
with open(f"{new_speaker_id}_manifest_dev_ns_all_local.json", "r") as f:
    for i, line in enumerate(f):
        val_records.append(json.loads(line))
        if len(val_records) >= num_val:
            break
            
for val_record in val_records:
    print("Real validation audio")
    ipd.display(ipd.Audio(val_record['audio_filepath'], rate=22050))
    print(f"SYNTHESIZED FOR -- Speaker: {new_speaker_id} | Dataset size: {duration_mins} mins | Mixing:{mixing} | Text: {val_record['text']}")
    spec, audio = infer(spec_model, vocoder, val_record['text'], speaker=speaker_id)
    ipd.display(ipd.Audio(audio, rate=22050))
    # %matplotlib inline
    imshow(spec, origin="lower", aspect="auto")
    plt.show()
# Out:
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: to mention that in this branch of the subject two reservations have been made
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: or vice versa
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: and felony towards our sovereign lord
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Real validation audio
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# SYNTHESIZED FOR -- Speaker: 6097 | Dataset size: 5 mins | Mixing:False | Text: and there abode in peace the time of their summoning
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#saving the audio
