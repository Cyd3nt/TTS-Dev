# %%
# !python --version
# Out:
# Python 3.7.11

# %% [markdown]
# ### Preparing the Data

# %%
trixie_data_path = "Dataset/audio/Trixie.tar"

# %%
# Options for Dataloading
Pony = 'Trixie' # <-- Pick a voice e.g 'Rainbow-Dash' or 'Rarity'

skip_noisy = True # Disable to train with Noisy Data included
percentage_training_data = 0.95 # 95% of Data will be used for training, 5% for Validation
allowed_emotions = """
Anxious
Angry
Annoyed
Amused
Confused
Crazy
Disgust
Exhausted
Fear
Happy
Neutral
Sad
Serious
Singing
Shouting
Surprised
Smug
Love
Sarcastic
Tired
Whispering
Whining
""".split("\n")[1:-1]

# %%
#=== load the repo and data (Thanks Synthbot) ===
# !apt -qq install -y sox
# !git clone "https://github.com/synthbot-anon/synthbot.git" /content/synthbot
!(cd /content/synthbot; git checkout experimental)
# !pip install pysoundfile 
# !pip install librosa
# Out:
# sox is already the newest version (14.4.1-5+deb8u4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# fatal: destination path '/content/synthbot' already exists and is not an empty directory.
# Already on 'experimental'
# Your branch is up-to-date with 'origin/experimental'.
# Requirement already satisfied: pysoundfile in /usr/local/lib/python3.7/site-packages (0.9.0.post1)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.7/site-packages (from pysoundfile) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=0.6->pysoundfile) (2.21)
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/site-packages (0.9.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/site-packages (from librosa) (0.2.2)
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.7/site-packages (from librosa) (2.1.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/site-packages (from librosa) (21.3)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/site-packages (from librosa) (1.1.0)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/site-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.7/site-packages (from librosa) (1.0.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/site-packages (from librosa) (1.21.6)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.7/site-packages (from librosa) (0.55.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.7/site-packages (from librosa) (1.7.3)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/site-packages (from soundfile>=0.10.2->librosa) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /usr/local/lib/python3.7/site-packages (from numba>=0.45.1->librosa) (0.38.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from numba>=0.45.1->librosa) (59.5.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/site-packages (from pooch>=1.0->librosa) (2.28.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.5.18.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.12)
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
import sys
sys.path.append('/content/synthbot/src')
from ponysynth.corpus import ClipperArchive, phoneme_transcription
import librosa
import subprocess
from tqdm.notebook import tqdm

# %%
archive_fn = "/home/deepankaracharyya/TTS-exp/Dataset/audio/Trixie.tar"
archive = ClipperArchive(archive_fn)

# %%
cd /home/deepankaracharyya/TTS-exp/Dataset/audio/
# Out:
# /home/deepankaracharyya/TTS-exp/Dataset/audio

# %%
# !pip install ipywidgets --user
# Out:
# Requirement already satisfied: ipywidgets in /root/.local/lib/python3.7/site-packages (7.7.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/site-packages (from ipywidgets) (5.4.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.7/site-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/site-packages (from ipywidgets) (5.2.2.post1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /root/.local/lib/python3.7/site-packages (from ipywidgets) (3.6.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /root/.local/lib/python3.7/site-packages (from ipywidgets) (1.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/site-packages (from ipywidgets) (6.13.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (4.6.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets) (2.15.3)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (59.5.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (3.0.29)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (2.12.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (5.1.1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.4.12)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (4.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /usr/local/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (5.7.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (4.11.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets) (0.7.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.14.1)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (23.1.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.5.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/site-packages (from packaging->ipykernel>=4.5.1->ipywidgets) (3.0.9)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.7/site-packages (from importlib-resources>=1.4.0; python_version < "3.9"->jsonschema>=2.6->nbformat>=4.2.0->ipywidgets) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.1.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.0.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.6.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.11.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (21.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.7/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21)
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
#=== output the data in NVIDIA/Tacotron2's required format
# Note that NVIDIA/Tacotron2 doesn't seem to use the test set, so this only
# creates the training and validation sets.
data_path = 'audio'
# !mkdir {data_path}

allowed_emotions = [x.lower() for x in allowed_emotions]
# !mkdir {data_path}
# !mkdir {data_path+"/out"}
all_clips = []; all_clips_arpa = []; skipped_count=0; too_short_count=0; emotion_skip=0
for key in archive.keys(): # write the audio files for processing in bash terminal
  audio = archive.read_audio(key)
  audio_fn = '{}/{}.wav'.format(data_path, key)
  audio_fn_ = '{}/{}.wav'.format(data_path+"/out", key)
  with open(audio_fn, 'wb') as audio_out:
    audio_out.write(audio.read())
# Out:
# mkdir: cannot create directory ‘audio’: File exists
# mkdir: cannot create directory ‘audio’: File exists
# mkdir: cannot create directory ‘audio/out’: File exists

# %%
# %%script bash
# # trim all 48Khz files
# mkdir /audio/out
# cd audio;
# for input in *.wav; do
#   output="out/$input"
#   sox "$input" "$output" silence 1 0.05 0.1% reverse silence 1 0.05 0.1% reverse;
# done
# Out:
# mkdir: cannot create directory ‘/audio/out’: No such file or directory

# %%
import os

should_continue = 0 # should run "continue" command inside outer loop.
for key in archive.keys():
  label = archive.read_label(key)
  audio_fn = '{}/{}.wav'.format(data_path, key)
  audio_fn_ = '{}/{}.wav'.format(data_path+"/out", key)
  if (label['noise'] in ['Very Noisy','Noisy']) and skip_noisy: os.remove(audio_fn_); skipped_count+=1; continue

  for tag in label['tags']:
    if tag.lower() not in allowed_emotions:
        try: os.remove(audio_fn_)
        except: pass
        print(tag+" emotion not in list"); emotion_skip+=1; should_continue = 1; break # this is supposed to break the outer loop
  if should_continue: should_continue = 0; continue

  audio = archive.read_audio(key)
  transcript = label['utterance']['content']
  
  if os.stat(audio_fn_).st_size < 71602:
    #print("Skipping Audio, Duration: "+str(len(librosa.core.load(audio_fn_, sr=48000)[0])/48000))
    try: os.remove(audio_fn_)
    except: pass
    too_short_count+=1; continue # Skips files based on size.

  filelist_line = "{}|{}".format(audio_fn_, transcript)
  all_clips.append(filelist_line)
  filelist_line = "{}|{}".format(audio_fn_, phoneme_transcription(label))
  all_clips_arpa.append(filelist_line)
print(str(skipped_count)+" Files are too Noisy.")
print(str(emotion_skip)+" Files contain an emotion not in permitted emotions")
print(str(too_short_count)+" Files are too short")
print(str(len(list(archive.keys()))-(skipped_count+too_short_count+emotion_skip))+" Files kept in dataset.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16197/3379459003.py in <module>
#       2
#       3 should_continue = 0 # should run "continue" command inside outer loop.
# ----> 4 for key in archive.keys():
#       5   label = archive.read_label(key)
#       6   audio_fn = '{}/{}.wav'.format(data_path, key)
#
# NameError: name 'archive' is not defined

# %%
# shuffle the training data
import random
random.seed(0)
random.shuffle(all_clips)

# get train, test, validation splits
num_clips = len(all_clips)
train_end = int(num_clips * percentage_training_data)

train = all_clips[:train_end]; validation = all_clips[train_end:]; train_arpa = all_clips_arpa[:train_end]; validation_arpa = all_clips_arpa[train_end:]

# dump the info to filelist files
with open('clipper_train_filelist.txt', 'w') as train_out:
  train_out.write('\n'.join(train)+'\n'+'\n'.join(train_arpa)+"")
with open('clipper_val_filelist.txt', 'w') as val_out:
  val_out.write('\n'.join(validation)+'\n'+'\n'.join(validation_arpa)+"")

# %%
BRANCH = 'r1.8.2'

# %%
# !apt-get install sox libsndfile1 ffmpeg
# !pip install wget unidecode pynini==2.1.4
# !pip install hydra-core==1.1
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.25-10ubuntu0.16.04.3).
# ffmpeg is already the newest version (7:2.8.17-0ubuntu0.1).
# sox is already the newest version (14.4.1-5+deb8u4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# Requirement already satisfied: wget in /usr/local/lib/python3.7/site-packages (3.2)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/site-packages (1.3.4)
# Requirement already satisfied: pynini==2.1.4 in /usr/local/lib/python3.7/site-packages (2.1.4)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/site-packages (from pynini==2.1.4) (0.29.30)
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: hydra-core==1.1 in /usr/local/lib/python3.7/site-packages (1.1.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/site-packages (from hydra-core==1.1) (4.8)
# Requirement already satisfied: omegaconf==2.1.* in /usr/local/lib/python3.7/site-packages (from hydra-core==1.1) (2.1.2)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.7/site-packages (from hydra-core==1.1) (5.7.1)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/site-packages (from omegaconf==2.1.*->hydra-core==1.1) (5.4.1)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /usr/local/lib/python3.7/site-packages (from importlib-resources; python_version < "3.9"->hydra-core==1.1) (3.8.0)
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]
# Out:
# Requirement already satisfied: nemo_toolkit[all] from git+https://github.com/NVIDIA/NeMo.git@r1.8.2#egg=nemo_toolkit[all] in /usr/local/lib/python3.7/site-packages (1.10.0rc0)
# Requirement already satisfied: setuptools==59.5.0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (59.5.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.21.6)
# Requirement already satisfied: onnx>=1.7.0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.14.1)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.17.21)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (4.64.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.55.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.3.2)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.3.4)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: black==19.10b0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (19.10b0)
# Requirement already satisfied: isort[requirements]<5 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (4.3.21)
# Requirement already satisfied: parameterized in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: pytest-runner in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (6.0.0)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: sphinxcontrib-bibtex in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.4.2)
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.12.18)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (5.6.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2022.6.2)
# Requirement already satisfied: pynini==2.1.4 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.1.4)
# Requirement already satisfied: pytorch-lightning>=1.6.1 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.6.4)
# Requirement already satisfied: torchmetrics>=0.4.1rc0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.9.1)
# Requirement already satisfied: transformers>=4.0.1 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (4.19.4)
# Requirement already satisfied: webdataset<=0.1.62,>=0.1.48 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.1.62)
# Requirement already satisfied: omegaconf<2.2,>=2.1.2 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: hydra-core<1.2,>=1.1.0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: pyyaml<6 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (5.4.1)
# Requirement already satisfied: sentencepiece<1.0.0 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.1.96)
# Requirement already satisfied: youtokentome>=1.0.5 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.3.5)
# Requirement already satisfied: sacremoses>=0.0.43 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.0.53)
# Requirement already satisfied: braceexpand in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.1.7)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.9.1)
# Requirement already satisfied: marshmallow in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.16.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.10.3.post1)
# Requirement already satisfied: sox in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: kaldi-python-io in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.2.2)
# Requirement already satisfied: kaldiio in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.17.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.7.3)
# Requirement already satisfied: g2p_en in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.25.1)
# Requirement already satisfied: pyannote.core in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (4.4)
# Requirement already satisfied: pyannote.metrics in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.2)
# Requirement already satisfied: ipywidgets in /root/.local/lib/python3.7/site-packages (from nemo_toolkit[all]) (7.7.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.5.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (9.1.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.12.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.24.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.7.0)
# Requirement already satisfied: rapidfuzz in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.0.11)
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (4.4.0)
# Requirement already satisfied: sacrebleu[ja] in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.7)
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.9.2)
# Requirement already satisfied: opencc in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: pangu in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (4.0.6.1)
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.42.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (6.1.1)
# Requirement already satisfied: flask_restful in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.3.9)
# Requirement already satisfied: einops in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.4.1)
# Requirement already satisfied: ijson in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (3.1.4)
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (1.7.2)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.46.0)
# Requirement already satisfied: attrdict in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.3.3)
# Requirement already satisfied: pesq in /usr/local/lib/python3.7/site-packages (from nemo_toolkit[all]) (0.0.4)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/site-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.2.0)
# Requirement already satisfied: protobuf>=3.12.2 in /usr/local/lib/python3.7/site-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.21.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil->nemo_toolkit[all]) (1.16.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6; platform_python_implementation == "CPython" and python_version < "3.11" in /usr/local/lib/python3.7/site-packages (from ruamel.yaml->nemo_toolkit[all]) (0.2.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/site-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/site-packages (from scikit-learn->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /usr/local/lib/python3.7/site-packages (from numba->nemo_toolkit[all]) (0.38.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from huggingface_hub->nemo_toolkit[all]) (4.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/site-packages (from huggingface_hub->nemo_toolkit[all]) (2.28.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/site-packages (from huggingface_hub->nemo_toolkit[all]) (3.7.1)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/site-packages (from black==19.10b0->nemo_toolkit[all]) (21.4.0)
# Requirement already satisfied: pathspec<1,>=0.6 in /usr/local/lib/python3.7/site-packages (from black==19.10b0->nemo_toolkit[all]) (0.9.0)
# Requirement already satisfied: typed-ast>=1.4.0 in /usr/local/lib/python3.7/site-packages (from black==19.10b0->nemo_toolkit[all]) (1.5.4)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.7/site-packages (from black==19.10b0->nemo_toolkit[all]) (0.10.2)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/site-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: click>=6.5 in /usr/local/lib/python3.7/site-packages (from black==19.10b0->nemo_toolkit[all]) (8.1.3)
# Requirement already satisfied: pipreqs; extra == "requirements" in /usr/local/lib/python3.7/site-packages (from isort[requirements]<5->nemo_toolkit[all]) (0.4.11)
# Requirement already satisfied: pip-api; extra == "requirements" in /usr/local/lib/python3.7/site-packages (from isort[requirements]<5->nemo_toolkit[all]) (0.0.29)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/site-packages (from pytest->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/site-packages (from pytest->nemo_toolkit[all]) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/site-packages (from pytest->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/site-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (2.12.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (1.0.3)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (3.1.2)
# Requirement already satisfied: docutils<0.19,>=0.14 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (0.18.1)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (2.10.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.7/site-packages (from sphinx->nemo_toolkit[all]) (2.0.0)
# Requirement already satisfied: pybtex-docutils>=1.0.0 in /usr/local/lib/python3.7/site-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: pybtex>=0.24 in /usr/local/lib/python3.7/site-packages (from sphinxcontrib-bibtex->nemo_toolkit[all]) (0.24.0)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (3.1.27)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (0.4.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (1.0.9)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (1.2.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (1.5.12)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (5.9.1)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (0.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/site-packages (from wandb->nemo_toolkit[all]) (2.3)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/site-packages (from pynini==2.1.4->nemo_toolkit[all]) (0.29.30)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/site-packages (from pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.9.1)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.7/site-packages (from pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.3.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /usr/local/lib/python3.7/site-packages (from pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2022.5.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/site-packages (from transformers>=4.0.1->nemo_toolkit[all]) (0.12.1)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/site-packages (from omegaconf<2.2,>=2.1.2->nemo_toolkit[all]) (4.8)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.7/site-packages (from hydra-core<1.2,>=1.1.0->nemo_toolkit[all]) (5.7.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/site-packages (from pandas->nemo_toolkit[all]) (2022.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/site-packages (from librosa->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.7/site-packages (from librosa->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/site-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: audioread>=2.1.5 in /usr/local/lib/python3.7/site-packages (from librosa->nemo_toolkit[all]) (2.1.9)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/site-packages (from packaging->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/site-packages (from soundfile->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: distance>=0.1.3 in /usr/local/lib/python3.7/site-packages (from g2p_en->nemo_toolkit[all]) (0.1.3)
# Requirement already satisfied: simplejson>=3.8.1 in /usr/local/lib/python3.7/site-packages (from pyannote.core->nemo_toolkit[all]) (3.17.6)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.7/site-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: pyannote.database>=4.0.1 in /usr/local/lib/python3.7/site-packages (from pyannote.metrics->nemo_toolkit[all]) (4.1.3)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/site-packages (from pyannote.metrics->nemo_toolkit[all]) (0.8.9)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/site-packages (from pyannote.metrics->nemo_toolkit[all]) (0.6.2)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.7/site-packages (from pyannote.metrics->nemo_toolkit[all]) (1.10.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (6.13.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /root/.local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /root/.local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (3.6.0)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (7.34.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (5.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/site-packages (from ipywidgets->nemo_toolkit[all]) (5.2.2.post1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/site-packages (from matplotlib->nemo_toolkit[all]) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/site-packages (from matplotlib->nemo_toolkit[all]) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/site-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/site-packages (from boto3->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: botocore<1.28.0,>=1.27.7 in /usr/local/lib/python3.7/site-packages (from boto3->nemo_toolkit[all]) (1.27.7)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.7/site-packages (from boto3->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: jarowinkler<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/site-packages (from rapidfuzz->nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from gdown->nemo_toolkit[all]) (4.11.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/site-packages (from sacrebleu[ja]->nemo_toolkit[all]) (0.4.4)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/site-packages (from sacrebleu[ja]->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: ipadic<2.0,>=1.0; extra == "ja" in /usr/local/lib/python3.7/site-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.0)
# Requirement already satisfied: mecab-python3==1.0.5; extra == "ja" in /usr/local/lib/python3.7/site-packages (from sacrebleu[ja]->nemo_toolkit[all]) (1.0.5)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/site-packages (from fasttext->nemo_toolkit[all]) (2.9.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/site-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/site-packages (from flask_restful->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.7/site-packages (from flask_restful->nemo_toolkit[all]) (9.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->huggingface_hub->nemo_toolkit[all]) (3.8.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests->huggingface_hub->nemo_toolkit[all]) (1.26.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests->huggingface_hub->nemo_toolkit[all]) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/site-packages (from requests->huggingface_hub->nemo_toolkit[all]) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests->huggingface_hub->nemo_toolkit[all]) (2022.5.18.1)
# Requirement already satisfied: yarg in /usr/local/lib/python3.7/site-packages (from pipreqs; extra == "requirements"->isort[requirements]<5->nemo_toolkit[all]) (0.1.9)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/site-packages (from pip-api; extra == "requirements"->isort[requirements]<5->nemo_toolkit[all]) (20.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/site-packages (from Jinja2>=2.3->sphinx->nemo_toolkit[all]) (2.1.1)
# Requirement already satisfied: latexcodec>=1.0.4 in /usr/local/lib/python3.7/site-packages (from pybtex>=0.24->sphinxcontrib-bibtex->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/site-packages (from GitPython>=1.0.0->wandb->nemo_toolkit[all]) (4.0.9)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.7.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.46.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/site-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.3.7)
# Requirement already satisfied: aiohttp; extra == "http" in /usr/local/lib/python3.7/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.8.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/site-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.7/site-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/site-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (0.1.3)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (6.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (1.5.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/site-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (6.4.12)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (3.0.29)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (0.18.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (2.15.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (4.6.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/site-packages (from beautifulsoup4->gdown->nemo_toolkit[all]) (2.3.2.post1)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.7/site-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (6.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0; python_version < "3.8" in /usr/local/lib/python3.7/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.13.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.7.2)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0; extra == "all" in /usr/local/lib/python3.7/site-packages (from typer[all]>=0.2.1->pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (1.4.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.7/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (23.1.0)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (6.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/site-packages (from jedi>=0.16->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->nemo_toolkit[all]) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets->nemo_toolkit[all]) (0.18.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.2.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.7/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (21.2.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.0)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.7/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
# !nvidia-smi
# Out:
# Sun Jun 12 07:18:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 495.46       CUDA Version: 11.5     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install protobuf==3.19.0
# Out:
# Collecting protobuf==3.19.0
#   Downloading protobuf-3.19.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 7.1 MB/s eta 0:00:01
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.17.3
#     Uninstalling protobuf-3.17.3:
#       Successfully uninstalled protobuf-3.17.3
# Successfully installed protobuf-3.19.0
# WARNING: You are using pip version 20.1.1; however, version 22.1.2 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.

# %%
#imports
import os
import json
import librosa

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

# %%
from nemo.collections.tts.models import HifiGanModel
from nemo.collections.tts.models import FastPitchModel

# %%
pwd
# Out:
# '/home/deepankaracharyya/TTS-exp/Dataset/audio'

# %%
#creating the json files for training and validation
with open('clipper_train_filelist.txt') as f :
  records = f.readlines()

print("Number of records : ",len(records))
# Out:
# Number of records :  948

# %%
import random

# %%
train_manifest = 'fastpitch_train.json'

train_rec = []
random.shuffle(records)
#count = 0

for i in records :
  # if count > 160 :
  #   break
  
  i = i.split('|')
  audio_filepath = i[0]
  text = i[-1].strip('\n')
  #if '{' in text :
    #print(text)
    #continue
  #count = count + 1

  duration = librosa.get_duration(filename=audio_filepath)
  r = {
       "audio_filepath" : audio_filepath,
       "text" : text,
       "duration" : round(duration,1),
       "text_no_preprocessing" : text
    }

  train_rec.append(r)

with open(train_manifest, "w") as f:
    for s in train_rec:
        f.write(json.dumps(s) + '\n')
        
print("Training Data : ", len(train_rec))
# Out:
# Training Data :  948

# %%
with open('clipper_val_filelist.txt') as f :
  records_val = f.readlines()

print("Number of records : ", len(records_val))
# Out:
# Number of records :  50

# %%
val_manifest = 'fastpitch_val.json'
#count = 0
val_rec = []
random.shuffle(records_val)

for i in records_val:
  # if count > 20 :
  #   break
    
  i = i.split('|')
  audio_filepath = i[0]
  text = i[-1].strip('\n')

  # if '{' in text :
  #   print(text)
  #   continue
  # count = count + 1
  duration = librosa.get_duration(filename=audio_filepath)
  r = {
       "audio_filepath" : audio_filepath,
       "text" : text,
       "duration" : round(duration,1),
       "text_no_preprocessing" : text
    }

  val_rec.append(r)

with open(val_manifest, "w") as f:
    for s in val_rec:
        f.write(json.dumps(s) + '\n')

# %%
home_path = !(echo $HOME)
home_path = home_path[0]
print(home_path)

FastPitchModel.from_pretrained("tts_en_fastpitch")
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_en_fastpitch_align.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_en_fastpitch_align.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# /root
# [NeMo I 2022-06-12 08:00:46 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/tts_en_fastpitch/versions/1.8.1/files/tts_en_fastpitch_align.nemo to /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo
# 100% [......................................................................] 187023360 / 187023360[NeMo I 2022-06-12 08:00:52 common:789] Instantiating model from pre-trained checkpoint
# [NeMo I 2022-06-12 08:00:56 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-12 08:01:26 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-06-12 08:01:27 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-06-12 08:01:27 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-06-12 08:01:27 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
# [NeMo I 2022-06-12 08:01:27 features:200] PADDING: 1
# [NeMo I 2022-06-12 08:01:31 save_restore_connector:243] Model FastPitchModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo.
# Copying /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo to ./
# 187023360

# %%
# !wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/fastpitch_finetune.py

# !mkdir -p conf \
&& cd conf \
&& wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/fastpitch_align_v1.05.yaml \
&& cd ..
# Out:
# --2022-06-12 08:04:30--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/fastpitch_finetune.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1751 (1.7K) [text/plain]
# Saving to: ‘fastpitch_finetune.py’
#
# fastpitch_finetune. 100%[===================>]   1.71K  --.-KB/s    in 0s
#
# 2022-06-12 08:04:30 (38.9 MB/s) - ‘fastpitch_finetune.py’ saved [1751/1751]
#
# --2022-06-12 08:04:30--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/fastpitch_align_v1.05.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6692 (6.5K) [text/plain]
# Saving to: ‘fastpitch_align_v1.05.yaml’
#
# fastpitch_align_v1. 100%[===================>]   6.54K  --.-KB/s    in 0s
#
# 2022-06-12 08:04:30 (87.4 MB/s) - ‘fastpitch_align_v1.05.yaml’ saved [6692/6692]

# %%
# additional files
# !mkdir -p tts_dataset_files && cd tts_dataset_files \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/cmudict-0.7b_nv22.01 \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/heteronyms-030921 \
&& wget https://github.com/NVIDIA/NeMo/blob/77be76349901d0dd99ad6778509ef5c0663a65c3/nemo_text_processing/text_normalization/en/data/whitelist_lj_speech.tsv \
&& cd ..
# Out:
# --2022-06-12 08:11:27--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/cmudict-0.7b_nv22.01
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3721964 (3.5M) [text/plain]
# Saving to: ‘cmudict-0.7b_nv22.01.1’
#
# cmudict-0.7b_nv22.0 100%[===================>]   3.55M  --.-KB/s    in 0.05s
#
# 2022-06-12 08:11:27 (68.6 MB/s) - ‘cmudict-0.7b_nv22.01.1’ saved [3721964/3721964]
#
# --2022-06-12 08:11:27--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/heteronyms-030921
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3132 (3.1K) [text/plain]
# Saving to: ‘heteronyms-030921.1’
#
# heteronyms-030921.1 100%[===================>]   3.06K  --.-KB/s    in 0s
#
# 2022-06-12 08:11:27 (52.4 MB/s) - ‘heteronyms-030921.1’ saved [3132/3132]
#
# --2022-06-12 08:11:27--  https://github.com/NVIDIA/NeMo/blob/77be76349901d0dd99ad6778509ef5c0663a65c3/nemo_text_processing/text_normalization/en/data/whitelist_lj_speech.tsv
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘whitelist_lj_speech.tsv’
#
# whitelist_lj_speech     [ <=>                ] 136.98K   760KB/s    in 0.2s
#
# 2022-06-12 08:11:28 (760 KB/s) - ‘whitelist_lj_speech.tsv’ saved [140266]

# %%
# TODO(oktai15): remove +model.text_tokenizer.add_blank_at=true when we update FastPitch checkpoint

!(python fastpitch_finetune.py --config-name=fastpitch_align_v1.05.yaml \
  train_dataset=./fastpitch_train.json \
  validation_datasets=./fastpitch_val.json \
  sup_data_path=./fastpitch_sup_data \
  phoneme_dict_path=tts_dataset_files/cmudict-0.7b_nv22.01 \
  heteronyms_path=tts_dataset_files/heteronyms-030921 \
  whitelist_path=tts_dataset_files/whitelist.tsv \
  exp_manager.exp_dir=./trixie_logs_fp \
  +init_from_nemo_model=./tts_en_fastpitch_align.nemo \
  +trainer.max_steps=2000 ~trainer.max_epochs \
  trainer.check_val_every_n_epoch=5 \
  model.train_ds.dataloader_params.batch_size=16 model.validation_ds.dataloader_params.batch_size=16 \
  model.n_speakers=1 model.pitch_mean=130 model.pitch_std=25 \
  model.pitch_fmin=30 model.pitch_fmax=512 model.optim.lr=2e-4 \
  ~model.optim.sched model.optim.name=adam trainer.devices=1 trainer.strategy=null \
  +model.text_tokenizer.add_blank_at=true \
)
# Out:
# [NeMo W 2022-06-12 11:23:14 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-06-12 11:23:17 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-06-12 11:23:19 exp_manager:287] Experiments will be logged at trixie_logs_fp/FastPitch/2022-06-12_11-23-19
# [NeMo I 2022-06-12 11:23:19 exp_manager:661] TensorboardLogger has been set up
# [NeMo W 2022-06-12 11:23:19 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo I 2022-06-12 11:23:22 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-12 11:23:58 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-06-12 11:23:59 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# Created a temporary directory at /tmp/tmp15h4t_jr
# Writing /tmp/tmp15h4t_jr/_remote_module_non_sriptable.py
# [NeMo I 2022-06-12 11:23:59 data:186] Loading dataset from ./fastpitch_train.json.
# 948it [00:57, 16.41it/s]
# [NeMo I 2022-06-12 11:24:57 data:221] Loaded dataset with 948 files.
# [NeMo I 2022-06-12 11:24:57 data:223] Dataset contains 0.88 hours.
# [NeMo I 2022-06-12 11:24:57 data:315] Pruned 0 files. Final dataset contains 948 files
# [NeMo I 2022-06-12 11:24:57 data:318] Pruned 0.00 hours. Final dataset contains 0.88 hours.
# [NeMo I 2022-06-12 11:24:57 data:186] Loading dataset from ./fastpitch_val.json.
# 50it [00:03, 14.64it/s]
# [NeMo I 2022-06-12 11:25:00 data:221] Loaded dataset with 50 files.
# [NeMo I 2022-06-12 11:25:00 data:223] Dataset contains 0.05 hours.
# [NeMo I 2022-06-12 11:25:00 data:315] Pruned 0 files. Final dataset contains 50 files
# [NeMo I 2022-06-12 11:25:00 data:318] Pruned 0.00 hours. Final dataset contains 0.05 hours.
# [NeMo I 2022-06-12 11:25:00 features:200] PADDING: 1
# [NeMo I 2022-06-12 11:25:06 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-12 11:25:42 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-06-12 11:25:42 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-06-12 11:25:42 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
#
# [NeMo I 2022-06-12 11:25:42 features:200] PADDING: 1
# [NeMo I 2022-06-12 11:25:42 save_restore_connector:243] Model FastPitchModel was successfully restored from /home/deepankaracharyya/TTS-exp/Dataset/audio/tts_en_fastpitch_align.nemo.
# [NeMo I 2022-06-12 11:25:43 modelPT:991] Model checkpoint restored from nemo file with path : `./tts_en_fastpitch_align.nemo`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2022-06-12 11:25:46 modelPT:579] Optimizer config = Adam (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.999]
#         eps: 1e-08
#         lr: 0.0002
#         maximize: False
#         weight_decay: 1e-06
#     )
# [NeMo I 2022-06-12 11:25:46 lr_scheduler:698] Scheduler not initialized as no `sched` config supplied to setup_optimizer()
#
#   | Name             | Type                              | Params
# -----------------------------------------------------------------------
# 0 | mel_loss         | MelLoss                           | 0
# 1 | pitch_loss       | PitchLoss                         | 0
# 2 | duration_loss    | DurationLoss                      | 0
# 3 | aligner          | AlignmentEncoder                  | 1.0 M
# 4 | forward_sum_loss | ForwardSumLoss                    | 0
# 5 | bin_loss         | BinLoss                           | 0
# 6 | preprocessor     | AudioToMelSpectrogramPreprocessor | 0
# 7 | fastpitch        | FastPitchModule                   | 45.8 M
# -----------------------------------------------------------------------
# 45.8 M    Trainable params
# 0         Non-trainable params
# 45.8 M    Total params
# 91.518    Total estimated model params size (MB)
# [NeMo W 2022-06-12 11:25:57 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:1937: PossibleUserWarning: The number of training batches (60) is smaller than the logging interval Trainer(log_every_n_steps=100). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#       category=PossibleUserWarning,
#
# Epoch 4:  94%|██████████▎| 60/64 [00:43<00:02,  1.38it/s, loss=7.02, v_num=3-19]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:  25%|█████               | 1/4 [00:00<00:00,  3.62it/s]
# Epoch 4:  95%|██████████▍| 61/64 [00:50<00:02,  1.22it/s, loss=7.02, v_num=3-19]
# Validation DataLoader 0:  50%|██████████          | 2/4 [00:00<00:00,  5.23it/s]
# Epoch 4:  97%|██████████▋| 62/64 [00:50<00:01,  1.23it/s, loss=7.02, v_num=3-19]
# Validation DataLoader 0:  75%|███████████████     | 3/4 [00:00<00:00,  5.55it/s]
# Epoch 4:  98%|██████████▊| 63/64 [00:50<00:00,  1.25it/s, loss=7.02, v_num=3-19]
# Epoch 4: 100%|███████████| 64/64 [00:50<00:00,  1.26it/s, loss=7.02, v_num=3-19]
#                                                                                 Epoch 4, global step 300: 'v_loss' reached 2.66522 (best 2.66522), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/FastPitch/2022-06-12_11-23-19/checkpoints/FastPitch--v_loss=2.6652-epoch=4.ckpt' as top 3
# Epoch 9:  94%|██████████▎| 60/64 [00:45<00:03,  1.32it/s, loss=6.46, v_num=3-19]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:  25%|█████               | 1/4 [00:00<00:00,  3.77it/s]
# Epoch 9:  95%|██████████▍| 61/64 [00:51<00:02,  1.17it/s, loss=6.46, v_num=3-19]
# Validation DataLoader 0:  50%|██████████          | 2/4 [00:00<00:00,  5.37it/s]
# Epoch 9:  97%|██████████▋| 62/64 [00:52<00:01,  1.19it/s, loss=6.46, v_num=3-19]
# Validation DataLoader 0:  75%|███████████████     | 3/4 [00:00<00:00,  5.71it/s]
# Epoch 9:  98%|██████████▊| 63/64 [00:52<00:00,  1.21it/s, loss=6.46, v_num=3-19]
# Epoch 9: 100%|███████████| 64/64 [00:52<00:00,  1.21it/s, loss=6.46, v_num=3-19]
#                                                                                 Epoch 9, global step 600: 'v_loss' reached 2.47327 (best 2.47327), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/FastPitch/2022-06-12_11-23-19/checkpoints/FastPitch--v_loss=2.4733-epoch=9.ckpt' as top 3
# Epoch 14:  94%|█████████▍| 60/64 [00:44<00:02,  1.36it/s, loss=6.39, v_num=3-19]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:  25%|█████               | 1/4 [00:00<00:00,  3.71it/s]
# Epoch 14:  95%|█████████▌| 61/64 [00:50<00:02,  1.21it/s, loss=6.39, v_num=3-19]
# Validation DataLoader 0:  50%|██████████          | 2/4 [00:00<00:00,  5.26it/s]
# Epoch 14:  97%|█████████▋| 62/64 [00:50<00:01,  1.23it/s, loss=6.39, v_num=3-19]
# Validation DataLoader 0:  75%|███████████████     | 3/4 [00:00<00:00,  5.61it/s]
# Epoch 14:  98%|█████████▊| 63/64 [00:50<00:00,  1.24it/s, loss=6.39, v_num=3-19]
# Epoch 14: 100%|██████████| 64/64 [00:51<00:00,  1.25it/s, loss=6.39, v_num=3-19]
#                                                                                 Epoch 14, global step 900: 'v_loss' reached 2.38419 (best 2.38419), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/FastPitch/2022-06-12_11-23-19/checkpoints/FastPitch--v_loss=2.3842-epoch=14.ckpt' as top 3
# Epoch 19:  94%|█████████▍| 60/64 [00:44<00:02,  1.35it/s, loss=6.21, v_num=3-19]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:  25%|█████               | 1/4 [00:00<00:00,  3.81it/s]
# Epoch 19:  95%|█████████▌| 61/64 [00:50<00:02,  1.20it/s, loss=6.21, v_num=3-19]
# Validation DataLoader 0:  50%|██████████          | 2/4 [00:00<00:00,  5.22it/s]
# Epoch 19:  97%|█████████▋| 62/64 [00:50<00:01,  1.22it/s, loss=6.21, v_num=3-19]
# Validation DataLoader 0:  75%|███████████████     | 3/4 [00:00<00:00,  5.60it/s]
# Epoch 19:  98%|█████████▊| 63/64 [00:50<00:00,  1.24it/s, loss=6.21, v_num=3-19]
# Epoch 19: 100%|██████████| 64/64 [00:51<00:00,  1.24it/s, loss=6.21, v_num=3-19]
#                                                                                 Epoch 19, global step 1200: 'v_loss' reached 2.36829 (best 2.36829), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/FastPitch/2022-06-12_11-23-19/checkpoints/FastPitch--v_loss=2.3683-epoch=19.ckpt' as top 3
# Epoch 24:  94%|█████████▍| 60/64 [00:43<00:02,  1.37it/s, loss=5.81, v_num=3-19]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:  25%|█████               | 1/4 [00:00<00:00,  3.77it/s]
# Epoch 24:  95%|█████████▌| 61/64 [00:50<00:02,  1.22it/s, loss=5.81, v_num=3-19]
# Validation DataLoader 0:  50%|██████████          | 2/4 [00:00<00:00,  5.30it/s]
# Epoch 24:  97%|█████████▋| 62/64 [00:50<00:01,  1.23it/s, loss=5.81, v_num=3-19]
# Validation DataLoader 0:  75%|███████████████     | 3/4 [00:00<00:00,  5.66it/s]
# Epoch 24:  98%|█████████▊| 63/64 [00:50<00:00,  1.25it/s, loss=5.81, v_num=3-19]
# Epoch 24: 100%|██████████| 64/64 [00:51<00:00,  1.25it/s, loss=5.81, v_num=3-19]
#                                                                                 Epoch 24, global step 1500: 'v_loss' reached 2.31704 (best 2.31704), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/FastPitch/2022-06-12_11-23-19/checkpoints/FastPitch--v_loss=2.3170-epoch=24.ckpt' as top 3
# Epoch 29:  94%|█████████▍| 60/64 [00:45<00:03,  1.33it/s, loss=5.61, v_num=3-19]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/4 [00:00<?, ?it/s]
# Validation DataLoader 0:  25%|█████               | 1/4 [00:00<00:00,  3.86it/s]
# Epoch 29:  95%|█████████▌| 61/64 [00:51<00:02,  1.19it/s, loss=5.61, v_num=3-19]
# Validation DataLoader 0:  50%|██████████          | 2/4 [00:00<00:00,  5.51it/s]
# Epoch 29:  97%|█████████▋| 62/64 [00:51<00:01,  1.21it/s, loss=5.61, v_num=3-19]
# Validation DataLoader 0:  75%|███████████████     | 3/4 [00:00<00:00,  5.79it/s]
# Epoch 29:  98%|█████████▊| 63/64 [00:51<00:00,  1.22it/s, loss=5.61, v_num=3-19]
# Epoch 29: 100%|██████████| 64/64 [00:52<00:00,  1.23it/s, loss=5.61, v_num=3-19]
#                                                                                 Epoch 29, global step 1800: 'v_loss' reached 2.34199 (best 2.31704), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/FastPitch/2022-06-12_11-23-19/checkpoints/FastPitch--v_loss=2.3420-epoch=29.ckpt' as top 3
# Epoch 33:  33%|███▎      | 20/60 [00:20<00:41,  1.03s/it, loss=5.42, v_num=3-19]

# %%
print("DONE")

# %%
FP_chck_pt = "./trixie_logs_fp/FastPitch/2022-06-12_08-12-40/checkpoints/FastPitch--v_loss=2.4638-epoch=24-last.ckpt"
spec_model = FastPitchModel.load_from_checkpoint(FP_chck_pt)
spec_model.eval().cuda()
# Out:
# [NeMo I 2022-06-12 09:12:39 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-12 09:13:11 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-06-12 09:13:11 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 12
#       pin_memory: true
#
# [NeMo W 2022-06-12 09:13:11 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 8
#       pin_memory: true
# [NeMo I 2022-06-12 09:13:11 features:200] PADDING: 1
# FastPitchModel(
#   (mel_loss): MelLoss()
#   (pitch_loss): PitchLoss()
#   (duration_loss): DurationLoss()
#   (aligner): AlignmentEncoder(
#     (softmax): Softmax(dim=3)
#     (log_softmax): LogSoftmax(dim=3)
#     (key_proj): Sequential(
#       (0): ConvNorm(
#         (conv): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (1): ReLU()
#       (2): ConvNorm(
#         (conv): Conv1d(768, 80, kernel_size=(1,), stride=(1,))
#       )
#     )
#     (query_proj): Sequential(
#       (0): ConvNorm(
#         (conv): Conv1d(80, 160, kernel_size=(3,), stride=(1,), padding=(1,))
#       )
#       (1): ReLU()
#       (2): ConvNorm(
#         (conv): Conv1d(160, 80, kernel_size=(1,), stride=(1,))
#       )
#       (3): ReLU()
#       (4): ConvNorm(
#         (conv): Conv1d(80, 80, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (forward_sum_loss): ForwardSumLoss(
#     (log_softmax): LogSoftmax(dim=3)
#     (ctc_loss): CTCLoss()
#   )
#   (bin_loss): BinLoss()
#   (preprocessor): AudioToMelSpectrogramPreprocessor(
#     (featurizer): FilterbankFeatures()
#   )
#   (fastpitch): FastPitchModule(
#     (encoder): FFTransformerEncoder(
#       (pos_emb): PositionalEmbedding()
#       (drop): Dropout(p=0.0, inplace=False)
#       (layers): ModuleList(
#         (0): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (word_emb): Embedding(115, 384, padding_idx=112)
#     )
#     (decoder): FFTransformerDecoder(
#       (pos_emb): PositionalEmbedding()
#       (drop): Dropout(p=0.0, inplace=False)
#       (layers): ModuleList(
#         (0): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (1): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (2): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (3): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (4): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#         (5): TransformerLayer(
#           (dec_attn): MultiHeadAttn(
#             (qkv_net): Linear(in_features=384, out_features=192, bias=True)
#             (drop): Dropout(p=0.1, inplace=False)
#             (dropatt): Dropout(p=0.1, inplace=False)
#             (o_net): Linear(in_features=64, out_features=384, bias=False)
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#           (pos_ff): PositionwiseConvFF(
#             (CoreNet): Sequential(
#               (0): Conv1d(384, 1536, kernel_size=(3,), stride=(1,), padding=(1,))
#               (1): ReLU()
#               (2): Conv1d(1536, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#               (3): Dropout(p=0.1, inplace=False)
#             )
#             (layer_norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#     )
#     (duration_predictor): TemporalPredictor(
#       (layers): Sequential(
#         (0): ConvReLUNorm(
#           (conv): Conv1d(384, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (1): ConvReLUNorm(
#           (conv): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (fc): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (pitch_predictor): TemporalPredictor(
#       (layers): Sequential(
#         (0): ConvReLUNorm(
#           (conv): Conv1d(384, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#         (1): ConvReLUNorm(
#           (conv): Conv1d(256, 256, kernel_size=(3,), stride=(1,), padding=(1,))
#           (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (fc): Linear(in_features=256, out_features=1, bias=True)
#     )
#     (aligner): AlignmentEncoder(
#       (softmax): Softmax(dim=3)
#       (log_softmax): LogSoftmax(dim=3)
#       (key_proj): Sequential(
#         (0): ConvNorm(
#           (conv): Conv1d(384, 768, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ReLU()
#         (2): ConvNorm(
#           (conv): Conv1d(768, 80, kernel_size=(1,), stride=(1,))
#         )
#       )
#       (query_proj): Sequential(
#         (0): ConvNorm(
#           (conv): Conv1d(80, 160, kernel_size=(3,), stride=(1,), padding=(1,))
#         )
#         (1): ReLU()
#         (2): ConvNorm(
#           (conv): Conv1d(160, 80, kernel_size=(1,), stride=(1,))
#         )
#         (3): ReLU()
#         (4): ConvNorm(
#           (conv): Conv1d(80, 80, kernel_size=(1,), stride=(1,))
#         )
#       )
#     )
#     (pitch_emb): Conv1d(1, 384, kernel_size=(3,), stride=(1,), padding=(1,))
#     (proj): Linear(in_features=384, out_features=80, bias=True)
#   )
# )

# %%
vocoder = HifiGanModel.from_pretrained("tts_hifigan")
vocoder = vocoder.eval().cuda()

#getting the pre-trained model for hifigan
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_hifigan.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_hifigan.nemo").write_bytes(nemo_files[0].read_bytes())
# Out:
# [NeMo I 2022-06-12 09:13:40 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/tts_hifigan/versions/1.0.0rc1/files/tts_hifigan.nemo to /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# 100% [......................................................................] 315386678 / 315386678[NeMo I 2022-06-12 09:13:49 common:789] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-06-12 09:13:52 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-06-12 09:13:52 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-06-12 09:13:52 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-12 09:13:52 features:200] PADDING: 0
# [NeMo W 2022-06-12 09:13:52 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-12 09:13:52 features:200] PADDING: 0
# [NeMo I 2022-06-12 09:13:53 save_restore_connector:243] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# Copying /root/.cache/torch/NeMo/NeMo_1.10.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo to ./
# 315386678

# %%
def infer(spec_gen_model, vocoder_model, str_input, speaker=None):
    """
    Synthesizes spectrogram and audio from a text string given a spectrogram synthesis and vocoder model.
    
    Args:
        spec_gen_model: Spectrogram generator model (FastPitch in our case)
        vocoder_model: Vocoder model (HiFiGAN in our case)
        str_input: Text input for the synthesis
        speaker: Speaker ID
    
    Returns:
        spectrogram and waveform of the synthesized audio.
    """
    with torch.no_grad():
        parsed = spec_gen_model.parse(str_input)
        if speaker is not None:
            speaker = torch.tensor([speaker]).long().to(device=spec_gen_model.device)
        spectrogram = spec_gen_model.generate_spectrogram(tokens=parsed, speaker=speaker)
        audio = vocoder_model.convert_spectrogram_to_audio(spec=spectrogram)
        
    if spectrogram is not None:
        if isinstance(spectrogram, torch.Tensor):
            spectrogram = spectrogram.to('cpu').numpy()
        if len(spectrogram.shape) == 3:
            spectrogram = spectrogram[0]
    if isinstance(audio, torch.Tensor):
        audio = audio.to('cpu').numpy()
    return spectrogram, audio

# %%
spec, audio = infer(spec_model, vocoder,"Hello Alex, how are you doing today ?")
print("\n\n\n\n")
ipd.display(ipd.Audio(audio, rate=22050))
# %matplotlib inline
#imshow(spec, origin="lower", aspect="auto")
plt.show()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Fine tuning HiFiGAN

# %%
#helper functions
def load_wav(audio_file, target_sr=None):
    with sf.SoundFile(audio_file, 'r') as f:
        samples = f.read(dtype='float32')
        sample_rate = f.samplerate
        if target_sr is not None and target_sr != sample_rate:
            samples = librosa.core.resample(samples, orig_sr=sample_rate, target_sr=target_sr)
    return samples.transpose()

# %%
from nemo.collections.tts.torch.helpers import BetaBinomialInterpolator
import librosa
import soundfile as sf
import numpy as np

# %%
#dataset preparation
# Get records from the training manifest
manifest_path = "./fastpitch_train.json"
records = []
with open(manifest_path, "r") as f:
    for i, line in enumerate(f):
        records.append(json.loads(line))

beta_binomial_interpolator = BetaBinomialInterpolator()
spec_model.eval()

device = spec_model.device

save_dir = Path("./train_mels")
save_dir.mkdir(exist_ok=True, parents=True)

# Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
for i, r in enumerate(records):
    audio = load_wav(r["audio_filepath"])
    audio = torch.from_numpy(audio).unsqueeze(0).to(device)
    audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)
    
        
    with torch.no_grad():
        if "normalized_text" in r:
            text = spec_model.parse(r["normalized_text"], normalize=False)
        else:
            text = spec_model.parse(r['text'])
        
        text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)
    
        spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

        # Generate attention prior and spectrogram inputs for HiFi-GAN
        attn_prior = torch.from_numpy(
          beta_binomial_interpolator(spect_len.item(), text_len.item())
        ).unsqueeze(0).to(text.device)
            
        spectrogram = spec_model.forward(
          text=text, 
          input_lens=text_len, 
          spec=spect, 
          mel_lens=spect_len, 
          attn_prior=attn_prior,
        )[0]
        
        save_path = save_dir / f"mel_{i}.npy"
        np.save(save_path, spectrogram[0].to('cpu').numpy())
        r["mel_filepath"] = str(save_path)

hifigan_manifest_path = "hifigan_train_ft.json"
with open(hifigan_manifest_path, "w") as f:
    for r in records:
        f.write(json.dumps(r) + '\n')

# %%
# Get records from the training manifest
manifest_path_validation = "./fastpitch_val.json"
records_val = []
with open(manifest_path_validation, "r") as f:
    for i, line in enumerate(f):
        records_val.append(json.loads(line))

save_dir_val = Path("./dev_mels")
save_dir_val.mkdir(exist_ok=True, parents=True)

# Generate a spectrograms (we need to use ground truth alignment for correct matching between audio and mels)
for i, r in enumerate(records_val):
    audio = load_wav(r["audio_filepath"])
    audio = torch.from_numpy(audio).unsqueeze(0).to(device)
    audio_len = torch.tensor(audio.shape[1], dtype=torch.long, device=device).unsqueeze(0)
    
       
    with torch.no_grad():
        if "normalized_text" in r:
            text = spec_model.parse(r["normalized_text"], normalize=False)
        else:
            text = spec_model.parse(r['text'])
        
        text_len = torch.tensor(text.shape[-1], dtype=torch.long, device=device).unsqueeze(0)
    
        spect, spect_len = spec_model.preprocessor(input_signal=audio, length=audio_len)

        # Generate attention prior and spectrogram inputs for HiFi-GAN
        attn_prior = torch.from_numpy(
          beta_binomial_interpolator(spect_len.item(), text_len.item())
        ).unsqueeze(0).to(text.device)
            
        spectrogram = spec_model.forward(
          text=text, 
          input_lens=text_len, 
          spec=spect, 
          mel_lens=spect_len, 
          attn_prior=attn_prior,
        )[0]
        
        save_path_val = save_dir_val / f"mel_{i}.npy"
        np.save(save_path_val, spectrogram[0].to('cpu').numpy())
        r["mel_filepath"] = str(save_path_val)

hifigan_val_manifest_path = "hifigan_val_ft.json"
with open(hifigan_val_manifest_path, "w") as f:
    for r in records_val:
        f.write(json.dumps(r) + '\n')

# %%
! mv hifigan.zip -t ./conf/
! cd conf && unzip hifigan.zip && cd ..
! wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/hifigan_finetune.py
! cd conf && cd hifigan && wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/hifigan/hifigan.yaml && cd .. && cd ..
# Out:
# Archive:  hifigan.zip
#    creating: hifigan/
#    creating: hifigan/model/
#    creating: hifigan/model/validation_ds/
#  extracting: hifigan/model/validation_ds/val_ds.yaml
#  extracting: hifigan/model/validation_ds/val_ds_finetune.yaml
#    creating: hifigan/model/train_ds/
#  extracting: hifigan/model/train_ds/train_ds.yaml
#  extracting: hifigan/model/train_ds/train_ds_finetune.yaml
#    creating: hifigan/model/generator/
#  extracting: hifigan/model/generator/v1.yaml
#  extracting: hifigan/model/generator/v1_44100.yaml
#  extracting: hifigan/model/generator/v2.yaml
#  extracting: hifigan/model/generator/v3.yaml
#  extracting: hifigan/hifigan.yaml
#  extracting: hifigan/hifigan_44100.yaml
# --2022-06-12 09:25:48--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/hifigan_finetune.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1192 (1.2K) [text/plain]
# Saving to: ‘hifigan_finetune.py’
#
# hifigan_finetune.py 100%[===================>]   1.16K  --.-KB/s    in 0s
#
# 2022-06-12 09:25:48 (65.5 MB/s) - ‘hifigan_finetune.py’ saved [1192/1192]
#
# --2022-06-12 09:25:49--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/hifigan/hifigan.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2245 (2.2K) [text/plain]
# Saving to: ‘hifigan.yaml.1’
#
# hifigan.yaml.1      100%[===================>]   2.19K  --.-KB/s    in 0s
#
# 2022-06-12 09:25:49 (48.9 MB/s) - ‘hifigan.yaml.1’ saved [2245/2245]

# %%
del spec_model
del vocoder

# %%
#finetuning the hifigan model
!(python hifigan_finetune.py \
--config-name=hifigan.yaml \
model.train_ds.dataloader_params.batch_size=16 \
model.max_steps=1000 \
model.optim.lr=0.0002 \
~model.optim.sched \
train_dataset=./hifigan_train_ft.json \
validation_datasets=./hifigan_val_ft.json \
exp_manager.exp_dir=trixie_logs_fp \
+init_from_nemo_model=tts_hifigan.nemo \
trainer.check_val_every_n_epoch=2 \
)
# Out:
# [NeMo W 2022-06-12 09:55:15 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-06-12 09:55:15 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-06-12 09:55:16 exp_manager:287] Experiments will be logged at trixie_logs_fp/HifiGan/2022-06-12_09-55-16
# [NeMo I 2022-06-12 09:55:16 exp_manager:661] TensorboardLogger has been set up
# [NeMo W 2022-06-12 09:55:16 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo W 2022-06-12 09:55:16 exp_manager:896] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 1000. Please ensure that max_steps will run for at least 2 epochs to ensure that checkpointing will not error out.
# Created a temporary directory at /tmp/tmpkfzw9umo
# Writing /tmp/tmpkfzw9umo/_remote_module_non_sriptable.py
# [NeMo I 2022-06-12 09:55:16 data:846] Loading dataset from ./hifigan_train_ft.json.
# 948it [00:00, 172234.26it/s]
# [NeMo I 2022-06-12 09:55:16 data:870] Loaded dataset with 948 files.
# [NeMo I 2022-06-12 09:55:16 data:872] Dataset contains 0.88 hours.
# [NeMo I 2022-06-12 09:55:16 data:315] Pruned 0 files. Final dataset contains 948 files
# [NeMo I 2022-06-12 09:55:16 data:318] Pruned 0.00 hours. Final dataset contains 0.88 hours.
# [NeMo I 2022-06-12 09:55:16 data:846] Loading dataset from ./hifigan_val_ft.json.
# 50it [00:00, 155575.07it/s]
# [NeMo I 2022-06-12 09:55:16 data:870] Loaded dataset with 50 files.
# [NeMo I 2022-06-12 09:55:16 data:872] Dataset contains 0.05 hours.
# [NeMo I 2022-06-12 09:55:16 data:315] Pruned 23 files. Final dataset contains 27 files
# [NeMo I 2022-06-12 09:55:16 data:318] Pruned 0.01 hours. Final dataset contains 0.04 hours.
# [NeMo I 2022-06-12 09:55:16 features:200] PADDING: 0
# [NeMo I 2022-06-12 09:55:16 features:208] STFT using exact pad
# [NeMo I 2022-06-12 09:55:16 features:200] PADDING: 0
# [NeMo I 2022-06-12 09:55:16 features:208] STFT using exact pad
# [NeMo W 2022-06-12 09:55:20 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-06-12 09:55:20 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-06-12 09:55:20 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-12 09:55:20 features:200] PADDING: 0
# [NeMo W 2022-06-12 09:55:20 features:178] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-06-12 09:55:20 features:200] PADDING: 0
# [NeMo I 2022-06-12 09:55:21 save_restore_connector:243] Model HifiGanModel was successfully restored from /home/deepankaracharyya/TTS-exp/Dataset/audio/tts_hifigan.nemo.
# [NeMo I 2022-06-12 09:55:21 modelPT:991] Model checkpoint restored from nemo file with path : `tts_hifigan.nemo`
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name                       | Type                     | Params
# ------------------------------------------------------------------------
# 0 | audio_to_melspec_precessor | FilterbankFeatures       | 0
# 1 | trg_melspec_fn             | FilterbankFeatures       | 0
# 2 | generator                  | Generator                | 13.9 M
# 3 | mpd                        | MultiPeriodDiscriminator | 41.1 M
# 4 | msd                        | MultiScaleDiscriminator  | 29.6 M
# 5 | feature_loss               | FeatureMatchingLoss      | 0
# 6 | discriminator_loss         | DiscriminatorLoss        | 0
# 7 | generator_loss             | GeneratorLoss            | 0
# ------------------------------------------------------------------------
# 84.7 M    Trainable params
# 0         Non-trainable params
# 84.7 M    Total params
# 338.643   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s][NeMo W 2022-06-12 09:55:24 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:245: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 16 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       category=PossibleUserWarning,
#
# Sanity Checking DataLoader 0:   0%|                       | 0/2 [00:00<?, ?it/s][NeMo W 2022-06-12 09:55:25 nemo_logging:349] /usr/local/lib/python3.7/site-packages/torch/functional.py:696: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:798.)
#       normalized, onesided, return_complex)
#
# [NeMo W 2022-06-12 09:55:26 nemo_logging:349] /usr/local/lib/python3.7/site-packages/torch/functional.py:771: UserWarning: istft will require a complex-valued input tensor in a future PyTorch release. Matching the output from stft with return_complex=True.  (Triggered internally at  ../aten/src/ATen/native/SpectralOps.cpp:950.)
#       normalized, onesided, length, return_complex)
#
# [NeMo W 2022-06-12 09:55:27 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:1937: PossibleUserWarning: The number of training batches (60) is smaller than the logging interval Trainer(log_every_n_steps=100). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#       category=PossibleUserWarning,
#
# Epoch 0:   0%|                                           | 0/60 [00:00<?, ?it/s][W reducer.cpp:1289] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
# [NeMo W 2022-06-12 09:55:30 nemo_logging:349] /usr/local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:231: UserWarning: You called `self.log('global_step', ...)` in your `training_step` but the value needs to be floating point. Converting it to torch.float32.
#       f"You called `self.log({self.meta.name!r}, ...)` in your `{self.meta.fx}` but the value needs to"
#
# Epoch 1:  97%|████▊| 60/62 [02:11<00:04,  2.19s/it, v_num=5-16, g_l1_loss=0.348]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|██████████          | 1/2 [00:01<00:01,  1.79s/it]
# Epoch 1:  98%|████▉| 61/62 [02:13<00:02,  2.18s/it, v_num=5-16, g_l1_loss=0.348]
# Validation DataLoader 0: 100%|████████████████████| 2/2 [00:03<00:00,  1.49s/it]
# Epoch 1: 100%|█████| 62/62 [02:14<00:00,  2.17s/it, v_num=5-16, g_l1_loss=0.348]
#                                                                                 Epoch 1, global step 240: 'val_loss' reached 0.48357 (best 0.48357), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/HifiGan/2022-06-12_09-55-16/checkpoints/HifiGan--val_loss=0.4836-epoch=1.ckpt' as top 3
# Epoch 3:  97%|████▊| 60/62 [02:11<00:04,  2.19s/it, v_num=5-16, g_l1_loss=0.368]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|██████████          | 1/2 [00:01<00:01,  1.79s/it]
# Epoch 3:  98%|████▉| 61/62 [02:13<00:02,  2.18s/it, v_num=5-16, g_l1_loss=0.368]
# Validation DataLoader 0: 100%|████████████████████| 2/2 [00:03<00:00,  1.49s/it]
# Epoch 3: 100%|█████| 62/62 [02:14<00:00,  2.17s/it, v_num=5-16, g_l1_loss=0.368]
#                                                                                 Epoch 3, global step 480: 'val_loss' reached 0.46698 (best 0.46698), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/HifiGan/2022-06-12_09-55-16/checkpoints/HifiGan--val_loss=0.4670-epoch=3.ckpt' as top 3
# Epoch 5:  97%|████▊| 60/62 [02:11<00:04,  2.19s/it, v_num=5-16, g_l1_loss=0.435]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|██████████          | 1/2 [00:01<00:01,  1.79s/it]
# Epoch 5:  98%|████▉| 61/62 [02:13<00:02,  2.18s/it, v_num=5-16, g_l1_loss=0.435]
# Validation DataLoader 0: 100%|████████████████████| 2/2 [00:03<00:00,  1.48s/it]
# Epoch 5: 100%|█████| 62/62 [02:14<00:00,  2.17s/it, v_num=5-16, g_l1_loss=0.435]
#                                                                                 Epoch 5, global step 720: 'val_loss' reached 0.45782 (best 0.45782), saving model to '/home/deepankaracharyya/TTS-exp/Dataset/audio/trixie_logs_fp/HifiGan/2022-06-12_09-55-16/checkpoints/HifiGan--val_loss=0.4578-epoch=5.ckpt' as top 3
# Epoch 7:  97%|████▊| 60/62 [02:11<00:04,  2.19s/it, v_num=5-16, g_l1_loss=0.398]
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                            | 0/2 [00:00<?, ?it/s]
# Validation DataLoader 0:  50%|██████████          | 1/2 [00:01<00:01,  1.80s/it]
# Epoch 7:  98%|████▉| 61/62 [02:13<00:02,  2.18s/it, v_num=5-16, g_l1_loss=0.398]
# Validation DataLoader 0: 100%|████████████████████| 2/2 [00:03<00:00,  1.49s/it]
# Epoch 7: 100%|█████| 62/62 [02:14<00:00,  2.17s/it, v_num=5-16, g_l1_loss=0.398]
#                                                                                 Epoch 7, global step 960: 'val_loss' was not in top 3
# Epoch 8:  33%|█▋   | 20/60 [00:44<01:29,  2.23s/it, v_num=5-16, g_l1_loss=0.368]

# %%
print("DONE")
# Out:
# DONE

# %%
# !cp ./trixie_logs_fp/FastPitch/2022-06-12_08-12-40/checkpoints/FastPitch--v_loss=2.4638-epoch=24-last.ckpt -t /home/deepankaracharyya/TTS-exp/Model-checkpoints/Iteration-01_Trixie_Whole_Data
# !cp ./trixie_logs_fp/HifiGan/2022-06-12_09-55-16/checkpoints/HifiGan--val_loss=0.4848-epoch=7-last.ckpt -t  /home/deepankaracharyya/TTS-exp/Model-checkpoints/Iteration-01_Trixie_Whole_Data

# %%
FP_chck_pt = "./trixie_logs_fp/FastPitch/2022-06-12_08-12-40/checkpoints/FastPitch--v_loss=2.4638-epoch=24-last.ckpt"
spec_model = FastPitchModel.load_from_checkpoint(FP_chck_pt)
spec_model.eval().cuda()

HFG_chck_pt = "./trixie_logs_fp/HifiGan/2022-06-12_09-55-16/checkpoints/HifiGan--val_loss=0.4848-epoch=7-last.ckpt"
vocoder = HifiGanModel.load_from_checkpoint(HFG_chck_pt)
vocoder = vocoder.eval().cuda()
# Out:
# [NeMo I 2022-06-12 10:17:27 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-06-12 10:18:02 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-06-12 10:18:02 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 12
#       pin_memory: true
#
# [NeMo W 2022-06-12 10:18:02 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: ./fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: ./fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 30
#       pitch_fmax: 512
#       pitch_norm: true
#       pitch_mean: 121.9
#       pitch_std: 23.1
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 8
#       pin_memory: true
# [NeMo I 2022-06-12 10:18:02 features:200] PADDING: 1
# [NeMo W 2022-06-12 10:18:03 modelPT:149] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.VocoderDataset
#       manifest_filepath: ./hifigan_train_ft.json
#       sample_rate: 22050
#       n_segments: 8192
#       max_duration: null
#       min_duration: 0.75
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 16
#       num_workers: 4
#
# [NeMo W 2022-06-12 10:18:03 modelPT:156] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.VocoderDataset
#       manifest_filepath: ./hifigan_val_ft.json
#       sample_rate: 22050
#       n_segments: 66048
#       max_duration: null
#       min_duration: 3
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 16
#       num_workers: 1
# [NeMo I 2022-06-12 10:18:03 features:200] PADDING: 0
# [NeMo I 2022-06-12 10:18:03 features:208] STFT using exact pad
# [NeMo I 2022-06-12 10:18:03 features:200] PADDING: 0
# [NeMo I 2022-06-12 10:18:03 features:208] STFT using exact pad

# %%
def custom_infer(transcript, spec_model, vocoder):
  spec, audio = infer(spec_model, vocoder, transcript)
  print("\n\n\n\n")
  ipd.display(ipd.Audio(audio, rate=22050))
  # %matplotlib inline
  plt.show()

# %%
custom_infer("Its a wonderful day to train some models", spec_model, vocoder)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pwd
# Out:
# /home/deepankaracharyya/TTS-exp/Dataset/audio
