# %% [markdown]
# ## Setting up the environment

# %%
# !pip install hydra-core==1.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hydra-core==1.1 in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: omegaconf==2.1.* in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (2.1.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (5.8.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core==1.1) (4.8)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.7/dist-packages (from omegaconf==2.1.*->hydra-core==1.1) (5.4.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources->hydra-core==1.1) (3.8.1)

# %%
# !pip install scipy==1.7.3

BRANCH = 'main'
# If you're using Google Colab and not running locally, uncomment and run this cell.
# !apt-get install sox libsndfile1 ffmpeg
# !pip install wget unidecode pynini==2.1.4
# !python -m pip install git+https://github.com/NVIDIA/NeMo.git@$BRANCH#egg=nemo_toolkit[all]

#=== load the repo and data (Thanks Synthbot) ===
# !sudo dpkg --configure -a
# !sudo apt -qq install -y sox
# !git clone "https://github.com/synthbot-anon/synthbot.git" /content/synthbot
!(cd /content/synthbot; git checkout experimental)
# !python3 -m pip install pysoundfile 
# !python3 -m pip install librosa

# !jupyter nbextension enable --py --sys-prefix widgetsnbextension
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scipy==1.7.3 in /usr/local/lib/python3.7/dist-packages (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy==1.7.3) (1.21.6)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libsndfile1 is already the newest version (1.0.28-4ubuntu0.18.04.2).
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3
# Suggested packages:
#   file libsox-fmt-all
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1 libopencore-amrnb0 libopencore-amrwb0 libsox-fmt-alsa
#   libsox-fmt-base libsox3 sox
# 0 upgraded, 8 newly installed, 0 to remove and 49 not upgraded.
# Need to get 760 kB of archives.
# After this operation, 6,717 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrnb0 amd64 0.1.3-2.1 [92.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopencore-amrwb0 amd64 0.1.3-2.1 [45.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox3 amd64 14.4.2-3ubuntu0.18.04.1 [226 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-alsa amd64 14.4.2-3ubuntu0.18.04.1 [10.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsox-fmt-base amd64 14.4.2-3ubuntu0.18.04.1 [32.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 sox amd64 14.4.2-3ubuntu0.18.04.1 [101 kB]
# Fetched 760 kB in 0s (2,043 kB/s)
# Selecting previously unselected package libopencore-amrnb0:amd64.
# (Reading database ... 155653 files and directories currently installed.)
# Preparing to unpack .../0-libopencore-amrnb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../1-libopencore-amrwb0_0.1.3-2.1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Selecting previously unselected package libmagic-mgc.
# Preparing to unpack .../2-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../3-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libsox3:amd64.
# Preparing to unpack .../4-libsox3_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-alsa:amd64.
# Preparing to unpack .../5-libsox-fmt-alsa_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package libsox-fmt-base:amd64.
# Preparing to unpack .../6-libsox-fmt-base_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Selecting previously unselected package sox.
# Preparing to unpack .../7-sox_14.4.2-3ubuntu0.18.04.1_amd64.deb ...
# Unpacking sox (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopencore-amrnb0:amd64 (0.1.3-2.1) ...
# Setting up libopencore-amrwb0:amd64 (0.1.3-2.1) ...
# Setting up libsox3:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-base:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up libsox-fmt-alsa:amd64 (14.4.2-3ubuntu0.18.04.1) ...
# Setting up sox (14.4.2-3ubuntu0.18.04.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.0 MB/s
# Collecting pynini==2.1.4
#   Downloading pynini-2.1.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (165.5 MB)
#      |████████████████████████████████| 165.5 MB 51 kB/s
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from pynini==2.1.4) (0.29.30)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=bd030dd65ba5d0541ce5b26eec3e4676b2af45575f48cc41ed27f7e6436dff3a
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget, unidecode, pynini
# Successfully installed pynini-2.1.4 unidecode-1.3.4 wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nemo_toolkit[all]
#   Cloning https://github.com/NVIDIA/NeMo.git (to revision main) to /tmp/pip-install-2l6enyyb/nemo-toolkit_d0b1aba6cb214a559b9e5c3eef53303b
#   Running command git clone -q https://github.com/NVIDIA/NeMo.git /tmp/pip-install-2l6enyyb/nemo-toolkit_d0b1aba6cb214a559b9e5c3eef53303b
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 4.9 MB/s
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.21.6)
# Collecting onnx>=1.7.0
#   Downloading onnx-1.12.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#      |████████████████████████████████| 13.1 MB 85.6 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.8.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.12.0+cu113)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.14.1)
# Collecting ruamel.yaml
#   Downloading ruamel.yaml-0.17.21-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 98.4 MB/s
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.0.2)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.64.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.51.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2)
# Collecting frozendict
#   Downloading frozendict-2.3.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (99 kB)
#      |████████████████████████████████| 99 kB 12.2 MB/s
# Requirement already satisfied: unidecode in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.4)
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 14.7 MB/s
# Collecting black==19.10b0
#   Downloading black-19.10b0-py36-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 9.0 MB/s
# Collecting isort[requirements]<5
#   Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.3 MB/s
# Collecting parameterized
#   Downloading parameterized-0.8.1-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.6.4)
# Collecting pytest-runner
#   Using cached pytest_runner-6.0.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.8.6)
# Collecting sphinxcontrib-bibtex
#   Downloading sphinxcontrib_bibtex-2.4.2-py3-none-any.whl (39 kB)
# Collecting wandb
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 82.5 MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2022.6.2)
# Requirement already satisfied: pynini==2.1.4 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.4)
# Collecting transformers>=4.0.1
#   Downloading transformers-4.21.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 78.8 MB/s
# Collecting pytorch-lightning>=1.6.1
#   Downloading pytorch_lightning-1.6.5-py3-none-any.whl (585 kB)
#      |████████████████████████████████| 585 kB 80.4 MB/s
# Collecting torchmetrics>=0.4.1rc0
#   Downloading torchmetrics-0.9.3-py3-none-any.whl (419 kB)
#      |████████████████████████████████| 419 kB 97.2 MB/s
# Collecting webdataset<=0.1.62,>=0.1.48
#   Downloading webdataset-0.1.62-py3-none-any.whl (32 kB)
# Requirement already satisfied: omegaconf<2.2,>=2.1.2 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (2.1.2)
# Requirement already satisfied: hydra-core<1.2,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.1.0)
# Collecting pyyaml<6
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 76.6 MB/s
# Collecting sentencepiece<1.0.0
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 70.5 MB/s
# Collecting youtokentome>=1.0.5
#   Downloading youtokentome-1.0.6-cp37-cp37m-manylinux2010_x86_64.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 72.5 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.3.5)
# Collecting sacremoses>=0.0.43
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 92.1 MB/s
# Collecting braceexpand
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Requirement already satisfied: editdistance in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.5.3)
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.8.1)
# Collecting marshmallow
#   Downloading marshmallow-3.17.0-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 6.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (21.3)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.10.3.post1)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting kaldi-python-io
#   Downloading kaldi-python-io-1.2.2.tar.gz (8.8 kB)
# Collecting kaldiio
#   Downloading kaldiio-2.17.2.tar.gz (24 kB)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (1.7.3)
# Collecting g2p_en
#   Downloading g2p_en-2.1.0-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 72.2 MB/s
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting pyannote.core
#   Downloading pyannote.core-4.4-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 5.6 MB/s
# Collecting pyannote.metrics
#   Downloading pyannote.metrics-3.2.1-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 202 kB/s
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (7.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.13.0+cu113)
# Collecting boto3
#   Downloading boto3-1.24.38-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 93.8 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.1.0)
# Collecting matplotlib>=3.3.2
#   Downloading matplotlib-3.5.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 72.1 MB/s
# Collecting rapidfuzz
#   Downloading rapidfuzz-2.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 83.7 MB/s
# Requirement already satisfied: gdown in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (4.4.0)
# Collecting sacrebleu[ja]
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      |████████████████████████████████| 116 kB 100.0 MB/s
# Requirement already satisfied: nltk>=3.6.5 in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (3.7)
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 9.1 MB/s
# Collecting opencc
#   Downloading OpenCC-1.1.4-cp37-cp37m-manylinux1_x86_64.whl (769 kB)
#      |████████████████████████████████| 769 kB 87.6 MB/s
# Collecting pangu
#   Downloading pangu-4.0.6.1-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: jieba in /usr/local/lib/python3.7/dist-packages (from nemo_toolkit[all]) (0.42.1)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.3 MB/s
# Collecting flask_restful
#   Downloading Flask_RESTful-0.3.9-py2.py3-none-any.whl (25 kB)
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting ijson
#   Downloading ijson-3.1.4-cp37-cp37m-manylinux2010_x86_64.whl (126 kB)
#      |████████████████████████████████| 126 kB 104.3 MB/s
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 84.5 MB/s
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      |████████████████████████████████| 85 kB 6.2 MB/s
# Collecting pypinyin
#   Downloading pypinyin-0.46.0-py2.py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 66.0 MB/s
# Collecting attrdict
#   Downloading attrdict-2.0.1-py2.py3-none-any.whl (9.9 kB)
# Collecting pystoi
#   Downloading pystoi-0.3.3.tar.gz (7.0 kB)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (21.4.0)
# Collecting typed-ast>=1.4.0
#   Downloading typed_ast-1.5.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (843 kB)
#      |████████████████████████████████| 843 kB 82.8 MB/s
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (1.4.4)
# Collecting pathspec<1,>=0.6
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: click>=6.5 in /usr/local/lib/python3.7/dist-packages (from black==19.10b0->nemo_toolkit[all]) (7.1.2)
# Collecting toml>=0.9.4
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: Cython>=0.29 in /usr/local/lib/python3.7/dist-packages (from pynini==2.1.4->nemo_toolkit[all]) (0.29.30)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.2,>=1.1.0->nemo_toolkit[all]) (5.8.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.2,>=1.1.0->nemo_toolkit[all]) (4.8)
# Collecting pip-api
#   Downloading pip_api-0.0.30-py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 94.9 MB/s
# Collecting pipreqs
#   Downloading pipreqs-0.4.11-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: protobuf<=3.20.1,>=3.12.2 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.7/dist-packages (from onnx>=1.7.0->nemo_toolkit[all]) (4.1.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf<=3.20.1,>=3.12.2->onnx>=1.7.0->nemo_toolkit[all]) (1.15.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.8.0)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 101.0 MB/s
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 61.8 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->nemo_toolkit[all]) (3.0.9)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses>=0.0.43->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.4.6)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.2.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.35.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.47.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.8.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (3.2.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 58.1 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.0.1->nemo_toolkit[all]) (3.7.1)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 98.8 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (2.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 97.9 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.8 MB/s
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 11.1 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting botocore<1.28.0,>=1.27.38
#   Downloading botocore-1.27.38-py3-none-any.whl (9.0 MB)
#      |████████████████████████████████| 9.0 MB 57.3 MB/s
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 96.4 MB/s
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.0-py3-none-any.whl (213 kB)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (2022.1)
# Collecting aniso8601>=0.82
#   Downloading aniso8601-9.0.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.8 MB/s
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_restful->nemo_toolkit[all]) (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (1.1.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask_restful->nemo_toolkit[all]) (2.0.1)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->nemo_toolkit[all]) (0.2.5)
# Collecting distance>=0.1.3
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      |████████████████████████████████| 180 kB 108.5 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from gdown->nemo_toolkit[all]) (4.6.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->nemo_toolkit[all]) (1.5.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (4.10.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (3.6.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets->nemo_toolkit[all]) (5.5.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (5.3.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.4.2)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets->nemo_toolkit[all]) (1.0.18)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.3.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.13.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.6.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.11.1)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->nemo_toolkit[all]) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.0)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (0.3.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (1.6.0)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa->nemo_toolkit[all]) (2.1.9)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba->nemo_toolkit[all]) (0.34.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->nemo_toolkit[all]) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile->nemo_toolkit[all]) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile->nemo_toolkit[all]) (2.21)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->nemo_toolkit[all]) (0.11.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (5.0.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (4.3.3)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (2.16.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.18.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->nemo_toolkit[all]) (0.5.1)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from pip-api->isort[requirements]<5->nemo_toolkit[all]) (21.1.3)
# Collecting yarg
#   Downloading yarg-0.1.9-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: docopt in /usr/local/lib/python3.7/dist-packages (from pipreqs->isort[requirements]<5->nemo_toolkit[all]) (0.6.2)
# Collecting simplejson>=3.8.1
#   Downloading simplejson-3.17.6-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (130 kB)
#      |████████████████████████████████| 130 kB 90.3 MB/s
# Requirement already satisfied: sortedcontainers>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from pyannote.core->nemo_toolkit[all]) (2.4.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (0.8.10)
# Requirement already satisfied: sympy>=1.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.metrics->nemo_toolkit[all]) (1.7.1)
# Collecting pyannote.database>=4.0.1
#   Downloading pyannote.database-4.1.3-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 603 kB/s
# Requirement already satisfied: typer[all]>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from pyannote.database>=4.0.1->pyannote.metrics->nemo_toolkit[all]) (0.4.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.1->pyannote.metrics->nemo_toolkit[all]) (1.2.1)
# Collecting colorama<0.5.0,>=0.4.3
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Collecting shellingham<2.0.0,>=1.3.0
#   Downloading shellingham-1.4.0-py2.py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (0.7.1)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (1.11.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from pytest->nemo_toolkit[all]) (8.13.0)
# Collecting jarowinkler<2.0.0,>=1.2.0
#   Downloading jarowinkler-1.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (104 kB)
#      |████████████████████████████████| 104 kB 71.0 MB/s
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.6.1->nemo_toolkit[all]) (1.7.1)
# Collecting ruamel.yaml.clib>=0.2.6
#   Downloading ruamel.yaml.clib-0.2.6-cp37-cp37m-manylinux1_x86_64.whl (546 kB)
#      |████████████████████████████████| 546 kB 98.1 MB/s
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from sacrebleu[ja]->nemo_toolkit[all]) (4.2.6)
# Collecting ipadic<2.0,>=1.0
#   Downloading ipadic-1.0.0.tar.gz (13.4 MB)
#      |████████████████████████████████| 13.4 MB 86.5 MB/s
# Collecting mecab-python3==1.0.5
#   Downloading mecab_python3-1.0.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (574 kB)
#      |████████████████████████████████| 574 kB 84.2 MB/s
# Requirement already satisfied: sphinxcontrib-websupport in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.2.4)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.7.12)
# Requirement already satisfied: docutils<0.18,>=0.11 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (0.17.1)
# Requirement already satisfied: babel!=2.0,>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.10.3)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.4.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (2.2.0)
# Collecting sphinx
#   Downloading Sphinx-5.1.1-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 85.1 MB/s
# Collecting pybtex>=0.24
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#      |████████████████████████████████| 561 kB 101.1 MB/s
# Collecting pybtex-docutils>=1.0.0
#   Downloading pybtex_docutils-1.0.2-py3-none-any.whl (6.3 kB)
# Collecting latexcodec>=1.0.4
#   Downloading latexcodec-2.0.1-py2.py3-none-any.whl (18 kB)
# Collecting sphinxcontrib-htmlhelp>=2.0.0
#   Downloading sphinxcontrib_htmlhelp-2.0.0-py2.py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 14.1 MB/s
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.2-py2.py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 99.2 MB/s
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 5.1 MB/s
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 13.1 MB/s
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx->nemo_toolkit[all]) (1.1.5)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 88.8 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.8.0-py2.py3-none-any.whl (153 kB)
#      |████████████████████████████████| 153 kB 101.7 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->nemo_toolkit[all]) (5.4.8)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: nemo-toolkit, sacremoses, fasttext, distance, kaldi-python-io, kaldiio, pesq, pystoi, ipadic, sentence-transformers, pathtools
#   Building wheel for nemo-toolkit (setup.py) ... done
#   Created wheel for nemo-toolkit: filename=nemo_toolkit-1.11.0rc0-py3-none-any.whl size=3708261 sha256=c192f5d1a4345284a9eadf6def420b8f88136de7817037ccdf5731d85657dd43
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zhuu1vze/wheels/82/66/ef/7248c1c27216d06425cab14b3391059534c889aaf2db89b855
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895260 sha256=c74733923b1b415a8758406ac83b40a1bba665b962fb0eb282af7b51d9f93d2a
#   Stored in directory: /root/.cache/pip/wheels/87/39/dd/a83eeef36d0bf98e7a4d1933a4ad2d660295a40613079bafc9
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3169118 sha256=89b8374bc8e73547997af315cc33a07fa278161d08c69aad91cd3d74bbf91827
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16276 sha256=4ae8b27026d894f8e2a5830e28111cefca1bce77a4a7d52d04a0d36ad193e2c5
#   Stored in directory: /root/.cache/pip/wheels/b2/10/1b/96fca621a1be378e2fe104cfb0d160bb6cdf3d04a3d35266cc
#   Building wheel for kaldi-python-io (setup.py) ... done
#   Created wheel for kaldi-python-io: filename=kaldi_python_io-1.2.2-py3-none-any.whl size=8969 sha256=ed63e478b99e7250986f008b633e6fcc5e1b523385d9bc1989a067f7f37aa6b8
#   Stored in directory: /root/.cache/pip/wheels/a9/26/38/7678d1ff6cd1bbcbfc0d80b0a29d94d917dfa9ad790b4a85a9
#   Building wheel for kaldiio (setup.py) ... done
#   Created wheel for kaldiio: filename=kaldiio-2.17.2-py3-none-any.whl size=24471 sha256=25ac7e6f4dfdbebb19e25e67d425315a0d1dc3d10ed5027fb0e03276227a7512
#   Stored in directory: /root/.cache/pip/wheels/04/07/e8/45641287c59bf6ce41e22259f8680b521c31e6306cb88392ac
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp37-cp37m-linux_x86_64.whl size=214581 sha256=93e1b6bf90937bc638e1587b53ca2237071399ef7e4f2f90b8f24069657e650e
#   Stored in directory: /root/.cache/pip/wheels/c5/3d/9c/542731f8357f7c82eb6ac2047cc5375f92c9a05b09a715aff6
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7793 sha256=d6b1db191e472917717d8da52ef135758c634c03f00e1fdc1f8efa4b955665c4
#   Stored in directory: /root/.cache/pip/wheels/46/4a/ad/3ab460193ed0535430b4b1575f255aa6bae69df17453628e86
#   Building wheel for ipadic (setup.py) ... done
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556723 sha256=df1db857b3d4a0ac23085f67be50ee46a783d173ad502d68fd4d27f0ec059ee1
#   Stored in directory: /root/.cache/pip/wheels/33/8b/99/cf0d27191876637cd3639a560f93aa982d7855ce826c94348b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=2345d3707b23ed3d3ba4ab061cc8732ad3746fead514306703aef08809c74c7b
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=5e9d800e9e3fc3e41f1cb0e55ad00a45b7921359c7cd7847507f57ec9273b18b
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built nemo-toolkit sacremoses fasttext distance kaldi-python-io kaldiio pesq pystoi ipadic sentence-transformers pathtools
# Installing collected packages: urllib3, setuptools, multidict, frozenlist, yarl, smmap, simplejson, shellingham, pyyaml, latexcodec, jmespath, colorama, asynctest, async-timeout, aiosignal, yarg, tokenizers, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, ruamel.yaml.clib, pybtex, pyannote.core, portalocker, huggingface-hub, gitdb, fsspec, botocore, aiohttp, typed-ast, transformers, torchmetrics, toml, sphinx, shortuuid, setproctitle, sentry-sdk, sentencepiece, sacrebleu, s3transfer, ruamel.yaml, pyDeprecate, pybtex-docutils, pybind11, pyannote.database, pipreqs, pip-api, pathtools, pathspec, onnx, mecab-python3, jarowinkler, isort, ipadic, GitPython, frozendict, docker-pycreds, distance, braceexpand, aniso8601, youtokentome, webdataset, wandb, sphinxcontrib-bibtex, sox, sentence-transformers, sacremoses, rapidfuzz, pytorch-lightning, pytest-runner, pystoi, pypinyin, pydub, pyannote.metrics, pesq, parameterized, pangu, opencc, nemo-toolkit, marshmallow, kaldiio, kaldi-python-io, ijson, g2p-en, ftfy, flask-restful, fasttext, faiss-cpu, einops, boto3, black, attrdict
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: sphinx
#     Found existing installation: Sphinx 1.8.6
#     Uninstalling Sphinx-1.8.6:
#       Successfully uninstalled Sphinx-1.8.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed GitPython-3.1.27 aiohttp-3.8.1 aiosignal-1.2.0 aniso8601-9.0.1 async-timeout-4.0.2 asynctest-0.13.0 attrdict-2.0.1 black-19.10b0 boto3-1.24.38 botocore-1.27.38 braceexpand-0.1.7 colorama-0.4.5 distance-0.1.3 docker-pycreds-0.4.0 einops-0.4.1 faiss-cpu-1.7.2 fasttext-0.9.2 flask-restful-0.3.9 frozendict-2.3.4 frozenlist-1.3.0 fsspec-2022.5.0 ftfy-6.1.1 g2p-en-2.1.0 gitdb-4.0.9 huggingface-hub-0.8.1 ijson-3.1.4 ipadic-1.0.0 isort-4.3.21 jarowinkler-1.2.0 jmespath-1.0.1 kaldi-python-io-1.2.2 kaldiio-2.17.2 latexcodec-2.0.1 marshmallow-3.17.0 mecab-python3-1.0.5 multidict-6.0.2 nemo-toolkit-1.11.0rc0 onnx-1.12.0 opencc-1.1.4 pangu-4.0.6.1 parameterized-0.8.1 pathspec-0.9.0 pathtools-0.1.2 pesq-0.0.4 pip-api-0.0.30 pipreqs-0.4.11 portalocker-2.5.1 pyDeprecate-0.3.2 pyannote.core-4.4 pyannote.database-4.1.3 pyannote.metrics-3.2.1 pybind11-2.10.0 pybtex-0.24.0 pybtex-docutils-1.0.2 pydub-0.25.1 pypinyin-0.46.0 pystoi-0.3.3 pytest-runner-6.0.0 pytorch-lightning-1.6.5 pyyaml-5.4.1 rapidfuzz-2.3.0 ruamel.yaml-0.17.21 ruamel.yaml.clib-0.2.6 s3transfer-0.6.0 sacrebleu-2.2.0 sacremoses-0.0.53 sentence-transformers-2.2.2 sentencepiece-0.1.96 sentry-sdk-1.8.0 setproctitle-1.3.0 setuptools-59.5.0 shellingham-1.4.0 shortuuid-1.0.9 simplejson-3.17.6 smmap-5.0.0 sox-1.4.1 sphinx-5.1.1 sphinxcontrib-applehelp-1.0.2 sphinxcontrib-bibtex-2.4.2 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.0 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 tokenizers-0.12.1 toml-0.10.2 torchmetrics-0.9.3 transformers-4.21.0 typed-ast-1.5.4 urllib3-1.25.11 wandb-0.12.21 webdataset-0.1.62 yarg-0.1.9 yarl-1.7.2 youtokentome-1.0.6
# sox is already the newest version (14.4.2-3ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Cloning into '/content/synthbot'...
# remote: Enumerating objects: 680, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 680 (delta 1), reused 1 (delta 1), pack-reused 674
# Receiving objects: 100% (680/680), 5.35 MiB | 6.39 MiB/s, done.
# Resolving deltas: 100% (308/308), done.
# Branch 'experimental' set up to track remote branch 'experimental' from 'origin'.
# Switched to a new branch 'experimental'
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pysoundfile
#   Downloading PySoundFile-0.9.0.post1-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.7/dist-packages (from pysoundfile) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=0.6->pysoundfile) (2.21)
# Installing collected packages: pysoundfile
# Successfully installed pysoundfile-0.9.0.post1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: librosa in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: resampy>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.3.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (21.3)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.0.2)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.51.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.21.6)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (1.7.3)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa) (0.10.3.post1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa) (59.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.25.11)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Enabling notebook extension jupyter-js-widgets/extension...
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json
#       - Validating: OK
# Paths used for configuration of notebook:
#     	/usr/etc/jupyter/nbconfig/notebook.json

# %%
home_path = !(echo $HOME)
home_path = home_path[0]
print(home_path)
# Out:
# /root

# %%
#downloading the dataset
id='12ClseQAzkqsqCNMClmptvbSjfs2Ulcei'
character='applejack'
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id={id}' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id={id}" -O {character+'.tar'} && rm -rf /tmp/cookies.txt
# Out:
# --2022-07-27 13:56:24--  https://docs.google.com/uc?export=download&confirm=t&id=12ClseQAzkqsqCNMClmptvbSjfs2Ulcei
# Resolving docs.google.com (docs.google.com)... 108.177.121.139, 108.177.121.102, 108.177.121.100, ...
# Connecting to docs.google.com (docs.google.com)|108.177.121.139|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0c-84-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/j5cjnhpd4tlr0m7j4vdpd1odmlt7qeu3/1658930175000/05434657448262868821/*/12ClseQAzkqsqCNMClmptvbSjfs2Ulcei?e=download&uuid=e66954af-b0ee-4d61-b9a7-f6eb69f2b4ca [following]
# Warning: wildcards not supported in HTTP.
# --2022-07-27 13:56:24--  https://doc-0c-84-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/j5cjnhpd4tlr0m7j4vdpd1odmlt7qeu3/1658930175000/05434657448262868821/*/12ClseQAzkqsqCNMClmptvbSjfs2Ulcei?e=download&uuid=e66954af-b0ee-4d61-b9a7-f6eb69f2b4ca
# Resolving doc-0c-84-docs.googleusercontent.com (doc-0c-84-docs.googleusercontent.com)... 173.194.192.132, 2607:f8b0:4001:c0e::84
# Connecting to doc-0c-84-docs.googleusercontent.com (doc-0c-84-docs.googleusercontent.com)|173.194.192.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1355008000 (1.3G) [application/x-tar]
# Saving to: ‘applejack.tar’
#
# applejack.tar       100%[===================>]   1.26G   189MB/s    in 7.3s
#
# 2022-07-27 13:56:32 (177 MB/s) - ‘applejack.tar’ saved [1355008000/1355008000]

# %%
skip_noisy = True # Disable to train with Noisy Data included
allowed_emotions = """
Anxious
Angry
Annoyed
Amused
Confused
Crazy
Disgust
Exhausted
Fear
Happy
Neutral
Sad
Serious
Singing
Shouting
Surprised
Smug
Love
Sarcastic
Tired
Whispering
Whining
""".split("\n")[1:-1]

percentage_training_data = 0.95 # 90% of Data will be used for training, 5% for Validation

##############################################################################################

import sys
sys.path.append('/content/synthbot/src')
from ponysynth.corpus import ClipperArchive, phoneme_transcription
import librosa
import subprocess

archive_fn = "/content/applejack.tar"
archive = ClipperArchive(archive_fn)

data_path = 'applejack'
allowed_emotions = [x.lower() for x in allowed_emotions]
# !mkdir {data_path}
# !mkdir {data_path+"/out"}
all_clips = []; all_clips_arpa = []; skipped_count=0; too_short_count=0; emotion_skip=0
for key in archive.keys(): # write the audio files for processing in bash terminal
  audio = archive.read_audio(key)
  audio_fn = '{}/{}.wav'.format(data_path, key)
  audio_fn_ = '{}/{}.wav'.format(data_path+"/out", key)
  with open(audio_fn, 'wb') as audio_out:
    audio_out.write(audio.read())
# Out:
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)

# %%
# %%script bash
# # trim all 48Khz files
# cd applejack
# for input in *.wav; do
#   output="out/$input"
#   sox "$input" "$output" silence 1 0.05 0.1% reverse silence 1 0.05 0.1% reverse;
# done

# %%
import os

should_continue = 0 # should run "continue" command inside outer loop.
for key in archive.keys():
  label = archive.read_label(key)
  audio_fn = '{}/{}.wav'.format(data_path, key)
  audio_fn_ = '{}/{}.wav'.format(data_path+"/out", key)
  if (label['noise'] in ['Very Noisy','Noisy']) and skip_noisy: os.remove(audio_fn_); skipped_count+=1; continue

  for tag in label['tags']:
     if tag.lower() not in allowed_emotions:
       try: os.remove(audio_fn_)
       except: pass
       print(tag+" emotion not in list"); emotion_skip+=1; should_continue = 1; break # this is supposed to break the outer loop
  if should_continue: should_continue = 0; continue

  audio = archive.read_audio(key)
  transcript = label['utterance']['content']
  
  if os.stat(audio_fn_).st_size < 71602:
    #print("Skipping Audio, Duration: "+str(len(librosa.core.load(audio_fn_, sr=48000)[0])/48000))
    try: os.remove(audio_fn_)
    except: pass
    too_short_count+=1; continue # Skips files based on size.

  filelist_line = "{}|{}".format(audio_fn_, transcript)
  all_clips.append(filelist_line)
  filelist_line = "{}|{}".format(audio_fn_, phoneme_transcription(label))
  all_clips_arpa.append(filelist_line)
    
print(str(skipped_count)+" Files are too Noisy.")
print(str(emotion_skip)+" Files contain an emotion not in permitted emotions")
print(str(too_short_count)+" Files are too short")
print(str(len(list(archive.keys()))-(skipped_count+too_short_count+emotion_skip))+" Files kept in dataset.")


####################################################################################################################
# shuffle the training data
import random
random.seed(0)
random.shuffle(all_clips)

# get train, test, validation splits
num_clips = len(all_clips)
train_end = int(num_clips * percentage_training_data)

train = all_clips[:train_end]
validation = all_clips[train_end:]

train_arpa = all_clips_arpa[:train_end]
validation_arpa = all_clips_arpa[train_end:]

# dump the info to filelist files
with open('train_filelist.txt', 'w') as train_out:
  train_out.write('\n'.join(train)+'\n'+'\n'.join(train_arpa)+"")
with open('val_filelist.txt', 'w') as val_out:
  val_out.write('\n'.join(validation)+'\n'+'\n'.join(validation_arpa)+"")

##################################################################################################################

#imports
import os
import json
import random
import librosa

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

from nemo.collections.tts.models import FastPitchModel

######################################################################################

#creating the json files for training and validation
with open('/content/train_filelist.txt') as f :
  records = f.readlines()

print("Number of records : ",len(records))

train_manifest = 'fastpitch_train.json'

train_rec = []
random.shuffle(records)
count = 0

for i in records :
  #if count > 1200 :
  #  break
  
  i = i.split('|')
  audio_filepath = i[0]
  text = i[-1].strip('\n')
  if '{' in text :
    #print(text)
    continue
  count = count + 1

  duration = librosa.get_duration(filename=audio_filepath)
  r = {
       "audio_filepath" : audio_filepath,
       "text" : text,
       "duration" : round(duration,1),
       "text_no_preprocessing" : text
    }

  train_rec.append(r)

with open(train_manifest, "w") as f:
    for s in train_rec:
        f.write(json.dumps(s) + '\n')
        
print("Training Data : ", len(train_rec))

##########################################################################################

with open('/content/val_filelist.txt') as f :
  records_val = f.readlines()

print("Number of records : ", len(records_val))

val_manifest = 'fastpitch_val.json'
count = 0
val_rec = []
random.shuffle(records_val)

for i in records_val:
  #if count > 50 :
  #  break
    
  i = i.split('|')
  audio_filepath = i[0]
  text = i[-1].strip('\n')

  if '{' in text :
    #print(text)
    continue
  count = count + 1
  duration = librosa.get_duration(filename=audio_filepath)
  r = {
       "audio_filepath" : audio_filepath,
       "text" : text,
       "duration" : round(duration,1),
       "text_no_preprocessing" : text
    }

  val_rec.append(r)

print(len(val_rec))
with open(val_manifest, "w") as f:
    for s in val_rec:
        f.write(json.dumps(s) + '\n')

####################################################################################

FastPitchModel.from_pretrained("tts_en_fastpitch")
nemo_files = [p for p in Path(f"{home_path}/.cache/torch/NeMo/").glob("**/tts_en_fastpitch_align.nemo")]
print(f"Copying {nemo_files[0]} to ./")
Path("./tts_en_fastpitch_align.nemo").write_bytes(nemo_files[0].read_bytes())

###################################################################################

# !wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/fastpitch_finetune.py

# !mkdir -p conf \
&& cd conf \
&& wget https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/fastpitch_align_v1.05.yaml \
&& cd ..

#######################################
# additional files
# !mkdir -p tts_dataset_files && cd tts_dataset_files \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/cmudict-0.7b_nv22.07 \
&& wget https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/heteronyms-030921 \
&& wget wget https://raw.githubusercontent.com/NVIDIA/NeMo/$BRANCH/nemo_text_processing/text_normalization/en/data/whitelist/lj_speech.tsv \
&& cd ..
# Out:
# 2768 Files are too Noisy.
# 0 Files contain an emotion not in permitted emotions
# 203 Files are too short
# 2486 Files kept in dataset.
# [NeMo W 2022-07-27 13:57:21 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-07-27 13:57:21 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# Number of records :  4722
# Training Data :  2361
# Number of records :  250
# 125
# [NeMo I 2022-07-27 13:57:22 cloud:66] Downloading from: https://api.ngc.nvidia.com/v2/models/nvidia/nemo/tts_en_fastpitch/versions/1.8.1/files/tts_en_fastpitch_align.nemo to /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo
# [NeMo I 2022-07-27 13:57:28 common:789] Instantiating model from pre-trained checkpoint
# [NeMo I 2022-07-27 13:57:31 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-27 13:57:51 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-07-27 13:57:51 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-27 13:57:51 modelPT:143] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-07-27 13:57:51 modelPT:150] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
# [NeMo I 2022-07-27 13:57:52 features:217] PADDING: 1
# [NeMo I 2022-07-27 13:57:56 save_restore_connector:243] Model FastPitchModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo.
# Copying /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_en_fastpitch_align/26d7e09971f1d611e24df90c7a9d9b38/tts_en_fastpitch_align.nemo to ./
# --2022-07-27 13:57:57--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/fastpitch_finetune.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1751 (1.7K) [text/plain]
# Saving to: ‘fastpitch_finetune.py’
#
# fastpitch_finetune. 100%[===================>]   1.71K  --.-KB/s    in 0s
#
# 2022-07-27 13:57:57 (36.7 MB/s) - ‘fastpitch_finetune.py’ saved [1751/1751]
#
# --2022-07-27 13:57:57--  https://raw.githubusercontent.com/nvidia/NeMo/main/examples/tts/conf/fastpitch_align_v1.05.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6692 (6.5K) [text/plain]
# Saving to: ‘fastpitch_align_v1.05.yaml’
#
# fastpitch_align_v1. 100%[===================>]   6.54K  --.-KB/s    in 0s
#
# 2022-07-27 13:57:57 (94.0 MB/s) - ‘fastpitch_align_v1.05.yaml’ saved [6692/6692]
#
# --2022-07-27 13:57:57--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/cmudict-0.7b_nv22.07
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3722012 (3.5M) [text/plain]
# Saving to: ‘cmudict-0.7b_nv22.07’
#
# cmudict-0.7b_nv22.0 100%[===================>]   3.55M  --.-KB/s    in 0.07s
#
# 2022-07-27 13:57:57 (51.7 MB/s) - ‘cmudict-0.7b_nv22.07’ saved [3722012/3722012]
#
# --2022-07-27 13:57:57--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/scripts/tts_dataset_files/heteronyms-030921
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3132 (3.1K) [text/plain]
# Saving to: ‘heteronyms-030921’
#
# heteronyms-030921   100%[===================>]   3.06K  --.-KB/s    in 0s
#
# 2022-07-27 13:57:58 (70.9 MB/s) - ‘heteronyms-030921’ saved [3132/3132]
#
# --2022-07-27 13:57:58--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2022-07-27 13:57:58--  https://raw.githubusercontent.com/NVIDIA/NeMo/main/nemo_text_processing/text_normalization/en/data/whitelist/lj_speech.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 263 [text/plain]
# Saving to: ‘lj_speech.tsv’
#
# lj_speech.tsv       100%[===================>]     263  --.-KB/s    in 0s
#
# 2022-07-27 13:57:58 (25.1 MB/s) - ‘lj_speech.tsv’ saved [263/263]
#
# FINISHED --2022-07-27 13:57:58--
# Total wall clock time: 0.3s
# Downloaded: 1 files, 263 in 0s (25.1 MB/s)

# %%
from nemo.collections.tts.torch.g2ps import EnglishG2p
from nemo.collections.tts.torch.data import TTSDataset
from nemo_text_processing.text_normalization.normalize import Normalizer
from nemo.collections.tts.torch.tts_tokenizers import EnglishPhonemesTokenizer, EnglishCharsTokenizer

import torch
from tqdm.notebook import tqdm


# Text normalizer
text_normalizer = Normalizer(
    lang="en", 
    input_case="cased", 
    whitelist="./tts_dataset_files/lj_speech.tsv"
)

text_normalizer_call_kwargs = {
    "punct_pre_process": True,
    "punct_post_process": True
}

# Text tokenizer
text_tokenizer = EnglishCharsTokenizer()

def pre_calculate_supplementary_data(sup_data_path, sup_data_types, text_tokenizer, text_normalizer, text_normalizer_call_kwargs):
    # init train and val dataloaders
    stages = ["train", "val"]
    stage2dl = {}
    for stage in stages:
        ds = TTSDataset(
            manifest_filepath=f"fastpitch_{stage}.json",
            sample_rate=16000,
            sup_data_path=sup_data_path,
            sup_data_types=sup_data_types,
            n_fft=1024,
            win_length=1024,
            hop_length=256,
            window="hann",
            n_mels=80,
            lowfreq=0,
            highfreq=8000,
            text_tokenizer=text_tokenizer,
            text_normalizer=text_normalizer,
            text_normalizer_call_kwargs=text_normalizer_call_kwargs

        ) 
        stage2dl[stage] = torch.utils.data.DataLoader(ds, batch_size=1, collate_fn=ds._collate_fn, num_workers=0)

    # iteration over dataloaders
    pitch_mean, pitch_std, pitch_min, pitch_max = None, None, None, None
    for stage, dl in stage2dl.items():
        pitch_list = []
        print(stage)
        print(dl)
        for batch in tqdm(dl, total=len(dl)):
            tokens, tokens_lengths, audios, audio_lengths, attn_prior, pitches, pitches_lengths = batch
            pitch = pitches.squeeze(0)
            pitch_list.append(pitch[pitch != 0])

        if stage == "train":
            pitch_tensor = torch.cat(pitch_list)
            pitch_mean, pitch_std = pitch_tensor.mean().item(), pitch_tensor.std().item()
            pitch_min, pitch_max = pitch_tensor.min().item(), pitch_tensor.max().item()
    
    print("Pitch_mean : ",pitch_mean)
    print("Pitch_std : ",pitch_std)
    print("Pitch_min : ",pitch_min)
    print("Pitch_max : ",pitch_max)
            
    return pitch_mean, pitch_std, pitch_min, pitch_max

fastpitch_sup_data_path = "fastpitch_sup_data_folder"
sup_data_types = ["align_prior_matrix", "pitch"]

pitch_mean, pitch_std, pitch_min, pitch_max = pre_calculate_supplementary_data(
    fastpitch_sup_data_path, sup_data_types, text_tokenizer, text_normalizer, text_normalizer_call_kwargs
)
# Out:
# [NeMo I 2022-07-27 10:41:54 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo I 2022-07-27 10:42:20 data:197] Loading dataset from fastpitch_train.json.
# 2361it [00:30, 76.43it/s]
# [NeMo I 2022-07-27 10:42:51 data:232] Loaded dataset with 2361 files.
# [NeMo I 2022-07-27 10:42:51 data:234] Dataset contains 1.55 hours.
# [NeMo I 2022-07-27 10:42:51 data:336] Pruned 0 files. Final dataset contains 2361 files
# [NeMo I 2022-07-27 10:42:51 data:339] Pruned 0.00 hours. Final dataset contains 1.55 hours.
# [NeMo I 2022-07-27 10:42:51 data:197] Loading dataset from fastpitch_val.json.
# 125it [00:01, 71.51it/s]
# [NeMo I 2022-07-27 10:42:53 data:232] Loaded dataset with 125 files.
# [NeMo I 2022-07-27 10:42:53 data:234] Dataset contains 0.08 hours.
# [NeMo I 2022-07-27 10:42:53 data:336] Pruned 0 files. Final dataset contains 125 files
# [NeMo I 2022-07-27 10:42:53 data:339] Pruned 0.00 hours. Final dataset contains 0.08 hours.
# train
# <torch.utils.data.dataloader.DataLoader object at 0x7fd47ac6cdd0>
#   0%|          | 0/2361 [00:00<?, ?it/s]
# [NeMo W 2022-07-27 10:42:53 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/amp/autocast_mode.py:198: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#       warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
#
# [NeMo W 2022-07-27 10:42:56 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/torch/amp/autocast_mode.py:198: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#       warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')
# val
# <torch.utils.data.dataloader.DataLoader object at 0x7fd47ae49890>
#   0%|          | 0/125 [00:00<?, ?it/s]
# Pitch_mean :  324.42596435546875
# Pitch_std :  112.51094055175781
# Pitch_min :  65.4063949584961
# Pitch_max :  2093.004638671875

# %%
#setting up wandb credentials
#weights and biases 
wandb_api_key = "d06dcb679ec9cf0d71c81cb750d142b6b90f3d25"
wandb_project_name = 'MLP'
wandb_run_name = character

# !wandb login ${wandb_api_key}
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
#resuming the training 
#+init_from_ptl_ckpt=Fastpitch_epoch_356.ckpt
# trainer.max_epochs=500 ~trainer.max_epochs 
#+init_from_nemo_model=tts_en_fastpitch_align.nemo \
! (python fastpitch_finetune.py --config-name=fastpitch_align_v1.05.yaml \
  train_dataset=fastpitch_train.json \
  validation_datasets=fastpitch_val.json \
  sup_data_path=fastpitch_sup_data \
  phoneme_dict_path=tts_dataset_files/cmudict-0.7b_nv22.07 \
  heteronyms_path=tts_dataset_files/heteronyms-030921 \
  whitelist_path=tts_dataset_files/lj_speech.tsv \
  exp_manager.exp_dir=training_logs \
  +init_from_nemo_model=tts_en_fastpitch_align.nemo \
  trainer.max_epochs=1000 ~trainer.max_epochs \
  trainer.check_val_every_n_epoch=7 \
  model.train_ds.dataloader_params.batch_size=8 model.validation_ds.dataloader_params.batch_size=8 \
  model.n_speakers=1 model.pitch_mean=324.43 model.pitch_std=112.51 \
  model.pitch_fmin=65.41 model.pitch_fmax=2093 model.optim.lr=2e-4 \
  +exp_manager.create_wandb_logger=true \
  +exp_manager.wandb_logger_kwargs.name='applejack' \
  +exp_manager.wandb_logger_kwargs.project='MLP' \
  ~model.optim.sched model.optim.name=adam trainer.devices=1 trainer.strategy=null \
  +model.text_tokenizer.add_blank_at=true \
)
# Out:
# [NeMo W 2022-07-27 14:00:55 optimizers:55] Apex was not found. Using the lamb or fused_adam optimizer will error out.
# [NeMo W 2022-07-27 14:00:56 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#       _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)
#
# [NeMo W 2022-07-27 14:01:05 experimental:28] Module <class 'nemo.collections.tts.torch.tts_tokenizers.IPATokenizer'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# Using 16bit native Automatic Mixed Precision (AMP)
# [NeMo W 2022-07-27 14:01:05 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loops/utilities.py:95: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#       category=PossibleUserWarning,
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo I 2022-07-27 14:01:05 exp_manager:286] Experiments will be logged at training_logs/FastPitch/2022-07-27_14-01-05
# [NeMo I 2022-07-27 14:01:05 exp_manager:660] TensorboardLogger has been set up
# wandb: Currently logged in as: convaitech. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.21
# wandb: Run data is saved locally in training_logs/wandb/run-20220727_140106-2022-07-27_14-01-05
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run applejack
# wandb: ⭐️ View project at https://wandb.ai/convaitech/MLP
# wandb: 🚀 View run at https://wandb.ai/convaitech/MLP/runs/2022-07-27_14-01-05
# [NeMo I 2022-07-27 14:01:06 exp_manager:675] WandBLogger has been set up
# [NeMo W 2022-07-27 14:01:07 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/loggers/base.py:236: LightningDeprecationWarning: `LoggerCollection` is deprecated in v1.6 and will be removed in v1.8. Directly pass a list of loggers to the Trainer and access the list via the `trainer.loggers` attribute.
#       "`LoggerCollection` is deprecated in v1.6 and will be removed in v1.8. Directly pass a list of loggers"
#
# [NeMo W 2022-07-27 14:01:07 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:2319: LightningDeprecationWarning: `Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.
#       rank_zero_deprecation("`Trainer.weights_save_path` has been deprecated in v1.6 and will be removed in v1.8.")
#
# [NeMo I 2022-07-27 14:01:09 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-27 14:01:28 experimental:28] Module <class 'nemo.collections.tts.torch.g2ps.IPAG2P'> is experimental, not ready for production and is not fully supported. Use at your own risk.
# [NeMo W 2022-07-27 14:01:29 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# Created a temporary directory at /tmp/tmp1ix_m9zt
# Writing /tmp/tmp1ix_m9zt/_remote_module_non_scriptable.py
# [NeMo I 2022-07-27 14:01:29 data:197] Loading dataset from fastpitch_train.json.
# 2361it [00:19, 119.24it/s]
# [NeMo I 2022-07-27 14:01:49 data:232] Loaded dataset with 2361 files.
# [NeMo I 2022-07-27 14:01:49 data:234] Dataset contains 1.55 hours.
# [NeMo I 2022-07-27 14:01:49 data:336] Pruned 0 files. Final dataset contains 2361 files
# [NeMo I 2022-07-27 14:01:49 data:339] Pruned 0.00 hours. Final dataset contains 1.55 hours.
# [NeMo I 2022-07-27 14:01:49 data:197] Loading dataset from fastpitch_val.json.
# 125it [00:01, 113.37it/s]
# [NeMo I 2022-07-27 14:01:50 data:232] Loaded dataset with 125 files.
# [NeMo I 2022-07-27 14:01:50 data:234] Dataset contains 0.08 hours.
# [NeMo I 2022-07-27 14:01:50 data:336] Pruned 0 files. Final dataset contains 125 files
# [NeMo I 2022-07-27 14:01:50 data:339] Pruned 0.00 hours. Final dataset contains 0.08 hours.
# [NeMo I 2022-07-27 14:01:50 features:217] PADDING: 1
# [NeMo I 2022-07-27 14:01:53 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-27 14:02:14 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-27 14:02:14 modelPT:143] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_train_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 24
#       num_workers: 0
#
# [NeMo W 2022-07-27 14:02:14 modelPT:150] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: /ws/LJSpeech/nvidia_ljspeech_val_clean_ngc.json
#       sample_rate: 22050
#       sup_data_path: /raid/LJSpeech/supplementary
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.40639132514966
#       pitch_fmax: 2093.004522404789
#       pitch_norm: true
#       pitch_mean: 212.35873413085938
#       pitch_std: 68.52806091308594
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 24
#       num_workers: 0
#
# [NeMo I 2022-07-27 14:02:14 features:217] PADDING: 1
# [NeMo I 2022-07-27 14:02:14 save_restore_connector:243] Model FastPitchModel was successfully restored from /content/tts_en_fastpitch_align.nemo.
# [NeMo I 2022-07-27 14:02:14 modelPT:1043] Model checkpoint restored from nemo file with path : `tts_en_fastpitch_align.nemo`
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [NeMo I 2022-07-27 14:02:16 modelPT:587] Optimizer config = Adam (
#     Parameter Group 0
#         amsgrad: False
#         betas: [0.9, 0.999]
#         capturable: False
#         eps: 1e-08
#         foreach: None
#         lr: 0.0002
#         maximize: False
#         weight_decay: 1e-06
#     )
# [NeMo I 2022-07-27 14:02:16 lr_scheduler:699] Scheduler not initialized as no `sched` config supplied to setup_optimizer()
#
#   | Name             | Type                              | Params
# -----------------------------------------------------------------------
# 0 | mel_loss         | MelLoss                           | 0
# 1 | pitch_loss       | PitchLoss                         | 0
# 2 | duration_loss    | DurationLoss                      | 0
# 3 | aligner          | AlignmentEncoder                  | 1.0 M
# 4 | forward_sum_loss | ForwardSumLoss                    | 0
# 5 | bin_loss         | BinLoss                           | 0
# 6 | preprocessor     | AudioToMelSpectrogramPreprocessor | 0
# 7 | fastpitch        | FastPitchModule                   | 45.8 M
# -----------------------------------------------------------------------
# 45.8 M    Trainable params
# 0         Non-trainable params
# 45.8 M    Total params
# 91.518    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s][NeMo W 2022-07-27 14:02:18 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:245: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       category=PossibleUserWarning,
#
# [NeMo W 2022-07-27 14:02:46 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:245: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#       category=PossibleUserWarning,
#
# Epoch 6:  90% 280/312 [02:14<00:15,  2.08it/s, loss=3.6, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 6:  96% 300/312 [02:46<00:06,  1.80it/s, loss=3.6, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [02:30<00:00,  9.38s/it]
# Epoch 6: 100% 312/312 [04:52<00:00,  1.07it/s, loss=3.56, v_num=1-05]
#                                                             Epoch 6, global step 2072: 'v_loss' reached 1.31023 (best 1.31023), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.3102-epoch=6.ckpt' as top 3
# Epoch 13:  90% 280/312 [02:30<00:17,  1.86it/s, loss=3.12, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 13:  96% 300/312 [02:41<00:06,  1.86it/s, loss=3.12, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.49it/s]
# Epoch 13: 100% 312/312 [02:46<00:00,  1.88it/s, loss=3.24, v_num=1-05]
#                                                             Epoch 13, global step 4144: 'v_loss' reached 1.17770 (best 1.17770), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1777-epoch=13.ckpt' as top 3
# Epoch 20:  90% 280/312 [02:36<00:17,  1.79it/s, loss=3.05, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 20:  96% 300/312 [02:46<00:06,  1.81it/s, loss=3.05, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:07<00:00,  2.25it/s]
# Epoch 20: 100% 312/312 [02:51<00:00,  1.82it/s, loss=2.89, v_num=1-05]
#                                                             Epoch 20, global step 6216: 'v_loss' reached 1.20993 (best 1.17770), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.2099-epoch=20.ckpt' as top 3
# Epoch 23:  14% 40/296 [00:23<02:27,  1.73it/s, loss=3.03, v_num=1-05]wandb: Network error (ReadTimeout), entering retry loop.
# Epoch 27:  90% 280/312 [02:42<00:18,  1.73it/s, loss=2.92, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 27:  96% 300/312 [02:53<00:06,  1.73it/s, loss=2.92, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.32it/s]
# Epoch 27: 100% 312/312 [02:58<00:00,  1.75it/s, loss=2.94, v_num=1-05]
#                                                             Epoch 27, global step 8288: 'v_loss' reached 1.20164 (best 1.17770), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.2016-epoch=27.ckpt' as top 3
# Epoch 34:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.87, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 34:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.87, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.00it/s]
# Epoch 34: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.98, v_num=1-05]
#                                                             Epoch 34, global step 10360: 'v_loss' reached 1.17612 (best 1.17612), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1761-epoch=34.ckpt' as top 3
# Epoch 41:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.9, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 41:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.9, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 41: 100% 312/312 [02:27<00:00,  2.11it/s, loss=2.86, v_num=1-05]
#                                                             Epoch 41, global step 12432: 'v_loss' reached 1.17052 (best 1.17052), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1705-epoch=41.ckpt' as top 3
# Epoch 48:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.85, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 48:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.85, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 48: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.9, v_num=1-05]
#                                                             Epoch 48, global step 14504: 'v_loss' reached 1.16999 (best 1.16999), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1700-epoch=48.ckpt' as top 3
# Epoch 55:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.92, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 55:  96% 300/312 [02:22<00:05,  2.10it/s, loss=2.92, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.01it/s]
# Epoch 55: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.67, v_num=1-05]
#                                                             Epoch 55, global step 16576: 'v_loss' was not in top 3
# Epoch 62:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.76, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 62:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.76, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.98it/s]
# Epoch 62: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.69, v_num=1-05]
#                                                             Epoch 62, global step 18648: 'v_loss' reached 1.17594 (best 1.16999), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1759-epoch=62.ckpt' as top 3
# Epoch 69:  90% 280/312 [02:18<00:15,  2.03it/s, loss=2.77, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 69:  96% 300/312 [02:26<00:05,  2.04it/s, loss=2.77, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.86it/s]
# Epoch 69: 100% 312/312 [02:31<00:00,  2.07it/s, loss=2.8, v_num=1-05]
#                                                             Epoch 69, global step 20720: 'v_loss' was not in top 3
# Epoch 76:  90% 280/312 [02:17<00:15,  2.03it/s, loss=2.7, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 76:  96% 300/312 [02:26<00:05,  2.05it/s, loss=2.7, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.92it/s]
# Epoch 76: 100% 312/312 [02:30<00:00,  2.07it/s, loss=2.57, v_num=1-05]
#                                                             Epoch 76, global step 22792: 'v_loss' was not in top 3
# Epoch 83:  90% 280/312 [02:20<00:16,  1.99it/s, loss=2.77, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 83:  96% 300/312 [02:29<00:05,  2.01it/s, loss=2.77, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.77it/s]
# Epoch 83: 100% 312/312 [02:33<00:00,  2.03it/s, loss=2.66, v_num=1-05]
#                                                             Epoch 83, global step 24864: 'v_loss' reached 1.16651 (best 1.16651), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1665-epoch=83.ckpt' as top 3
# Epoch 90:  90% 280/312 [02:18<00:15,  2.02it/s, loss=2.68, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 90:  96% 300/312 [02:28<00:05,  2.03it/s, loss=2.68, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.51it/s]
# Epoch 90: 100% 312/312 [02:33<00:00,  2.04it/s, loss=2.84, v_num=1-05]
#                                                             Epoch 90, global step 26936: 'v_loss' was not in top 3
# Epoch 97:  90% 280/312 [02:22<00:16,  1.96it/s, loss=2.7, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 97:  96% 300/312 [02:31<00:06,  1.98it/s, loss=2.7, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.45it/s]
# Epoch 97: 100% 312/312 [02:36<00:00,  1.99it/s, loss=2.75, v_num=1-05]
#                                                             Epoch 97, global step 29008: 'v_loss' was not in top 3
# Epoch 104:  90% 280/312 [02:22<00:16,  1.96it/s, loss=2.69, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 104:  96% 300/312 [02:32<00:06,  1.97it/s, loss=2.69, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.76it/s]
# Epoch 104: 100% 312/312 [02:36<00:00,  1.99it/s, loss=2.7, v_num=1-05]
#                                                             Epoch 104, global step 31080: 'v_loss' reached 1.16142 (best 1.16142), saving model to '/content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints/FastPitch--v_loss=1.1614-epoch=104.ckpt' as top 3
# Epoch 111:  90% 280/312 [02:22<00:16,  1.97it/s, loss=2.61, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 111:  96% 300/312 [02:30<00:06,  1.99it/s, loss=2.61, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.79it/s]
# Epoch 111: 100% 312/312 [02:35<00:00,  2.01it/s, loss=2.54, v_num=1-05]
#                                                             Epoch 111, global step 33152: 'v_loss' was not in top 3
# Epoch 118:  90% 280/312 [02:20<00:16,  1.99it/s, loss=2.62, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 118:  96% 300/312 [02:30<00:06,  2.00it/s, loss=2.62, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.71it/s]
# Epoch 118: 100% 312/312 [02:34<00:00,  2.01it/s, loss=2.68, v_num=1-05]
#                                                             Epoch 118, global step 35224: 'v_loss' was not in top 3
# Epoch 125:  90% 280/312 [02:24<00:16,  1.93it/s, loss=2.66, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 125:  96% 300/312 [02:34<00:06,  1.95it/s, loss=2.66, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.71it/s]
# Epoch 125: 100% 312/312 [02:38<00:00,  1.97it/s, loss=2.65, v_num=1-05]
#                                                             Epoch 125, global step 37296: 'v_loss' was not in top 3
# Epoch 132:  90% 280/312 [02:26<00:16,  1.92it/s, loss=2.69, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 132:  96% 300/312 [02:36<00:06,  1.92it/s, loss=2.69, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.64it/s]
# Epoch 132: 100% 312/312 [02:40<00:00,  1.94it/s, loss=2.6, v_num=1-05]
#                                                             Epoch 132, global step 39368: 'v_loss' was not in top 3
# Epoch 135:  74% 220/296 [01:44<00:36,  2.10it/s, loss=2.61, v_num=1-05]wandb: Network error (ReadTimeout), entering retry loop.
# Epoch 139:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.64, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 139:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.64, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.97it/s]
# Epoch 139: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.59, v_num=1-05]
#                                                             Epoch 139, global step 41440: 'v_loss' was not in top 3
# Epoch 146:  90% 280/312 [02:14<00:15,  2.07it/s, loss=2.59, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 146:  96% 300/312 [02:24<00:05,  2.07it/s, loss=2.59, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.01it/s]
# Epoch 146: 100% 312/312 [02:29<00:00,  2.09it/s, loss=2.64, v_num=1-05]
#                                                             Epoch 146, global step 43512: 'v_loss' was not in top 3
# Epoch 153:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.63, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 153:  96% 300/312 [02:24<00:05,  2.07it/s, loss=2.63, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 153: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.65, v_num=1-05]
#                                                             Epoch 153, global step 45584: 'v_loss' was not in top 3
# Epoch 160:  90% 280/312 [02:14<00:15,  2.09it/s, loss=2.5, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 160:  96% 300/312 [02:22<00:05,  2.10it/s, loss=2.5, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.03it/s]
# Epoch 160: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.35, v_num=1-05]
#                                                             Epoch 160, global step 47656: 'v_loss' was not in top 3
# Epoch 167:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.51, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 167:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.51, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.01it/s]
# Epoch 167: 100% 312/312 [02:27<00:00,  2.11it/s, loss=2.53, v_num=1-05]
#                                                             Epoch 167, global step 49728: 'v_loss' was not in top 3
# Epoch 174:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.45, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 174:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.45, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.00it/s]
# Epoch 174: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.46, v_num=1-05]
#                                                             Epoch 174, global step 51800: 'v_loss' was not in top 3
# Epoch 181:  90% 280/312 [02:13<00:15,  2.09it/s, loss=2.46, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 181:  96% 300/312 [02:22<00:05,  2.10it/s, loss=2.46, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.73it/s]
# Epoch 181: 100% 312/312 [02:27<00:00,  2.11it/s, loss=2.61, v_num=1-05]
#                                                             Epoch 181, global step 53872: 'v_loss' was not in top 3
# Epoch 188:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.46, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 188:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.46, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.69it/s]
# Epoch 188: 100% 312/312 [02:28<00:00,  2.11it/s, loss=2.45, v_num=1-05]
#                                                             Epoch 188, global step 55944: 'v_loss' was not in top 3
# Epoch 194:  95% 280/296 [02:15<00:07,  2.07it/s, loss=2.51, v_num=1-05]wandb: Network error (ReadTimeout), entering retry loop.
# Epoch 195:  90% 280/312 [02:16<00:15,  2.05it/s, loss=2.56, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 195:  96% 300/312 [02:25<00:05,  2.07it/s, loss=2.56, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.97it/s]
# Epoch 195: 100% 312/312 [02:29<00:00,  2.09it/s, loss=2.5, v_num=1-05]
#                                                             Epoch 195, global step 58016: 'v_loss' was not in top 3
# Epoch 202:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.42, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 202:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.42, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.96it/s]
# Epoch 202: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.39, v_num=1-05]
#                                                             Epoch 202, global step 60088: 'v_loss' was not in top 3
# Epoch 209:  90% 280/312 [02:18<00:15,  2.02it/s, loss=2.65, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 209:  96% 300/312 [02:27<00:05,  2.03it/s, loss=2.65, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.89it/s]
# Epoch 209: 100% 312/312 [02:32<00:00,  2.05it/s, loss=2.57, v_num=1-05]
#                                                             Epoch 209, global step 62160: 'v_loss' was not in top 3
# Epoch 216:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.51, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 216:  96% 300/312 [02:25<00:05,  2.07it/s, loss=2.51, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.94it/s]
# Epoch 216: 100% 312/312 [02:29<00:00,  2.09it/s, loss=2.52, v_num=1-05]
#                                                             Epoch 216, global step 64232: 'v_loss' was not in top 3
# Epoch 223:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.47, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 223:  96% 300/312 [02:24<00:05,  2.07it/s, loss=2.47, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.00it/s]
# Epoch 223: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.51, v_num=1-05]
#                                                             Epoch 223, global step 66304: 'v_loss' was not in top 3
# Epoch 230:  90% 280/312 [02:15<00:15,  2.07it/s, loss=2.36, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 230:  96% 300/312 [02:24<00:05,  2.07it/s, loss=2.36, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.00it/s]
# Epoch 230: 100% 312/312 [02:29<00:00,  2.09it/s, loss=2.61, v_num=1-05]
#                                                             Epoch 230, global step 68376: 'v_loss' was not in top 3
# Epoch 237:  90% 280/312 [02:15<00:15,  2.07it/s, loss=2.4, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 237:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.4, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.98it/s]
# Epoch 237: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.46, v_num=1-05]
#                                                             Epoch 237, global step 70448: 'v_loss' was not in top 3
# Epoch 244:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.38, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 244:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.38, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.96it/s]
# Epoch 244: 100% 312/312 [02:27<00:00,  2.11it/s, loss=2.49, v_num=1-05]
#                                                             Epoch 244, global step 72520: 'v_loss' was not in top 3
# Epoch 251:  90% 280/312 [02:15<00:15,  2.07it/s, loss=2.39, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 251:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.39, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 251: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.52, v_num=1-05]
#                                                             Epoch 251, global step 74592: 'v_loss' was not in top 3
# Epoch 258:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.43, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 258:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.43, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 258: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.44, v_num=1-05]
#                                                             Epoch 258, global step 76664: 'v_loss' was not in top 3
# Epoch 265:  90% 280/312 [02:15<00:15,  2.07it/s, loss=2.4, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 265:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.4, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 265: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.4, v_num=1-05]
#                                                             Epoch 265, global step 78736: 'v_loss' was not in top 3
# Epoch 272:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.53, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 272:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.53, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.65it/s]
# Epoch 272: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.44, v_num=1-05]
#                                                             Epoch 272, global step 80808: 'v_loss' was not in top 3
# Epoch 279:  90% 280/312 [02:15<00:15,  2.07it/s, loss=2.42, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 279:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.42, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.00it/s]
# Epoch 279: 100% 312/312 [02:28<00:00,  2.11it/s, loss=2.35, v_num=1-05]
#                                                             Epoch 279, global step 82880: 'v_loss' was not in top 3
# Epoch 286:  90% 280/312 [02:14<00:15,  2.09it/s, loss=2.43, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 286:  96% 300/312 [02:22<00:05,  2.10it/s, loss=2.43, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.05it/s]
# Epoch 286: 100% 312/312 [02:26<00:00,  2.13it/s, loss=2.38, v_num=1-05]
#                                                             Epoch 286, global step 84952: 'v_loss' was not in top 3
# Epoch 293:  90% 280/312 [02:14<00:15,  2.09it/s, loss=2.42, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 293:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.42, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:06<00:00,  2.61it/s]
# Epoch 293: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.49, v_num=1-05]
#                                                             Epoch 293, global step 87024: 'v_loss' was not in top 3
# Epoch 300:  90% 280/312 [02:15<00:15,  2.06it/s, loss=2.31, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 300:  96% 300/312 [02:24<00:05,  2.07it/s, loss=2.31, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.98it/s]
# Epoch 300: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.42, v_num=1-05]
#                                                             Epoch 300, global step 89096: 'v_loss' was not in top 3
# Epoch 307:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.26, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 307:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.26, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.04it/s]
# Epoch 307: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.33, v_num=1-05]
#                                                             Epoch 307, global step 91168: 'v_loss' was not in top 3
# Epoch 314:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.49, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 314:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.49, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 314: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.46, v_num=1-05]
#                                                             Epoch 314, global step 93240: 'v_loss' was not in top 3
# Epoch 321:  90% 280/312 [02:14<00:15,  2.09it/s, loss=2.33, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 321:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.33, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.98it/s]
# Epoch 321: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.43, v_num=1-05]
#                                                             Epoch 321, global step 95312: 'v_loss' was not in top 3
# Epoch 328:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.45, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 328:  96% 300/312 [02:23<00:05,  2.09it/s, loss=2.45, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.97it/s]
# Epoch 328: 100% 312/312 [02:27<00:00,  2.11it/s, loss=2.42, v_num=1-05]
#                                                             Epoch 328, global step 97384: 'v_loss' was not in top 3
# Epoch 335:  90% 280/312 [02:15<00:15,  2.07it/s, loss=2.44, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 335:  96% 300/312 [02:24<00:05,  2.08it/s, loss=2.44, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 335: 100% 312/312 [02:28<00:00,  2.10it/s, loss=2.44, v_num=1-05]
#                                                             Epoch 335, global step 99456: 'v_loss' was not in top 3
# Epoch 342:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.36, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 342:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.36, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 342: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.29, v_num=1-05]
#                                                             Epoch 342, global step 101528: 'v_loss' was not in top 3
# Epoch 349:  90% 280/312 [02:13<00:15,  2.10it/s, loss=2.41, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 349:  96% 300/312 [02:22<00:05,  2.11it/s, loss=2.41, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  3.01it/s]
# Epoch 349: 100% 312/312 [02:26<00:00,  2.13it/s, loss=2.33, v_num=1-05]
#                                                             Epoch 349, global step 103600: 'v_loss' was not in top 3
# Epoch 356:  90% 280/312 [02:13<00:15,  2.10it/s, loss=2.38, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 356:  96% 300/312 [02:21<00:05,  2.11it/s, loss=2.38, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.97it/s]
# Epoch 356: 100% 312/312 [02:26<00:00,  2.13it/s, loss=2.43, v_num=1-05]
#                                                             Epoch 356, global step 105672: 'v_loss' was not in top 3
# Epoch 363:  90% 280/312 [02:14<00:15,  2.08it/s, loss=2.34, v_num=1-05]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/16 [00:00<?, ?it/s]
# Epoch 363:  96% 300/312 [02:23<00:05,  2.10it/s, loss=2.34, v_num=1-05]
# Validation DataLoader 0: 100% 16/16 [00:05<00:00,  2.99it/s]
# Epoch 363: 100% 312/312 [02:27<00:00,  2.12it/s, loss=2.27, v_num=1-05]
#                                                             Epoch 363, global step 107744: 'v_loss' was not in top 3
# Epoch 366:  47% 140/296 [01:08<01:16,  2.04it/s, loss=2.36, v_num=1-05][NeMo W 2022-07-28 05:48:58 nemo_logging:349] /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:726: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#       rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  epoch ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:             epoch_time ▁▄▅█▁▁▂▁▂▄▂▃▄▃▅▃▁▁▂▁▁▃▁▁▃▁▁▂▁▁▂▁▁▂▁▁▃▁▁▁
# wandb:                lr-Adam ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:             t_bin_loss ▁▁▂▂▂▄▄▅▄▇▅▅▄▄▄█▅▅▄▅▅▅▃▄▅▄▅▃▄▃▄▆▃▆▃▄▃▄▄▄
# wandb:             t_ctc_loss ▇▅▅▃▃▄▅▆▂█▃▂▄▂▄▆▄▄▂▄▅▇▁▅▄▃▅▂▅▃▃▄▃▃▃▅▁▄▄▂
# wandb:             t_dur_loss █▆▅▄▆▃▃▃▃▃▃▃▂▂▂▂▂▃▂▂▂▁▁▁▂▁▁▂▂▂▂▂▁▂▂▁▂▂▂▁
# wandb:                 t_loss █▆▅▃▄▄▄▅▂▇▄▃▄▂▄▆▄▄▂▄▅▆▁▄▃▃▄▂▄▂▃▄▃▃▂▄▁▃▃▂
# wandb:             t_mel_loss █▆▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:           t_pitch_loss ▆▃▃▄▅▂▂▂▁▂▂▂█▁▁▂▁▂▁▁▁▁▁▁▁▁▁▂▂▁▁▃▁▁▁▂▂▂▂▁
# wandb:  train_backward_timing ▃▃▄█▃▂▄▃▃▄▂▄▅▂▇▃▃▃▄▄▅▃▃▆▅▅▃▂▅▃▃▂▃▃▁▆▁▆▅▄
# wandb:      train_step_timing ▅▁▄▂▂▂▂▆▂▅▅▁▂▃▂▇▁▄▂▃▆▅▂▄▃▇▅▁▆▁▃▇▂▃▅█▅█▇▂
# wandb:    trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▁▅▅▁▅▆▁▆▆▁▆▇▁▇▇▁▇█▁█
# wandb:             v_dur_loss █▄▁▃▃▂▂▁▂▂▂▂▂▂▂▁▂▃▁▃▂▂▃▁▁▂▂▂▃▃▂▂▂▃▃▂▂▁▂▃
# wandb:                 v_loss █▂▃▃▁▁▄▂▂▁▂▁▂▁▂▂▂▂▃▂▂▄▃▃▃▃▃▃▃▄▃▄▃▅▄▃▃▄▄▅
# wandb:             v_mel_loss █▁▃▃▁▁▃▁▂▁▂▁▂▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▃▄▃▅▄▃▃▄▄▅
# wandb:           v_pitch_loss ▃█▄▅▅▂▆▆▅▁▅▃▃▂▆▃▅▅▆▃▆▅▃▅▃▄▅▂▅▆▆▃▅▃▂▃▃▃▃▃
# wandb: validation_step_timing ▆▅▂▁▅▁▁▆▂▁█▁▁▆▇▁▅▆▁▆▅▁▅▆▁▅▅▂▁▆▁▁▆▁▁▆▁▁▆▁
# wandb:
# wandb: Run summary:
# wandb:                  epoch 366
# wandb:             epoch_time 142.09907
# wandb:                lr-Adam 0.0002
# wandb:             t_bin_loss 0.23697
# wandb:             t_ctc_loss 2.25451
# wandb:             t_dur_loss 0.00327
# wandb:                 t_loss 2.66357
# wandb:             t_mel_loss 0.15675
# wandb:           t_pitch_loss 0.01207
# wandb:  train_backward_timing 0.02153
# wandb:      train_step_timing 0.13417
# wandb:    trainer/global_step 108399
# wandb:             v_dur_loss 0.0208
# wandb:                 v_loss 1.23785
# wandb:             v_mel_loss 1.15405
# wandb:           v_pitch_loss 0.063
# wandb: validation_step_timing 0.01926
# wandb:
# wandb: Synced applejack: https://wandb.ai/convaitech/MLP/runs/2022-07-27_14-01-05
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: training_logs/wandb/run-20220727_140106-2022-07-27_14-01-05/logs

# %% [markdown]
# ## Checking the checkpoint

# %%
#imports
import os
import json
import librosa

import torch
import IPython.display as ipd
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
from pathlib import Path

from nemo.collections.tts.models import FastPitchModel
from nemo.collections.tts.models import HifiGanModel
from nemo.collections.tts.torch.helpers import BetaBinomialInterpolator
import soundfile as sf
import numpy as np

#helper functions
def infer(spec_gen_model, vocoder_model, str_input, speaker=None):
    """
    Synthesizes spectrogram and audio from a text string given a spectrogram synthesis and vocoder model.
    
    Args:
        spec_gen_model: Spectrogram generator model (FastPitch in our case)
        vocoder_model: Vocoder model (HiFiGAN in our case)
        str_input: Text input for the synthesis
        speaker: Speaker ID
    
    Returns:
        spectrogram and waveform of the synthesized audio.
    """
    with torch.no_grad():
        parsed = spec_gen_model.parse(str_input)
        if speaker is not None:
            speaker = torch.tensor([speaker]).long().to(device=spec_gen_model.device)
        spectrogram = spec_gen_model.generate_spectrogram(tokens=parsed, speaker=speaker)
        audio = vocoder_model.convert_spectrogram_to_audio(spec=spectrogram)
        
    if spectrogram is not None:
        if isinstance(spectrogram, torch.Tensor):
            spectrogram = spectrogram.to('cpu').numpy()
        if len(spectrogram.shape) == 3:
            spectrogram = spectrogram[0]
    if isinstance(audio, torch.Tensor):
        audio = audio.to('cpu').numpy()
    return spectrogram, audio

def custom_infer(transcript, spec_model, vocoder, download=None):
  spec, audio = infer(spec_model, vocoder, transcript)
  print("\n\n\n\n")
  ipd.display(ipd.Audio(audio, rate=22050))
  # %matplotlib inline
  plt.show()

def try_infering_with_finetuned_fastpitch(checkpointpath, sentence):
  spec_model = FastPitchModel.load_from_checkpoint(checkpointpath)
  spec_model.eval().cuda()

  vocoder = HifiGanModel.from_pretrained("tts_hifigan")
  vocoder = vocoder.eval().cuda()

  custom_infer(sentence, spec_model, vocoder)

# %%
checkpoint = '/content/drive/MyDrive/TTS_finetuning/apple_jack/FastPitch--v_loss=1.1907-epoch=132-last.ckpt'

# %%
spec_model = FastPitchModel.load_from_checkpoint(checkpoint)
spec_model.eval().cuda()

vocoder = HifiGanModel.from_pretrained("tts_hifigan")
vocoder = vocoder.eval().cuda()
# Out:
# [NeMo I 2022-07-28 06:00:17 tokenize_and_classify:87] Creating ClassifyFst grammars.
# [NeMo W 2022-07-28 06:00:40 g2ps:87] apply_to_oov_word=None, This means that some of words will remain unchanged if they are not handled by any of the rules in self.parse_one_word(). This may be intended if phonemes and chars are both valid inputs, otherwise, you may see unexpected deletions in your input.
# [NeMo W 2022-07-28 06:00:40 modelPT:143] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_train.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: 0.1
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.41
#       pitch_fmax: 2093
#       pitch_norm: true
#       pitch_mean: 324.43
#       pitch_std: 112.51
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 8
#       num_workers: 0
#       pin_memory: true
#
# [NeMo W 2022-07-28 06:00:40 modelPT:150] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.torch.data.TTSDataset
#       manifest_filepath: fastpitch_val.json
#       sample_rate: 22050
#       sup_data_path: fastpitch_sup_data
#       sup_data_types:
#       - align_prior_matrix
#       - pitch
#       n_fft: 1024
#       win_length: 1024
#       hop_length: 256
#       window: hann
#       n_mels: 80
#       lowfreq: 0
#       highfreq: 8000
#       max_duration: null
#       min_duration: null
#       ignore_file: null
#       trim: false
#       pitch_fmin: 65.41
#       pitch_fmax: 2093
#       pitch_norm: true
#       pitch_mean: 324.43
#       pitch_std: 112.51
#       use_beta_binomial_interpolator: true
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 8
#       num_workers: 0
#       pin_memory: true
# [NeMo I 2022-07-28 06:00:40 features:217] PADDING: 1
# [NeMo I 2022-07-28 06:00:40 cloud:56] Found existing object /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.
# [NeMo I 2022-07-28 06:00:40 cloud:62] Re-using file from: /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo
# [NeMo I 2022-07-28 06:00:40 common:789] Instantiating model from pre-trained checkpoint
# [NeMo W 2022-07-28 06:00:43 modelPT:143] If you intend to do training or fine-tuning, please call the ModelPT.setup_training_data() method and provide a valid configuration file to setup the train data loader.
#     Train config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/train_finetune.txt
#       min_duration: 0.75
#       n_segments: 8192
#     dataloader_params:
#       drop_last: false
#       shuffle: true
#       batch_size: 64
#       num_workers: 4
#
# [NeMo W 2022-07-28 06:00:43 modelPT:150] If you intend to do validation, please call the ModelPT.setup_validation_data() or ModelPT.setup_multiple_validation_data() method and provide a valid configuration file to setup the validation data loader(s).
#     Validation config :
#     dataset:
#       _target_: nemo.collections.tts.data.datalayers.MelAudioDataset
#       manifest_filepath: /home/fkreuk/data/val_finetune.txt
#       min_duration: 3
#       n_segments: 66150
#     dataloader_params:
#       drop_last: false
#       shuffle: false
#       batch_size: 5
#       num_workers: 4
#
# [NeMo W 2022-07-28 06:00:43 features:195] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-07-28 06:00:43 features:217] PADDING: 0
# [NeMo W 2022-07-28 06:00:43 features:195] Using torch_stft is deprecated and has been removed. The values have been forcibly set to False for FilterbankFeatures and AudioToMelSpectrogramPreprocessor. Please set exact_pad to True as needed.
# [NeMo I 2022-07-28 06:00:43 features:217] PADDING: 0
# [NeMo I 2022-07-28 06:00:44 save_restore_connector:243] Model HifiGanModel was successfully restored from /root/.cache/torch/NeMo/NeMo_1.11.0rc0/tts_hifigan/e6da322f0f7e7dcf3f1900a9229a7e69/tts_hifigan.nemo.

# %%
custom_infer(" I am a dragon and I like to fly over the town. ", spec_model, vocoder)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/training_logs/FastPitch/2022-07-27_14-01-05/checkpoints -t /content/drive/MyDrive/TTS_finetuning/apple_jack/
